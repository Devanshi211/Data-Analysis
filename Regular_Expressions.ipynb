# %% [markdown]
# Regular expressions, also called regex, is a syntax or rather a language to search, extract and manipulate specific string patterns from a larger text. It is widely used in projects that involve text validation, NLP and text mining

# %% [markdown]
# # Context:
# Fraudulent e-mails contain criminally deceptive information, usually with the intent of convincing the recipient to give the sender a large amount of money. Perhaps the best known type of fraudulent e-mails is the Nigerian Letter or “419” Fraud.
#
# Content:
# This dataset is a collection of more than 2,500 "Nigerian" Fraud Letters, dating from 1998 to 2007.
#
# These emails are in a single text file. Each e-mail has a header which includes the following information:
#
# Return-Path: address the email was sent from
#
# X-Sieve: the X-Sieve host (always cmu-sieve 2.0)
#
# Message-Id: a unique identifier for each message
#
# From: the message sender (sometimes blank)
#
# Reply-To: the email address to which replies will be sent
#
# To: the email address to which the e-mail was originally set (some are truncated for anonymity)
#
# Date: Date e-mail was sent
#
# Subject: Subject line of e-mail
#
# X-Mailer: The platform the e-mail was sent from
#
# MIME-Version: The Multipurpose Internet Mail Extension version
#
# Content-Type: type of content & character encoding
#
# Content-Transfer-Encoding: encoding in bits
#
# X-MIME-Autoconverted: the type of autoconversion done
#
# Status: r (read) and o (opened)

# %%
#First, we’ll prepare the data set by opening the test file, setting it to read-only, and reading it. We’ll also assign it to a variable, fh (for “file handle”).

# %%
#Now, suppose we want to find out who the emails are from. We could try raw Python on its own:

fh = open(r"fradulent_emails.txt", "r",encoding="utf8", errors='ignore').read()
for line in fh.split("\n"):
    if "From:" in line:
        print(line)
# Out:
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>
# From: "Mr. Ben Suleman" <bensul2004nng@spinfinder.com>
# From: "PRINCE OBONG ELEME" <obong_715@epatra.com>
# From: "PRINCE OBONG ELEME" <obong_715@epatra.com>
# From: "Maryam Abacha" <m_abacha03@www.com>
# From: Kuta David <davidkuta@postmark.net>
# From: "Barrister tunde dosumu" <tunde_dosumu@lycos.com>
# From: "William Drallo" <william2244drallo@maktoob.com>
# From: "MR USMAN ABDUL" <abdul_817@rediffmail.com>
# From: "Tunde  Dosumu" <barrister_td@lycos.com>
# From: MR TEMI JOHNSON <temijohnson2@rediffmail.com>
# From: "Dr.Sam jordan" <sjordan@diplomats.com>
# From: p_brown2@lawyer.com
# Subject: From: Barrister Peter Brown
# From: mic_k1@post.com
# From: "COL. MICHAEL BUNDU" <mikebunduu1@rediffmail.com>
# From: "MRS MARIAM ABACHA" <elixwilliam@usa.com>
# From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>
# From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>
# From: "Victor Aloma" <victorloma@netscape.net>
# From: "Victor Aloma" <victorloma@netscape.net>
# From: "JAMES NGOLA" <james_ngola2002@maktoob.com>
# From: "MARTIN CHIME" <martinchime@usa.com>
# From: "Mr George Mboro" <mboro1555@post.com>
# From: "MARTIN  CHIME" <martinchime@borad.com>
# From: "MARTIN  CHIME" <martinchime@borad.com>
# From: <edema_mb@phantomemail.com>
# From: <edema_mb@phantomemail.com>
# From: "ADE WILLIAMS" <adewilliams_ade@lawyer.com>
# From: smithkam2@post.com
# From: "MRS. M SESE-SEKO" <sesm@omaninfo.com>
# From: "obina okoro" <obinaokoro@37.com>
# From: "DR. JAMES  ALBERT" <jamesalbert0@eircom.net>
# Resent-From: software-seminar@eecs.UM
# From: adamuohiroma adamuohiroma <adamuohiroma.adamuohiroma@caramail.com>
# From: "MR FRED OBI." <fredobi3@omaninfo.com>
# From: "mbeki ngumeni" <mbengu@37.com>
# From: mahoyi mamudu <mmahoyi@caramail.com>
# From: "Mr. David Agu" <adgua@mail.com>
# From: "bell.idr bell.idr" <bbell.idr@caramail.com>
# From: "idris.bello idris.bello" <iidris.bello@caramail.com>
# From: john2002@bluemail.ch
# From: "CLEMENT APUTE" <clem-apute@consultant.com>
# From: "MR GODWIN IGBUNU" <g.godwin12345@caramail.com>
# From: "bell.idr bell.idr" <bbell.idr@caramail.com>
# From: "Mr. David Agu" <dav84@mail.com>
# From: "deborah kabila" <kabila72b@37.com>
# From: Khalifa Sese <kss07@go.com>
# From: Khalifa Sese <kss07@go.com>
# From: "MOHAMMED BELLO (Ph.D)" <mohammed_bello_1@yahoo.com>
# From: "PETER WILLIAMS" <cooooofoooooooo@rediffmail.com>
# From: "Oliveira Savimbi" <olivsav@netscape.net>
# From: "Mr. Daniel Osondu" <tdannosondu@mail.com>
# From: Mr.Daniel Osondu
# From: <williamsdaniel1@phantomemail.com>
# From: "Ruka" <rulagg@excite.com>
# From: "IDRIS ADAMU" <idris2003942@aol.com>
# From: "DR.  SANNI  SABO" <davidmensoh@mail.com>
# From: "DR.  SANNI  SABO" <davidmensoh@mail.com>
# From: "Ibrahim Galadima" <ig_esq@rediffmail.com>
# From: ademola1950@hknetmail.com
# From: "Mohammed Abacha" <a_mabachas@yahoo.co.uk>
# From: "PRINCE TUNDE O ADISARAKI" <princeadisaraki5@usa.com>
# From: "judeestrada" <judeestrada2@dmailman.com>
# From: "JONATHAN  MOKOENA" <davidmensoh@mail.com>
# From: olu@mailservice.ms
# From: "res bob12" <resbobi2@al-islam.com>
# From: "LADY MARYAM ABACHA " <mariam.abacha58@boredmail.com>
# From: "MR.TUNDE  BALOGUN" <tundebalogun@omaninfo.com>
# From: "MR.BENSON  ATTAH" <mrbenson_attah@omaninfo.com>
# From: "MR.BENSON  ATTAH" <mrbenson_attah@omaninfo.com>
# From: "MR.TUNDE  BALOGUN" <tundebalogun@omaninfo.com>
# From: "LADY MARYAM ABACHA " <mariam.abacha57@boredmail.com>
# From: "DR.  SANNI  SABO" <davidmensoh@mail.com>
# From: "Dr Luisa Pimental Estrada" <luisaestrada2002@luisapestrada.zzn.com>
# From: "Graham Douglas" <douglas.graham@caramail.com>
# From: luis oboh <oluis2@caramail.com>
# From: luis oboh <oluis2@caramail.com>
# Subject: From:Savimbi Denis
# From: "savimbidenis@www.com" <savimbidenis@www.com>
# From: "Nsekou Mobutu Sesekou" <sekou_family@mailsurf.com>
# From: "DR. BELLO MUSA" <dr_bellomusa01@omaninfo.com>
# From: Frank Williams <frankwilliams2@starmedia.com>
# From: Mr. Frank Williams.
# From: "=?iso-8859-1?Q?lawrence.smith?=" <lawrence.smith@voila.fr>
# From: "DONALD  ATTAH" <donaldattah@netzero.com>
# From: "daniel innocent" <daninno555@37.com>
# From: "deborah kabila" <kabila72i@37.com>
# From: "peter" <peter_savimbi20@phantomemail.com>
# From: "joseph benson" <josephbenson@weedmail.com>
# From: mr_bb@hknetmail.com
# From: "pat odogu" <pat11@weedmail.com>
# From: felix lamine <felix.lamine@caramail.com>
# From: "PATRICK  MOHAMMED" <patrickmohammed@omaninfo.com>
# From: "PATRICK  MOHAMMED" <patrickmohammed@omaninfo.com>
# From: "Mr. Lawrence Abba" <lawrenceabba@operamail.com>
# From: bill_james4@bluemail.ch
# From: Mr Benard Gelicah Sankoh.
# From: "MALCOM TUTU" <macontu05@yahoo.com>
# From: Mr. MALCOM TUTU  (chief auditor)
# From: "MALCOM TUTU" <macontu05@yahoo.com>
# From: Mr. MALCOM TUTU  (chief auditor)
# From: stevens bangura <stevens.bangura@caramail.com>
# From: "MR. DONALD ATTAH" <donaldattah@omaninfo.com>
# From: "Dr mariam abacha" <marabac011@hotmail.com>
# From: Frank Ikpendu <frankikpendu3@mail.co.za>
# From: "jeffery hill" <jeffery_hill10007@hotmail.com>
# From: "malcom tutu" <macontu028@yahoo.com>
# From: "malcom tutu" <macontu028@yahoo.com>
# From: "sam aluko" <samaluko1@37.com>
# From: "GEORGE  KABILA" <ggeorgekabyl@caramail.com>
# From: "CYRIL AKWARANDU" <madu_invest@yahoo.com>
# From: "CYRIL AKWARANDU" <madu_invest@yahoo.com>
# From: "MR.YARO BAMIYI" <doomer@themail.com>
# From: "barr.femi" <barr.femi@caramail.com>
# From: "DR DOUGLAS NWANKWO" <douglankwo@yahoo.com>
# From: "Mrs. Safi  Al Mustapha" <leathercity1@irangate.net>
# From: "Mrs. Safi  Al Mustapha" <leathercity1@irangate.net>
# From: "Dr Mariam abacha" <mariam.aba@caramail.com>
# From: "Dr.Moses" <moses1970@englishexpert.com>
# From: "Dr.Moses" <moses1970@englishexpert.com>
# From: "DR. OLUSEGUN SMITH" <olu002@phantomemail.com>
# From: "Dr. Bernard Makelele" <benkelele@phantomemail.com>
# From: chiedo_jonathan2@netzero.com
# From: "kaseke kenneth" <kasekek@email.com>
# From: willbanigo003@juntos.com
# From: "DR ABDULL RASAQ" <drabdullrasaq@phantomemail.com>
# From: "DR ABDULL RASAQ" <drabdullrasaq@phantomemail.com>
# From: "williame ume" <kkalume@bluemail.ch>
# From: jisrael2@breathe.com
# From: "KENNETH ILOKA" <umarb@themail.com>
# From: charlesnwodo@excite.com
# From: Mr. Charles Nwodo
# From: "Oliveira Savimbi" <olivsav@netscape.net>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: chinaeke7@juno.com
# From: "PAPA BELLO" <papabello@lawyer.com>
# From: "Dr. Don Arturo Ramitez." <don_1000@fastermail.com>
# From: "E E" <foryourconsumption_2@hotmail.com>
# From: "KABILA" <greenkab@email.com>
# From: "Oliveira Savimbi" <olivsav@netscape.net>
# From: "MR DANIEL KALU" <danielkalukalu@netscape.net>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: "NOSA" <ni452003@yahoo.com>
# From: "MR TUNDA" <tundatx@zapo.net>
# From: "DR STEPHEN UMAH" <u.stephen1@caramail.com>
# From: "Dr stephen umah" <u.stephen@caramail.com>
# From: "JOHN CHOMA" <jochom12@hotmail.com>
# From: "DR TONY COLE" <tony3@ecplaza.net>
# From: "DR TONY COLE" <tony3@ecplaza.net>
# From: "DR. GOODWILL MPENZA" <savim_5@email.com>
# From: wbanigo@anfmail.com
# From: "Engr. William Goye" <wgoye@ecplaza.net>
# From: "FRANK  GUEI JNR." <frank_jnr3@myself.com>
# From: solochuks5000@breathe.com
# From: Farouk Al-Bashar <falbashar@olumo.net>
# From: "WILLIAM   OKAFOR" <fowika@ecplaza.net>
# From: Farouk Al-Bashar <falbashar@olumo.net>
# From: "DR STEPHEN AKIGA" <ohunola@latinmail.com>
# From: "DR STEPHEN AKIGA" <ohunola@latinmail.com>
# From: "Ola Kelvin" <olakelv3@ecplaza.net>
# From: MRS CECILIA MARK AKU <mrscecilliaak@ecplaza.net>
# From: "MR.DON UBALA," <donubala@ecplaza.net>
# From: "Dr. Wilson" <itwilson33@netscape.net>
# From: James Kabila.
# From: dayonaps04@aol.com
# From: "Oliveira Savimbi" <olisav@netscape.net>
# From: "Dr Pascal Ugoti" <pascal_962@myself.com>
# From: "Dr Pascal Ugoti" <pascal_962@myself.com>
# From: "Professor Frank Obi" <professorfranko@netscape.com>
# From: "koffi joseph" <offjo@hotmail.com>
# From: "ENGR: KUMALO DILIZA" <kumalodiliza6@ecplaza.net>
# From: "MR GBENRO ADEGBOLA" <salisu_bola@yahoo.com>
# From: "MAKO OKERE" <okere1972@netscape.net>
# From: "GBENGA ALUKO" <gbealuko@voila.fr>
# From: "MR, DOMAS K, YANK" <kecityy@netscape.net>
# From: "Oliveira Savimbi" <olisav@netscape.net>
# From: "DR. PAUL BABS." <paulbabs@caramail.com>
# From: "grace abba-gana" <gabbagana@albawaba.com>
# From: "salatu_ibru300" <salatu_ibru300@indiatimes.com>
# From: "ADEROJU MUYIWA" <ademuyiwa1950@rediffmail.com>
# From: "Mr Olu Martins" <olu_martins007@yahoo.com>
# From: "maryam  abacha" <maryamy2k@indiatimes.com>
# From: "MRS ROSE SAVIMBI" <rosesavibmi@rediffmail.com>
# From: luisaastrada@portugalmail.com
# From: MARIAM ABACHA <mariamabacha202@ecplaza.net>
# From: "Bola  Harry" <bolaharryt@tiscali.co.uk>
# From: "Bola  Harry" <bolaharryt@tiscali.co.uk>
# From: "DR.TUNJI OWO" <tunjiowo@regards.net>
# From: Owen Mubane <muowen^%&@mmail.com>
# From: "DR.TUNJI OWO" <tunjiowo@regards.net>
# From: Mohammed Abacha <orionventures@go.com>
# From:Muhammed Abacha
# From: "ENGR ZULUMAKALENI." <zulumakaleni1@netscape.net>
# From: "DR (MRS) MARIAM ABACHA" <koolizzy@hotmail.com>
# From: "MR. TAMBO" <engranthony_zuma@lycos.com>
# From: Dukat Kabila <dukatka_s22@rediffmail.com>
# From: "Dr. Bouguiba Samuel" <samaguiba1@ecplaza.net>
# From: James Oni <jamesoni2000@go.com>
# From: James Oni <jamesoni2000@go.com>
# From: James Oni <jamesoni2000@go.com>
# From: CARLOS SAVIMBI <carlos_sav@go.com>
# From: "MRS, AMINA BOLA IGE" <isa_kaitha2002@yahoo.com>
# From: "Andy Bello" <andy_bello2003@rediffmail.com>
# From: "Andy Bello" <andy_bello2003@rediffmail.com>
# From: "AHMED MARTINS. D" <martinsdanjuma@mail15.com>
# From: Gabriel Kali <gadikali@gatechambers.com>
# From: "Mr.Kola Awosika" <kola.awosika@caramail.com>
# From: "SAAD A.ALLI" <husseinalli33@zwallet.com>
# From: "JOHNSON ABBAS" <johnsonabbas@zwallet.com>
# From: "Dr.Tito Sithole." <macusgee@hotmail.com>
# From: KATURA BANGA <mrkatban@netscape.net>
# From: "MADAM MARYAM" <maryamy2k@indiatimes.com>
# From: "DELE MARTINS" <delemartins@indiatimes.com>
# From: saidi fatou <saidifatou@moldova.com>
# From: "Mrs. Mariam M. Sese-seko" <Liusa11@totalise.co.uk>
# From: "MICHAEL AFOLABI" <frankemeni@ecplaza.net>
# From: NZANGA MOBUTU <Nzangamobutu@phantomemail.com>
# From: NZANGA MOBUTU <Nzangamobutu@phantomemail.com>
# From: "CHUKS ANTHONY" <chuksanthony05@netscape.net>
# From: "godfrey eche3" <godfreyeche3@albawaba.com>
# From: "godfrey eche3" <godfreyeche3@albawaba.com>
# From: "Muhammad Khalil Hasan" <khalil_muhammad@myownemail.com>
# From: "Muhammad Khalil Hasan" <khalil_muhammad@myownemail.com>
# From: "Hamzat Sulaiman" <hamzatsulaiman@unionintbanks.com>
# From: "keven wei" <envoltbattery@163.com>
# X-Original-From: ami44000@netzero.com
# From: ami44000@netzero.com
# From: "Mr Chuks Anthony" <chuksanthony05@netscape.net>
# From: " JOHNSON ELENDU " <jelendu@nzoomail.com>
# From: "Mike Jide" <mijez2001_nnpc@indiatimes.com>
# From: "Mike Jide" <mijez2001_nnpc@indiatimes.com>
# From: wale_williams@post.cz
# From: "Fred Mbonu" <mfrred@hknetmail.com>
# From: "Fred Mbonu" <mfrred@hknetmail.com>
# From: JOHN COLEMEN <johncolemen1970@netscape.net>
# From: j_remitance@hknetmail.com
# From: "Mrs. Mariam M. Sese-seko" <liusaxxxx@totalise.co.uk>
# From: "MakamSomo" <sa_03@breathe.com>
# From: "Engr. Musa  Akim." <engr_musa@hknetmail.com>
# From: "Engr. Musa  Akim." <engr_musa@hknetmail.com>
# From: "DR.MATTHEW OKOYE" <mattokoye@didamail.com>
# From: "abram nkomo" <ab_nkomo@hotmail.com>
# From: maira ssesko <sseko019@go.com>
# From: Joseph Mobutu Sese-Seko <jmobutu189@latinmail.com>
# From: "Mariam Abacha" <myriaj03@femail.com.au>
# From: Joseph Mobutu Sese-Seko <jmobutu189@latinmail.com>
# From: "PRINCE FOLU FADAKA" <folufadaka@netzero.com>
# From: sussy emma <e.sussy@caramail.com>
# From: "Harry O Harry" <harry1@hknet.com>
# From: Drmoore James <jdrmoore@personal.ro>
# From: "PRINCE WILLIAMS" <princewilliamson99@portugalmail.pt>
# From: "PRINCE M  WILLIAMS" <princewilliamson99@portugalmail.pt>
# From: "MRS CECILIA  AKU" <aku_cmrs2002@surfy.net>
# From: MECK MAHABILE <mahabile10@netscape.net>
# From: "FRANK BELLO" <fbellojr39@hotmail.com>
# From: "FRANK BELLO" <fbellojr39@hotmail.com>
# From: "Mr. Mike Obodoh" <mike.obodoh@caramail.com>
# From: "Barrister. Bassey  Owo" <basseyowo300@hknetmail.com>
# From: "MUYIWA IGE" <bechmank@yahoo.com>
# From: "Dr.Tunde Cole" <tundecole@uboot.com>
# From: "Dr Tunde Cole" <tundecole@uboot.com>
# From: "williamume" <willyume@zapo.net>
# From: "Mr.Philip Jones" <philjones1@uboot.com>
# From:Mr.Philip Jones.
# From: solosavimbi@netscape.com
# From: "LEO  WILLIAMS" <leowilliams3@ipost.cz>
# From: =?iso-8859-1?Q?makathy?= <makathy@libero.it>
# From: "MRS MARY SANKOH" <sank_mary6@popmail.com>
# From: "Mr.Bom Uche" <mrbom@fastermail.com>
# From: "Mr.Bom Uche" <mrbom@fastermail.com>
# From: ikhayere obinyan <ikhayere6000@addlebrain.com>
# From: "Mr. Daniel Abass." <danielabass@afmail.com>
# From: BASHER MOBUTU <basher39@lycos.com>
# From: evans peter <evanspeter@hkonline.com>
# From: "CHIEF(DR.)BODE GEORGE" <bode_george@xuppa.com>
# From: "CHIEF(DR.)BODE GEORGE" <bode_george@xuppa.com>
# From: "GREGORY PREMIER" <gregoryprem@incamail.com>
# From: "....." <xxxxnnnnaaaa@netscape.net>
# From: "Mr.Fred Obi" <fredobi02@zwallet.com>
# From: idris umar <idrisumar94@go.com>
# From: idris umar <idrisumar94@go.com>
# From: idris umar <idrisumar94@go.com>
# From: "daniel bello" <danbello07@hotmail.com>
# From: "Mohammed Abacha" <dansekou@voila.fr>
# From: "Mohammed Abacha" <dansekou@voila.fr>
# From: "mrs m mbeki" <mrsmbeki@juno.com>
# From: "Kola Daniel" <kolad05@indiatimes.com>
# From: E-Loan Consumer Department <consumer.support@e-loan.com>
# From: E-Loan Consumer Department <consumer.support@e-loan.com>
# From: E-Loan Consumer Department <consumer.support@e-loan.com>
# From: princeige@mail3000.com
# sum of forty million United States dollars to From:
# From: "Francis Sonto Mbomam" <dr_francis_mboma0@lycos.com>
# From: Wells Fargo Accounting <wfba.accounting@wellsfargo.com>
# From: Wells Fargo Accounting <wfba.accounting@wellsfargo.com>
# From: Wells Fargo Accounting <wfba.accounting@wellsfargo.com>
# From: frank <frankzambani42@netscape.net>
# From: "Pandindra" <>
# From: Dr. Uba Jega.
# From: usman aminu <dr_aminuusman@anytimenow.com>
# From: "Dr .Titi okonkwo" <titi_okonkwo@yahoo.com>
# From: "Dr .Titiokonkwo" <titiokonkwo234@yahoo.com>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: ENGR MARK DAVID <igho200@netscape.net>
# From: "Fadaka Randebe" <randebe@kalpoint.com>
# From: "Fadaka Randebe" <randebe@kalpoint.com>
# From: Ali Mohammed <ali_mohammed@123.com>
# From: "First Bank Nig. Plc.( Dr. Femi Johnson.)" <fbplcnig@nzoomail.com>
# From: "carlos savimbi" <savimbicar1@dogmail.co.uk>
# From: vumeh704@hknetmail.com
# From: "CHIEF(DR.)BODE GEORGE" <bodegeorge@pisem.net>
# From: mariam abachas <mariamabachs@go.com>
# From: "ALI AHMED" <aliahmed@ecplaza.net>
# From: "Abu Kyari." <akyari1@sudanmail.net.sd>
# From: alimabu@tiscali.co.uk
# From: "Joseph Savimbi" <joseph_1ang@zwallet.com>
# From: "Joseph Savimbi" <joseph_1ang@zwallet.com>
# From: "prince george duke" <naa8m@mail.com>
# From: okijames@latinmail.com
# From: "Mr. Jeffrey Daniels" <jeffreydaniels2@excite.com>
# From: "Mr. Jeffrey Daniels" <jeffreydaniels4@excite.com>
# From: "ADA USMAN!" <adausman@popmail.com>
# From: "Daniel  Kargbu" <dankar3@zwallet.com>
# From: "Mr. John Nlobo" <johnnlobo@yahoo.com>
# From: <ajala8000@rediffmail.com>
# From:Mr.Wilson Ajala
# From: "Dr.Kunle Owolo" <kunowolo3@tiscali.co.uk>
# From: "Dr.Kunle Owolo" <kunowolo3@tiscali.co.uk>
# From: "MRSJENNIFER KOBE" <mrsjennikobe@hknetmail.com>
# From: jackamala@tiscali.co.uk
# From: "DR THOMAS AUDU" <thomasaudu@mail.com>
# From: kalu idika <kaluidikak@go.com>
# From: makalele01@xzapmail.com
# From: g_ineh@tiscali.co.uk
# From: "Michael Stevens Junior." <marksteven301@netscape.net>
# From: "Hajia Maryam Abacha" <maraba234@anfmail.com>
# From: "Hajia Maryam Abacha" <maraba234@latinmail.com>
# From: "BARRISTER MATHEW IKE" <mathewike212@juno.com>
# From: engedetamanah@post.cz
# From: "MR.ODIASE GEORGE" <sunnyokogwo@post.cz>
# From: "DEACON ZIK R. DON" <deacon_zik@yaoo.com>
# From: "Nzanga Mobutu" <mobkuz3@kukamail.com>
# From: adew1@mail3000.com
# From: adew1@mail3000.com
# From: "DR.MUHAMMED MUSTAFA" <muhammed303@arabtop.net>
# From: "BARRISTER, HOPKINS MBEKI" <hopkinsmbeki@hknetmail.com>
# From: ndandla@latinmail.com
# From: <mcabacha@freesurf.fr>
# From: "Mr Ugochukwu .W" <ugoch_8@z6.com>
# From:Mr.UGOCHUKWU WILLIAM. URGENT REQUEST FOR ASSISTANCE Tel: 00971-50-7155760. Private e-mail:(ugochukwu9@yahoo.co.uk) Dear sir, This letter might surprises you because we have met neither in person nor by correspondence.But I believe it is one day that you got to know somebody either physical or through correspondence,I got your contact through the web-site when I was searching for a reliable trusth-worthy foreign partner to work with. However I am the son of Ex-Minister of Finance Mr.Ugochukwu, a formal Minister of Finance during Late President Laurent Kabila of Democratic Republic of Congo. Infact, I left my country because it was no longer save for me. My father is now in detention awaiting trial because of his involvement againt the government of President Joseph Kabila, who is presently the president of my country. My father called my attention and informed me that he lodged some funds on a Trunk Box with a security firm with an open beneficiary status.I am making thi!
# From: shaabanbait@primposta.com
# From: shaabanbait@primposta.com
# From: consultant_ng3@send-mail.co.uk
# From: mike odey <modey06@go.com>
# From: "DR. AKIN DADA." <akindada@indiatimes.com>
# From: "barrister vincent usman" <2003vincent@freesurf.fr>
# From: "JAMIE  OPUKU." <jamie777@mail.biz.ly>
# From: <jerrypeter2@freesurf.fr>
# From: "mona noah" <mnoah3@hotmail.com>
# From: "MICHEAL  OSSAI" <JUDE@YAHOO.COM>
# From: test@yahoo.com
# From: test@yahoo.com
# From: "Peter Bongo" <mrbongo@themail.com>
# From: MASTER HAROLD MBEKI <akumembeki@netscape.net>
# From: "maryaabacha8 maryam " <mmaryaabacha8@caramail.com>
# From: Mrs Maryam Abacha
# From: "maryaabacha8 maryam " <mmaryaabacha8@caramail.com>
# From: Mrs Maryam Abacha
# From: "H B" <hansob@123.com>
# From: diaka tshombe <dtshombe2@123.com>
# From: EKONG BASSEY <ekong.bassey2@caramail.com>
# From: Vasil Nanchev <vas_imoti@abv.bg>
# From: frank okonjo <frankokonjo5@123.com>
# From: "DR. GODWIN KALALA" <gokalala1@tiscali.co.uk>
# From: EKONG BASSEY <ekong.bassey2@caramail.com>
# From: HELLEN SHAKA ZUMA <hellenshaka@netscape.net>
# From: Akande fredrick <fredsam@123.com>
# From: esama kingdom <esamakingdom@fsmail.net>
# From: MARY ABASS <mary_abass2@123.com>
# From: frank okonjo <frankokonjo6@123.com>
# From: "vino koni" <vinokoni5@hotmail.com>
# From: sarah.mutete@caramail.com
# From: "DAVIDS ANDERSON." <anders01_lb@post.cz>
# From: diaka tshombe <dtshombe3@123.com>
# From: markedeozo@freesurf.fr
# From: allan Sheriff
# From: abu_saeed4@tiscali.co.uk
# From: elosub@freesurf.fr
# From: "Yetunde Bassey" <yetunde@mail2world.com>
# From: "Yetunde Bassey" <yetunde@mail2world.com>
# From: "lary kamokai" <lary_kamokai1@hotmail.com>
# From: "micheal ado santigo" <micheal_ado@hotmail.com>
# From: <fredkuma@freesurf.fr>
# From: wolny_olkusz@latinmail.com
# From: "DR. George Ibrahim Quattara" <dr_georgequattara@indiatimes.com>
# From: "Mr..John Chukwu" <johnchukwu1@caramail.com>
# From: "DR BELLO BATURE" <dr.bell_bat@portugalmail.com>
# From: "maryaabacha8 maryam " <mmaryaabacha8@caramail.com>
# From: Mrs Maryam Abacha
# From: "Mrs. Juliet Bello." <ladyj4u@mail2cherry.com>
# From: "Mrs. Serena  Jones" <serenajones$$7@netscape.net>
# From: Mrs Serena Jones
# From: "chuks Anthony" <chuksanthony05@netscape.net>
# From: =?us-ascii?Q?jide=20williams?= <jide.williams@seznam.cz>
# From: yinkadavi@mailbox.hu
# From: "MR.WILLIAM" <william_d@zwallet.com>
# From: "MR.WILLIAM" <william_d@zwalley.com>
# From: karimusesay@whipmail.com
# From: chesson_joseph@mail2world.com
# From: J.Rodney chesson jr
# From: "Nelson Abia" <nelson_abia203@hotmail.com>
# From: "MR ALI AMED" <prince_amed011@hotmail.com>
# From: "muhammed abacha" <abamohammed@ananzi.co.za>
# From: "HASSAN DIKO" <hassandiko@fsmail.net>
# From: "OLUWATOBI E.BOYE" <oluwatobiboye@dcemail.com>
# From: "OLUWATOBI E.BOYE" <oluwatobiboye@dcemail.com>
# From: "Mr Nelson Abia" <nelson_abia203@hotmail.com>
# From: "Fred Okoli" <redokoli42@yahoo.com>
# From: "haji musa diya" <musa_diya@fastermail.com>
# From: "haji musa diya" <musa_diya@fastermail.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: Mrs Serena Jones <ssarejo355@netscape.net>
# From: Mrs Serena Jones
# From: "prince duke" <aa44@rt.nl>
# From: "MRS M. SESE SEKO" <nanaseko3@web-mail.com.ar>
# From: Mac Jonson Bonida <jonsonbonida_mac$77@latinmail.com>
# From: "Mrs.Floxy Page" <floxypage44@hknetmail.com>
# From: "PETER OKOYE" <opeter6@caramail.com>
# From: "PETER OKOYE" <opeter6@caramail.com>
# From: "MRS.MARYAM ABACHA" <firstlady234@post.cz>
# From: "MRS M. SESE SEKO" <nanaseko4@web-mail.com.ar>
# From: "MOHAMMED" <port1.net@email.it>
# From: "MOHAMMED" <port1.net@email.it>
# From: "MOHAMMED" <port1.net@email.it>
# From: "HAJIA MARYAM ABACHA" <hajia2000@i2828.com>
# From: =?us-ascii?Q?mogua=20mogogo?= <moguam@seznam.cz>
# From: selina_gabrielmarinze <selina_gabrielmarinze@voila.fr>
# From: y a <project101@123.com>
# From: "MRS AMINA MOHAMMED" <aminamohammed311@netscape.net>
# From: MRS SUSAN <mrs_susan2@123.com>
# From: "Dr.Faroq Uztaz[Regional Director]" <faroqz10@hotmail.com>
# From: MR JANG DOO-HWAN <jangdo1@hknetmail.com>
# From: ken dikko <kendikko01@123.com>
# From: "Mr Ugochukwu" <ugochukwu_8@z6.com>
# From: "from prince duke" <d11@rt.nl>
# From: "from prince duke" <van77@rt.nl>
# From: Thomas Taylor <thomutete@netscape.net>
# From: "Mr.Michael Dohn" <m_doh4@zwallet.com>
# From: "Mr.Michael Dohn" <m_doh4@zwallet.com>
# From: jonbwaya@tiscali.co.uk
# From: jonbwaya@tiscali.co.uk
# From: william Isiaka <williamisiaka55@123.com>
# From: "DR. MRS. MARIAM ABACHA" <hmariam234@rediffmail.com>
# From: "MR MICHAEL EWALD" <mikeewald@eudoramail.com>
# From: abayomidavies@yahoo.com
# Subject: From:  Davies
# From: errol_marshall2@albawaba.com
# From: mrsjane abdullah <mrsjaneabdullah@123.com>
# From: Yetunde Bassey <yet_bassey@123.com>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MOHAMMED ABACHA" <mohammed_ab000@go.com>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MARK AKPU" <markakpu@tiscali.co.uk>
# From: susan shabangu <sussy_shab@123.com>
# From: "Mr. Nasser Nasiri." <nassernasiri2003@uaemail.com>
# From: "Mr. Nasser Nasiri." <nassernasiri2003@uaemail.com>
# From: "Mr. Nasser Nasiri." <nassernasiri2003@uaemail.com>
# X-Original-From: "sogolo_hmd@juno.com" <sogolo_hmd@juno.com>
# From: sogolo_hmd@juno.com
# From: "prince duke" <laa@rt.nl>
# From: jrchesson@rediffmail.com
# From: J. Rodney Chesson
# From: Mrs Serena Jones <serenajones1@rediffmail.com>
# From: Mrs Serena Jones
# From: MR BASHE MOBUTU SESE SEKO <mobutbashe3@rediffmail.com>
# From: "PETER BUNO" <peterbuno@rediffmail.com>
# From: "PETER BUNO" <peterbuno@rediffmail.com>
# From: jeffmboma@tiscali.co.uk
# From: "ABDULKAREEM USMAN" <abdulkareem_39@findology.com>
# From: "Mr. Duke Nze" <dukenze@123.com>
# From: "Mr. Duke Nze" <dukenze@123.com>
# From: "Phill Ipenza" <philpenza@ecplaza.com>
# From: james kyari <jameskyari22@netscape.net>
# From: "DR DONALD" <dr_don_ike@hknetmail.com>
# From: mariama seseko <mmssko2@123.com>
# From: "NETHERLOTTO CORPORATION." <netherlotto@corporation.com>
# From: "MR.DANDY NNAJI" <dandy_nnaji@yahoo.com>
# From: "MR.DANDY NNAJI" <dandy_nnaji@yahoo.com>
# From: "PETERSON BULINGA" <peson@zwallet.com>
# From: MR JOSEPH MOBUTU SESE SEKO <josephmobutu200$@latinmail.com>
# From: dada abu <dada@fsmail.net>
# From: Yetunde Bassey <yet_bassey@123.com>
# From: susan shubangu <susanshubangu@123.com>
# From: kayode phillip <kayodephillip@fsmail.net>
# From: Mrs Jumai YOUSSEF <juma2003@thepostbox.co.uk>
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# <BODY>From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# <BODY>From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# <BODY>From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# <BODY>From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: Alexander Afadia <eeaesq@123.com>
# From: "MUSA AHMED ZULU" <musma_adb@ny.com>
# From: issacwimpoehato@yahoo.com
# From: Mallam Bello Ali <mallam_bello@123.com>
# From: james morgan <jamesmorgan@fsmail.net>
# From: "Fred Okoli" <fredokoli300@yahoo.com>
# From: "Fred Okoli" <fredokoli300@yahoo.com>
# From: "MR.lucman Watson" <lucman_watson@macmail.com>
# From: "KAZEEM AHMED" <kazeemahmed@gawab.com>
# From: JULIET UGAGA <julietugaga22@netscape.net>
# From: Frank Bello <fbello1@megamail.pt>
# From: Frank Bello <fbello1@megamail.pt>
# From: "MR FEMI MARTINS" <femi-martins876@fsmail.net>
# From: "laurent_nkono@zwallet.com" <laurent_nkono@zwallet.com>
# From: "MRS. MARIAM ABACHA (WIDOW)." <bonakama232322de45@eudoramail.com>
# From: manuelsisilu@latinmail.com
# From: "Mohammed Mustafa" <mohammedmustafa@arabtop.net>
# From: abachafamily4@tiscali.co.uk
# From: "THEMBI" <thembi79@zwallet.com>
# From: kojadams <kojadams@voila.fr>
# From: "Carl Eblon" <carleblon@zwallet.com>
# From: "DAVIS TUTU" <davistutu@yahoo.co.uk>
# From: "SAM KOROMA" <sarakoroma@hotmail.com>
# From: "" <mjaja02@libero.it>
# From: hildatoms@Eudoramail.com
# From: "Rose Savimbi" <rosesav1@webave.com>
# From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123.com>
# From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123.com>
# From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123.com>
# From: usman_ali@tiscali.co.uk
# From: henrich agah <hc_agah555@fsmail.net>
# From: "FROM MRS RAMA IDRIS" <rama1@whipmail.com>
# From: "FROM  PRINCE WILLIAMS  TAYOLR." <princewillams773@z6.com>
# From: "FROM  PRINCE WILLIAMS  TAYOLR." <princewillams773@z6.com>
# From: joseph.williamvaye@caramail.com
# From: "collins" <collinsngobe@fsmail.net>
# From: "collins" <collinsngobe@fsmail.net>
# From: kaladah@epatra.com
# From: "DR OKON PHILIP" <okphilip1@tiscali.co.uk>
# From: "Donga Kabaka" <dongakabaka@tiscali.co.uk>
# From: james momodu <Bruno.Daems@pandora.be>
# From: "MR IBRAHIM YADUDU." <ibrahimyadudu@tiscali.co.uk>
# From: "DR. JOHNSON KENNETH" <jjoh3000@yahoo.co.uk>
# From: "DR. JOHNSON KENNETH" <jjoh3000@yahoo.co.uk>
# From: gregorykabila333@mail.bg
# From: mary alade <maryalade66@fsmail.net>
# From: K.M.ZONDI@foxfire.mr.itd.UM (REV),
# From: "DANJUMA WILLIAMS M" <danjumawilliams@fsmail.net>
# From: dr kabo hammed <ka_hammed@fsmail.net>
# From: maryam abacha <mar_maryam@fsmail.net>
# From: "KEN GOMAN" <ukpd@web-mail.com.ar>
# From: mohameed_aba1@tiscali.co.uk
# From: mohameed_aba@tiscali.co.uk
# From: "george akin" <george2000@wp.pl>
# From: robert harare <rharare1@spinfinder.com>
# From: mohameed_aba@tiscali.co.uk
# From: "J.C.G" <jocg102@netscape.net>
# From: "oliver  yengeni" <oliveryengeni@tiscali.co.uk>
# From: kufor2000 <kufor2000@tatanova.com>
# From: "matthew molefe" <matthewmolefe3@webmail.co.za>
# From: tblmichl <tblmichl@voila.fr>
# From: DR USMAN BELLO <dr_usmanbello@fsmail.net>
# From: her29@rediffmail.com
# From: 03mariam@tiscali.co.uk
# From: jewel taylor <jeweltaylor_274@fsmail.net>
# From: "James Mercy Sankoh" <sankoh.james@caramail.com>
# From: "James Mercy Sankoh" <sankoh.james@caramail.com>
# From: "Mr Zakir Mahmood" <zakirmahmood@primposta.com>
# From: "Mr Zakir Mahmood" <zakirmahmood@primposta.com>
# From: "MR. JAMES NICHOLAS" <jamesnicholas@zwallet.com>
# From: "Dr.Wahid Mallam" <wahidmallam@fsmail.net>
# From: Bello Musa <bmusa11@fsmail.net>
# From: "MR. BASIL EZE" <bakko_bakko@yahoo.com>
# From: "Dr. Felix William" <felix_william123@hotmail.com>
# From: steveuwa <steveuwa@telstra.com>
# From: steveuwa2@tiscali.co.uk
# From: steveuwa2@tiscali.co.uk
# From: "KAMARA WILLIAM" <kamara1000w@hotmail.com>
# From: "MRS.ROSE OBASEKI" <roseoba1@webmail.co.za>
# X-Original-From: "jj_walter9@netzero.com" <jj_walter9@netzero.com>
# From: jj_walter9@netzero.com
# From: "Dardossi" <b.goronyo1@caramail.com>
# From: Dr.Goronyo Baba..
# From: MRS MUDIWA ZUKA <zuka2004@netscape.net>
# From: "Mrs. Jumai Abdul Azad." <fatima_abdul@sify.com>
# From: Zuka <zuka2005@netscape.net>
# From: "Mariam Mustapha" <marab_ha@weedmail.com>
# From: jubeeg venture <jubeegv@fsmail.net>
# From: Kanu Chijuka <dr_kanuchijuka@fsmail.net>
# From: "Robinson Dike" <dr.robinson.dike@webmail.co.za>
# From: "Robinson Dike" <dr.robinson.dike@webmail.co.za>
# From: "Robinson Dike" <dr.robinson.dike@webmail.co.za>
# From: =?iso-8859-1?Q?michael_=A0nkomo?= <nkomo2004_026@fsmail.net>
# From: =?iso-8859-1?Q?michael_=A0nkomo?= <nkomo2004_026@fsmail.net>
# From: "kolapo omidire" <kolapoomidire2@webmail.co.za>
# From: abdullah_andani@z6.com
# From: abdullah_andani@z6.com
# From: patrick atike <patrickatike2@fsmail.net>
# From: nze_moore <nze_moore@voila.fr>
# From: mngomeni james <mngomeni4@fsmail.net>
# From: Engineer Tony Edem <engrtonyedem@fsmail.net>
# From: Engineer Tony Edem <engrtonyedem@fsmail.net>
# From: kufor_1000 <kufor_1000@tatanova.com>
# From: "MR JOHN MENSAH" <johnmensah@past.cz>
# From: "Mr. Zakir Mehmood" <mood_zakir22@primposta.com>
# From: MRS LOI C ESTRADA <mrrssjjjoseph@netscape.net>
# From: MRS LOI C ESTRADA <mrrssjjjoseph@netscape.net>
# From: "MRS LOI C. ESTRADA" <estradason2@tiscali.co.uk>
# From: "MRS LOI C. ESTRADA http://www.iro.bsp.gov.ph/whoswhoprint.asp?ID=30
# From: George Nduumba <georgenduumba@fsmail.net>
# From: "Susan Martins" <smartins1@webmail.co.za>
# From: Mrs.Susan Martins
# From: WILLIAMS OLUFEMI <barrisolu@fsmail.net>
# From: "frank damas" <frankdamas34@webmail.co.za>
# From: "PRINCE OGO" <princeogo20043000@yahoo.com>
# From: "PRINCE OGO" <princeogo20043000@yahoo.com>
# From: "blessed ogbe" <blog333@webmail.co.za>
# From: "PRINCE CHARLES ZUMA" <prince_charlzuma@fsmail.net>
# From: ohams oham <ohams1@fsmail.net>
# From: "DR WILLIAMS FREDRICK" <drwilldrick25@fsmail.net>
# From: paul bugati <paul147_422@fsmail.net>
# From: "SA" <suleoketayo@alexandria.cc>
# From: Mr Usman Ramat <mrramatu@fsmail.net>
# From: blessed ogbe <blog555ng@fsmail.net>
# From: "michael nkomo" <nkomo_2004@cosmo.com>
# From: "michael nkomo" <nkomo_2004@cosmo.com>
# From: "JONAS SAVIMBI" <sourcetrans@weedmail.com>
# From: "aishatu            ahmed" <aishatuahmed006@hotmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: s.shabangu2@freenet.de
# From: Mrs. Susan Shabangu.<br>
# From: Martins Aku <martinsaku01@truthmail.com>
# From: Martins Aku <martinsaku01@truthmail.com>
# From: "Mr. Zuhair Idris" <idris_z@primposta.com>
# From: "Mr. Zuhair Idris" <idris_z@primposta.com>
# From: "SA" <suleoketayo@alexandria.cc>
# From: "ahmed abu" <ahmedabu@e-tapaal.com>
# From: ".." <ewossawk@netscape.net>
# From: "FROM DANIEL TUNDE" <daniel09@yahoo.com>
# From: "Mr Richard Akwasi" <Akwasi101@52.com>
# From: abu_saeed04@tiscali.co.uk
# From: mzimba_vivian@hotmail.com
# From: "KEN AMOBI" <ukpd2@email.cz>
# From: "Dr. Lukman Rilwanu" <luckmankkk@netscape.net>
# From: Kalister Maunda <kalika@tiscali.co.uk>
# From: "Usman Ramat" <ramatemail@cosmo.com>
# From: "Usman Ramat" <ramatemail@cosmo.com>
# From: larryacb <larryacb@voila.fr>
# From: larryacb <larryacb@voila.fr>
# From: "Barrister Maxwell Obiekwu ." <barristermaxwell1@macmail.com>
# From: "MARIAM ABACHA" <marian_abacha@indiatimes.com>
# From: "David Aku" <dudu1234@webmail.co.za>
# 	0.9 FROM_ENDS_IN_NUMS      From: ends in numbers
# From: "MR JERRY OZUBA" <j_ozuba@fsmail.net>
# From: onyemauk2004 <onyemauk2004@voila.fr>
# From: "Dr. Kelly William" <kellywiliam2@telstra.com>
# From: "Susan Martins" <swodi111@hotmail.com>
# From: "Richard Akueze" <richardakueze@cosmo.com>
# From: "MADAM STELLA SIGCAU" <madamstellasigcau_8@fsmail.net>
# From: "MADAM STELLA SIGCAU" <madamstellasigcau_8@fsmail.net>
# From: "jeffersila04" <jeffersila04@libero.it>
# From: JOHNSON  <johnsontwilliams@netscape.net>
# From: "Peter Saseh" <sasehpeter@latinmail.com>
# From: Rashidat Azmil <r_azmil@email.si>
# From: "fred mende" <fredmende04@zwallet.com>
# From: SIMON OKOH1 <simonokoh1@fsmail.net>
# From: "Engr Mansur Ahmed" <manahmed@sify.com>
# From: bmohammend@themail.com
# From: bmohammend@themail.com
# From: bmohammend@themail.com
# From: bmohammend@themail.com
# From: "Dr. Mchenry Douglas" <mchenry911@tiscali.co.uk>
# From: franck1@wooow.it
# From: larrybrown@starspath.com
# From: "Mr. Kizie Mulumba" <kizie_mulumba@myway.com>
# From: "Mr. Kizie Mulumba" <kizie_mulumba@myway.com>
# From: "MR. PASCAL IBE" <pascalibe1@mail.nu>
# From: arapmoi.gideon@caramail.com
# From: "mariam abacha" <mariam_9999@atlas.cz>
# From: abacha80 <abacha80@voila.fr>
# From: MR TONY  OBA
# <DIV>From: MR TONY&nbsp; OBA<BR>REPLY MY MAIL THROUGH THIS EMAIL ADDRESS: <U><FONT color=#0000ff><A href="mailto:ike_oba1@yahoo.co.uk">ike_oba1@yahoo.co.uk</A></FONT></U><BR>Dear Sir/Madam, <BR>I am Mr Baldwin Gozie, Bank Manager of Diamond BANK , Lagos Branch. I have urgent and very confidential business proposition for you.I got your contact from the World Trade Center (W.T.C) regional office in Lagos,Nigeria although the details of my intention was not made known to them. On June 6 1997, an American oil consultant/contractor with the Nigerian National Petroleum Corporation, Mr. Barry Kelly made a numbered time (Fixed) deposited for twelve calendar months, valued at US$11,600,000.00 (Eleven Million,Six Hundred Thousand Dollars) in my branch. Upon maturity, I sent a routine notification to his forwarding address but got no reply. After a month, we sent a reminder and finally we discovered from his contract employers, Nigerian National Petroleum Corporation that Mr. Barry Ke!
# From: MR TONY  OBA
# <DIV>From: MR TONY&nbsp; OBA<BR>REPLY MY MAIL THROUGH THIS EMAIL ADDRESS: <U><FONT color=#0000ff><A href="mailto:ike_oba1@yahoo.co.uk">ike_oba1@yahoo.co.uk</A></FONT></U><BR>Dear Sir/Madam, <BR>I am Mr Baldwin Gozie, Bank Manager of Diamond BANK , Lagos Branch. I have urgent and very confidential business proposition for you.I got your contact from the World Trade Center (W.T.C) regional office in Lagos,Nigeria although the details of my intention was not made known to them. On June 6 1997, an American oil consultant/contractor with the Nigerian National Petroleum Corporation, Mr. Barry Kelly made a numbered time (Fixed) deposited for twelve calendar months, valued at US$11,600,000.00 (Eleven Million,Six Hundred Thousand Dollars) in my branch. Upon maturity, I sent a routine notification to his forwarding address but got no reply. After a month, we sent a reminder and finally we discovered from his contract employers, Nigerian National Petroleum Corporation that Mr. Barry Ke!
# From: solomon owen <wwwsolomon@mail.co.za>
# From: sekomariam2001 <sekomariam2001@telstra.com>
# From: MRBATESALANN@netscape.net
# From: BEL-ZULU SANI AHMED <belsa@acazamail.com>
# From: julliet03 <julliet03@voila.fr>
# From: MRBATESALAN@netscape.net
# From: "Kelly William" <kellywilliam@telstra.com>
# From: marzuba <marzuba@telstra.com>
# From: "pikka saaiman" <psaaiman2@mail.az>
# From: "Frank Shabalala" <mr_frank2020@hotmail.com>
# From: Mr John Obi.
# From: steve_kam11@yahoo.com
# From: sadmarah@sapo.pt
# From: sadmarah@sapo.pt
# From: "MOHAMMED ABACHA" <mohammed2@mail15.com>
# From: "DR.LUISA ESTRADA" <mrsluisaestrada1@emailaccount.com>
# From: "William Fufua" <williamfufua@yahoo.com>
# From: "FROM  DR.  HASSOUN   ODHIAMBO" <hassounodhiambo4@z6.com>
# From: "FROM  DR.  HASSOUN   ODHIAMBO" <hassounodhiambo4@z6.com>
# From: cromjohn@postino.it
# From: BALA MANCHA <balamancha@telstra.com>
# From: "MRS. LINDA CAMARA." <linda02@luxmail.com>
# From: "DR. MARCUS COLE" <freshcole@netscape.net>
# From: "FROM  DR.  HASSOUN   ODHIAMBO." <drhassounodhiambo@arabtop.net>
# From: semassaq@o2.pl
# From: "dr_frances" <dr_frances@libero.it>
# From: "dr_frances" <dr_frances@libero.it>
# From: johnkabilaa@rt.nl
# From: JOHN KABILA
# From: danjumansule <danjumansule@bigpond.com>
# From: danjumansule <danjumansule@bigpond.com>
# From: danjumansule <danjumansule@bigpond.com>
# From: "James Obulu" <jobulu1@torba.com>
# From: "James Obulu" <jobulu1@torba.com>
# From: "Oladimeji Afolabi" <afolabi_olu@hotvoice.com>
# From: dpatrick88 <dpatrick88@telstra.com>
# From: dpatrick88 <dpatrick88@telstra.com>
# From: dpatrick88 <dpatrick88@telstra.com>
# From: "Chamberlin Klugman" <chamberlin@drunkandstoned.com>
# From: kamasutu <kamasutu@telstra.com>
# From: "Dr,A. Almack." <dr_tta1@hotmail.com>
# From: "PRINCESS" <princessifeoma@702mail.co.za>
# From: nzani3 <nzani3@telstra.com>
# From: USMAN ISA <iusmanng2@telstra.com>
# From:  Barrister Isa Usman & Co.,
# From: "cyril8" <cyril8@telkom.net>
# From:Cyril Konan.
# From: "MATAMELA C. RAMAPHOSA" <cyrilmata1@zwallet.com>
# From: james001@postino.it
# From: The Desk of Ajibola James
# From: "Mercy Kume" <kumemercy@netzero.com>
# From: "Princess Ifeoma." <princess_ifeoma@excite.com>
# From: "Princess Ifeoma." <princess_ifeoma@excite.com>
# From: "Mr.Chan Fung." <chanfung123@indiatimes.com>
# From: "SAMSON K.MANI" <manifamily3@hotmail.com>
# From: James Nandu <jamesnandu11@mac.com>
# From: semassaq4@o2.pl
# From: semassaq4@o2.pl
# From: "DR. ABU HASSAN" <abu@go.com>
# From:DR.ABU  HASSAN
# From: memunamousa@zwallet.com
# From: memunamousa@zwallet.com
# From: Barrister Philip Ajayi
# From: "AHMED SANI" <mohdsule@fsmail.net>
# From: "p.mass" <p.mass@telstra.com>
# From: "Mr.Johnson Gube" <mrgube_john@hotmail.com>
# From: "monica martins" <monicamtf11@galmail.co.za>
# From: Mrs.Monica Martins
# From: mkhasan01<mkhasan01@tatanova.com>
# From: "john carlos" <johncarlos26@webmail.co.za>
# From: "PRINCESS" <princessifeoma@702mail.co.za>
# From: "Thomas Chilunda" <thomaschilundaa40@hotmail.com>
# From: "Mercy Kume" <mercykume121@netzero.com>
# From: semassaq4@o2.pl
# From: johncoro@o2.pl
# From: "Daniel  Mukaila" <daniel_m@123.com>
# From: "Daniel  Mukaila" <daniel_m@123.com>
# From: "Daniel  Mukaila" <daniel_m@123.com>
# From: "Mr.Kizie Mulumba" <kizie_mulumba2@humanux.com>
# From: barrister_dennkerry@telstra.com
# From: "mr   kala  kabila" <kkkabila2003@yahoo.com>
# From: royalmajesty <royalmajesty@telstra.com>
# From: johncoro@o2.pl
# From: "Dr.Tony Williams" <tony_williams77@hotmail.com>
# From: "BUNOR DICKINS" <bunor_dickins@yahoo.com>
# From: "Reverend Ngoly" <ngo@mail32.com>
# From: "hassanahmed" <hassanahmed@moldova.cc>
# From: "MRS. LINDA CAMARA." <linda02@luxmail.com>
# From: "Mr Bruno Williams" <brunowiliams04@voila.fr>
# From: "MR. PASCAL IBE" <pascal_ibe102@yahoo.co.in>
# From: "mohammed .s. abacha" <moabas1@netscape.net>
# From: "Okpara Addey" <addeyokpara@yahoo.co.uk>
# From: "Mr Stephen Bello" <stbello55th@yahoo.co.in>
# From: "MRS, FATIMA RASHEED KHALIFA" <Mrs_fatima@z6.com>
# From: semassaq@fastmail.fm
# From: "MR  COLINS  BROWN" <colins_brown@yehey.com>
# From: "john paul"<john_paul@email.cz>
# From: "john paul"<john_paul@email.cz>
# From: "Dr  Mrs  Estrada" <dr_mrs_estrada@homenetmail.com>
# From: "Dr  Mrs  Estrada" <dr_mrs_estrada@homenetmail.com>
# From: "Philip Dickson" <philipdickson35@hotmail.com>
# From: semassaq@netscape.net
# From: solomon_mudani8<solomon_mudani8@tatanova.com>
# From: semassaquoe23g@yehey.com
# From: semassaquoe23g@yehey.com
# From: ri_mboweni@telstra.com
# From: fmlucy112@netscape.net
# From: R@M
# From: monicayangani250@netscape.net
# From: "Mrs Juliana Faith Peters" <mrsjfp11@tiscali.co.uk>
# From: Mrs. Juliana Faith Peters
# From: "Mrs Juliana Faith Peters" <mrsjfp11@tiscali.co.uk>
# From: Mrs. Juliana Faith Peters
# From: "Bakura BJ Zamani" <bakurawae@fa.org>
# From: "Bakura BJ Zamani" <bakurawae@fa.org>
# From: "Mrs. Monica Kofi" <monicakofi@voila.fr>
# From: semassaq@mail.az
# From: "PRINCESS HASIHATU SESSEY COLA." <princesshasihatu@myway.com>
# From: seeem4@mail.az
# From: aminawazi@netscape.net
# From: "daniel kabila" <dankabila001@yehey.com>
# <P>To: President/Ceo<BR>From:Daniel Kabila<BR>Johannesburg,South Africa</P>
# From: "Mrs Fatima Rasheed Khalifa" <fatima_khalifa2004@Z6.com>
# From: ilist-owner@krusty.si.UM
#     From:    drallo_wd4@yahoo.com
# From: =?iso-8859-1?q?william=20drallo?= <drallo_wd4@yahoo.com>
# From: ilist-request@lists.si.UM
# From: "Dr Frank Obi" <frankobi@direccion.com>
# From: davidbongani@netscape.net
# From: solomon_mudani8<solomon_mudani8@tatanova.com>
# From: Rahim Sule <x9k5@yahoo.com>
# From: Dan Wilson <dan@danielm.org>
# From: Dan Wilson <dan@danielm.org>
# From:Dan Wilson
# From:Dan Wilson
# From: mohammed-abacha@whipmail.com
# From: "markduke2004" <markduke2004@libero.it>
# From: "Lawyer" <barristerpeter2@emaila.nu>
# From: michael_nwa1@iol.pt
# From: "SUSAN SHABANGU" <ss@yahoo.com>
# From: tsepovusi@netscape.net
# From: tsepovusi@netscape.net
# From: "SESAY MASSAQUOE" <semassaq3@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq3@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq3@o2.pl>
# From: massaq1@di-ve.com
# From: sitholebaloy@netscape.net
# From: "MR GEORGE AMACHREE" <georgeamachree_2@hotmail.com>
# From: "MR GEORGE AMACHREE" <georgeamachree_2@hotmail.com>
# From: "MR GEORGE AMACHREE" <georgeamachree_2@hotmail.com>
# From: willamsj@tiscali.co.uk
# From: davidnelson3010@tiscali.co.uk
# From: davis2010@tiscali.co.uk
# From: idumar55@di-ve.com
# From: idumar55@di-ve.com
# From: idumar55@di-ve.com
# From: "boyd ololo" <boydololo1@tiscali.co.uk>
# From: "susan shabangu" <shabang2susan@webmail.co.za>
# From: "hubert kliuvert" <cbforg_1@hotmail.com>
# From: "williams\.onwa" <williams.onwa@laposte.net>
# From: "Josef Bala" <josef_bala@x-sub.de>
# From: ndidi_uwoma@jumpy.it
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR, MIKE KOFI" <mikekofi@wowmail.com>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: massaq1@di-ve.com
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: williammabaye@netscape.net
# From: williammabaye@netscape.net
# From: williammabaye@netscape.net
# From: "JAMES STEIN" <steinjames1@netscape.net>
# From: "Alhaji Hamza Aliu." <shellpetrocoltd@sify.com>
# From: williammabaye@netscape.net
# From: "james nzama" <jamesnzama012@hotmail.com>
# From: "larry_ed1" <larry_ed1@libero.it>
# From: "james nzama" <jamesnzama012@hotmail.com>
# From: tonynjaba2@iol.pt
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: abmaryam <abmaryam@voila.fr>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: abmaryam <abmaryam@voila.fr>
# From: SAVIMBI <savimbi098@netscape.net>
# From: shadak_foundation12@tiscali.co.uk
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: rev_drosvaldopj@tiscali.co.uk
# From: jonathanbongani1@netscape.net
# From: jonathanbongani1@netscape.net
# From: jonathanbongani1@netscape.net
# From: "Balarabe Zamani" <balarabe_zamani@voila.fr>
# From: naybet@aeneasmail.com
# From: "DR,GAIUS OBASEKI" <dittrich2000@fastermail.com>
# From: "Martins Awele" <awele_martins@tiscali.co.uk>
# From: michealmumbaza@jumpy.it
# From: lee_tsong@tiscali.it
# From: "Mercy Kume" <mckume@yahoo.com>
# From: "Mohammed Abacha" <mohammed_abacha2004@indiatimes.com>
# From: "Mohammed Abacha" <mohammed_abacha2004@indiatimes.com>
# From: "Mohammed Abacha" <mohammed_abacha2004@indiatimes.com>
# From: bg-misc-owner@cs.CU
# From: mohammed abacha <moha@dixinet.com>
# From: contactiyang@postino.it
# From: "MRS. MARIAM ABACHA" <abachafamily20052005@yahoo.com>
# From: "Mr.Stephen Koseff" <koseft@katamail.com>
# From: Abel Guobadia <ab@merakdemo.com>
# From: "Rev Mark Bome" <bomefoundation2@voila.fr>
# From: "Abu M.Sesay" <abuabu3@pro.hu>
# From: "Abu M.Sesay" <abuabu3@pro.hu>
# From: DR RANI JUMA <dr.rani.ali.2001@caramail.com>
# From: "MR. JOHN PETERS" <mr_john_peters@telstra.com>
# From: "MR. JOHN PETERS" <mr_john_peters@telstra.com>
# From: "bongo wale" <bongowale2002@hotmail.com>
# From: DR RANI JUMA <dr.rani.ali.2001@caramail.com>
# From: claudiamafikeng@caltanet.it
# From: aminawazi@netscape.net
# From: aminawazi@netscape.net
# From: "Dr.Benard Mcarthy" <banking17@tiscali.co.uk>
# From: "Barr. Chris Edu" <edu2@fuorissimo.com>
# From: "Mr Chris Ogiemwonyi." <chri@mail.com>
# From: charityattention@netscape.net
# From: charityattention@netscape.net
# From: charityattention@netscape.net
# From: "Barr. Chris Edu" <ed@fuorissimo.com>
# From: "Barr. Chris Edu" <ed@fuorissimo.com>
# From: "MR JOHN DICKSON" <jon_dic101@quick.cz>
# From: "Dr (Mrs) BETTY PEDRO" <betty_pedro01@jumpy.it>
# From:Dan Wilson
# From:Dan Wilson
# From: "james obi" <jamesobi1@classicmail.co.za>
# From: "james obi" <jamesobi@classicmail.co.za>
# Resent-From: all-atl@eecs.UM
# From: "Dr Mrs Mariam Abacha" <mariamabacha@yahoo.com>
# From: "james obi" <jamesobi1@classicmail.co.za>
# From: "james obi" <jamesobi1@classicmail.co.za>
# From: "MRS. PATRIKA KOVAC" <errtty@hotmail.com>
# From: "MRS. PATRIKA KOVAC" <errtty@hotmail.com>
# From: "Shadak Shari" <shadak_shari5@albawaba.com>
# From: "Shadak Shari" <shadak_shari6@albawaba.com>
# From: "Shadak Shari" <shadak_shari@albawaba.com>
# From: "ROBERT MAJUS" <robe878@tiscali.it>
# From: "Engr. Ukot Thomas Ukot" <thomas_ukot1@rediffmail.com>
# From: "MRS. PATRIKA KOVAC" <ertrttyt@hotmail.com>
# From: "DR. HARRY OBUM" <harryobum@sudanmail.net>
# From: "Mr. Dicka Dumas" <dicka@galmail.co.za>
# From: "Mr. Dicka Dumas" <dicka@galmail.co.za>
# From: "DR. EKIYOH MARTINS" <ekiyohmartins@netscape.net>
# From: "Mr.Harry Hakeem" <harryhakeem1956@netscape.net>
# From: princefwbolkiah2000 <princefwbolkiah2000@yahoo.com>
# From: "John Mikado" <mjohn004@netscape.net>
# From: "John Mikado" <mjohn004@netscape.net>
# From: "MRS MAVIS KAKI" <johnkakiz@netscape.net>
# From: "MRS MAVIS KAKI" <johnkakiz@netscape.net>
# From: "Mr Frank" <frank13_@mailsurf.com>
# From: "info@crack-ag.com" <info@crack-ag.com>
# From: jamestshabalala@netscape.net
# From: jamestshabalala@netscape.net
# From: jamestshabalala@netscape.net
# From: "SAMSON K.MANI" <samson_k_mani01@voila.fr>
# From: "Mr frank" <frank13_@mailsurf.com>
# From: "oliver"<oliverfpaul@aib.com>
# From: "oliver"<oliverfpaul@aib.com>
# From: "Terry" <gimlabpnuipfi@rocketmail.com>
# From: sitholebaloy@netscape.net
# From: sitholebaloy@netscape.net
# Old-X-Envelope-From: sitholebaloy@netscape.net
# From: sitholebaloy@netscape.net
# From: "yaya" <dr_tyh@hotmail.com>
# From: "yaya" <dr_tyh@hotmail.com>
# From: "sessay massaquoe" <sessay1_7o2.pl@seeqmail.com>
# From: "sessay massaquoe" <sessay1_7o2.pl@seeqmail.com>
# From: "sessay massaquoe" <sessay1_7o2.pl@seeqmail.com>
# From: "Paul Jacksoncole." <mrp_jack@bankersmail.com>
# From: "BAR.MYKE UTAKI" <attorneymyke@justice.com>
# From: xiao gang <xg2004@ofir.dk>
# From: "Tony" <zlblzm@sohu.com>
# From: "Tony" <zlblzm@sohu.com>
# From: "Dr. mustafa mohammed" <mohammed_mustafa@voila.fr>
# From: "Dr. muystafa mohammed" <mohammed_mustafa@voila.fr>
# From: sunlolly@caltanet.it
# From: harryhakeem1956@netscape.net
# From: "FROM ME PLEASE REPLY" <rita20000@quick.cz>
# From: "MR BEKO EZE" <bek@macmail.com>
# From: "Charles Taylor" <charlestayloraap@iqsecure.com>
# From: mr john paul <john_paul@email.cz>
# From: "Kumalo Debe" <kumalodebe1@netscape.net>
# From: "oliver"<aiboliv@aib.com>
# From: "oliver"<aiboliv@aib.com>
# From: harryhakeem988@netscape.net
# From: harryhakeem988@netscape.net
# From: "MOHAMED  ZUBA" <muhab_zuba@ourwest.com>
# From: "chris" <chris_nwoke100@amnetsal.com>
# From: alfreddouglas2@virgilio.it
# From: "Lt. Col. Richard Egwu" <egwu_17@yahoo.co.uk>
# From: "Lt. Col. Richard Egwu" <egwu_17@yahoo.co.uk>
# From: "Lt. Col. Richard Egwu" <egwu_17@yahoo.co.uk>
# From: "Mattew Molefe" <mattewmolefe6@yehey.com>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "BIKO ZULATO" <bikozulato@yahoo.co.uk>
# ...
# Subject: From: Edward Moore & Associates(Urgent)
# From: "Edward Moore & Associates" <edward_moore22@yahoo.co.uk>
# From: Robert Williams <robertwills@pre.sltnet.lk>
# From: adnanhram@aim.com
# From: Michael Jones <michjones@mickyjones.co.uk>
# From: Koutaba jean <koutab0078@hotmail.com>
# From: Phillip Croce <bullfrog812@charter.net>
# From: asinthe nignan <asinthe_nignan33@hotmail.fr>
# From: Robert Williams <robertwills@pre.sltnet.lk>
# From: emekaben@aol.co.uk
# From: "Edward Moore & Associates" <edwardmoore99@yahoo.co.uk>
# From: "Mr. Gamudi Mboma" <gmboma2@hotmail.com>
# From: mrcolinshand20 <mrcolinshand20@poczta.pf.pl>
# From: richard bongo <richard_bongo112za@hotmail.com>
# From: richard bongo <richard_bongo112za@hotmail.com>
# From: Koutaba jean <koutab0025@hotmail.com>
# From: DR AHMED SHALAA <drahmed_sh14@hotmail.com>
# From: COLLINS LYONS <collins_lyons73@yahoo.co.uk>
# From: "Mr.Jonathan Mutambara" <rahim.attah1@virgilio.it>
# From: Mr.Jonathan Mutambara.
# From: "FREDERICK WILLIAMS." <fred_williams05@o2.pl>
# From: amir jasmin <amija_1035@hotmail.com>
# From: "Mahmud Azzam" <mamud_islandoil@yahoo.com.hk>
# From: "Mahmud Azzam" <mamud_islandoil@yahoo.com.hk>
# From: CHRIS ANDERSON <chris_anderson@universia.com.br>
# From: ben coroma <bencoroma12@hotmail.com>
# From: "MRS. LARISA SOSNITSKAYA" <larisasosnkayapawou@mail2russia.com>
# =0D=0A=0D=0AFrom:Mr.Kenneth Mashaba=0D=0AEmail:kmashaba@myway.com=0D=0ATel:=
# From: MR WILLIAM KABILA <williamkabila05@gmail.com>
# From: LIKA CHEUNG HOLDINGS LIMITED <joemelosi@charter.net>
# From: "MRS. LARISA SOSNITSKAYA" <larisasosnkayanxly@mail2russia.com>
# From: " MR james roberts" <james_roberts007@navegante.com.sv>
#   h=Message-ID:X-YMail-OSG:Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding;
# From: "Dr. Paul A. Sule" <drpaulsule1950@o2.pl>
# From: john alison <johnali20@hotmail.com>
# From: "alimoheamed1" <alimoheamed1@mynet.com>
# From: "Mr. Joseph Chau." <info_unionbankofchain007@adelphia.net>
# From: Mr Paul Baloyi <patrickokonta10@virgilio.it>
# Subject: From: Mr. Paul Baloyi.
# From: Mr. Paul Baloyi.
# From: Mr Paul Baloyi <patrickokonta10@virgilio.it>
# Subject: From: Mr. Paul Baloyi.
# From: Mr. Paul Baloyi.
#   h=X-YMail-OSG:Received:Date:From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: nabjib ibrahim <nabjib_n27@hotmail.fr>
# From: nabjib ibrahim <nabjib_n27@hotmail.fr>
# From: "Mr. Albert Sitholi" <sitholi@webmail.co.za>
# From: fredrick thambo <fredrick.thambo.107@hotmail.com>
# From: Barrister Fredrick Thambo=20
# <DIV class=3DEC_EC_RTE><STRONG>From: Barrister Fredrick Thambo </STRONG></D=
# From: musa saladin <musa_saladin030@hotmail.com>
# From: "PETER NDABA" <peterndaba@fsmail.net>
# From: kouajo@hotmail.fr
# From: "DR DAVID RAY" <david_ray202@yahoo.co.uk>
# X-EStarr-MailScanner-From: david_ray202@yahoo.co.uk
# From: JOHN ABOH <meetic@meetic.com>
# From: "Mikhail Khodorkovsky" <mikhail@yukosoil.com>
# From: koajoo_aka@yahoo.com
# From: theresa coleman <mrst5heresa@hotmail.fr>
#   h=Message-ID:Received:X-RocketDSI:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type;
# From: JOSEPH hOPONU <hoponuj101@yahoo.co.jp>
# From: "A.B. Solarin" <alexandro_solarin1973@yahoo.co.uk>
# From: "Martins Mazuri" <mart_mazuri03@yahoo.ca>
# From: "Mr. Peter Leon" <mr66leon@hotmail.com>
# From: chantal kouakou <kouakou_chantou15@hotmail.fr>
# From: chantal kouakou <kouakou_chantou15@hotmail.fr>
# From: sahidi ngoma <sahidi_ngoma14@hotmail.fr>
# From: Capt James C Willians <officialmail@realmail.co.uk>
# From: "IRS"<refund@irs.gov>
#   h=Received:Date:From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
#   h=X-YMail-OSG:Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "MR. MARK ADAMS" <m_adams1102@walla.com>
# From: "MR. MARK ADAMS" <m_adams1102@walla.com>
# From: "bala kabore" <bala_kabore48@hotmail.fr>
# From: "DR.IDRISSA SEKK" <d_dudu@virgilio.it>
#   h=X-YMail-OSG:Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: gerald zongo <geraldzongo_38@hotmail.fr>
# From: chantal kouakou <chant004@hotmail.fr>
# From: princess gesinta <princess_gesinta016@hotmail.fr>
# From: MR JAMES ROBERTS <williambrown@virgilio.it>
# From: Tim McCarron <pre91@pre.sltnet.lk>
# From: "Chief Anthony Enahoro. JP" <coalition_protect@yahoo.fr>
# From: "Richard Akintunde"<r.akintunde@yahoo.it>
# From: "Martins Akim" <martinsakim@handbag.com>
# From: "Dr. Ahmed Hassan" <ahassan1696@gmail.com>
# From: "Dr. Ahmed Hassan" <ahassan1696@gmail.com>
# From: "LUISA ESTRADA" <luisa@blue-conn.de>
# Subject: From:Evangelist Lindy Mike(Widow).
# From: "Evangelist Lindy Mike (Widow)." <evlindymike@myway.com>
# From:Evangelist Lindy Mike(Widow).
#   h=X-YMail-OSG:Received:Date:From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# Subject: From: Edward Moore & Associates
# From: "Edward Moore & Associates" <edward.moore20@yahoo.com>
# Subject: From: Edward Moore & Associates
# From: "Edward Moore & Associates" <edward.moore99@yahoo.co.uk>
# From: "bjsri budak" <bjsri072@hotmail.com>
# From: Barrister Al Mohammed El Said <benmowilliamss@lawyer.com>
# From: Gary William <stella.sigcau4@virgilio.it>
#   h=X-YMail-OSG:Received:Date:From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "Mr. Robin Shephard" <fredmaxwell@virgilio.it>
# From: "Martin J. Waghorn" <leonardmuller@virgilio.it>
# From:Mr. Martin J. Waghorn
# From: "Didan Kimati" <kimati_didan@excite.com>
# From: MR LAAD cologo <mrlaad_cologo13@hotmail.fr>
# From: Mr LAAD COLOGOManager,Audit/Account SectionAfrican Development BankOuagadougou Burkina-Faso    Dear FRIEND,   How are you today? Hope all is well. Please be informed that I have decided to contact you for a fund transfer transaction worth the sum of US$22,300,000.00 into your reliable bank account as the sole NEXT-OF-KIN to the foreign deceased customer of our bank (an International Billionaire French Businessman) who was killed with his entire family by PLANE-CRASH in Central England atmost 3 years ago. Since his death occured, no body have show up as his next of kin for the claim because the account is untraceable. Upon the investigation I carried out from his records, I found out that his foreign business consultant who would have trace the account died earlier before the deceased. Therefore, this is a confidential and sealed deal. For the success of this transaction, you should apply and act as the only existing NEXT-OF-KIN to the deceased which our bank will replace the deceased account information through proper documentation in position of your own account. This transaction is risk-free, it will never harm your good reputation in your society because no one can trace the account, and on the instant of the transfer of the fund into your account, the chapter of this transaction will be closed entirely. Note that in a business of this nature, the bank dont want to know your difference between the deceased country, religion or believe because our bank inheritance law is against that. So, it is a preference for us achieve this success without any problem.Please note down that once the fund get transferred into your account, you will take 39% of the total sum while the rest will be for me as I will arrange myself down to your country to take my share. I need your urgent response and include your private telephone/mobile numbers for easy communication.Please reply if you can be trusted in this deal.Thanks,  Mr.LAAD COLOGO.
# <STRONG>From: Mr LAAD COLOGO<BR>Manager,Audit/Account Section<BR>African Development Bank<BR></STRONG><SPAN id=EC_lw_1184178655_0 style="BACKGROUND: none transparent scroll repeat 0% 0%; CURSOR: hand; BORDER-BOTTOM: #0066cc 1px dashed; HEIGHT: 1em"><STRONG>Ouagadougou Burkina-Faso</STRONG></SPAN><BR><STRONG>&nbsp;&nbsp;&nbsp; <BR>Dear FRIEND,&nbsp; <BR>&nbsp;<BR>How are you today? Hope all is well. Please be informed that I have decided to contact you for a fund transfer transaction worth the sum of US$22,300,000.00 into your reliable bank account as the sole NEXT-OF-KIN to the foreign deceased customer of our bank (an International Billionaire French Businessman) who was killed with his entire family by PLANE-CRASH in Central England atmost 3 years ago. Since his death occured, no body have show up as his next of kin for the claim because the account is untraceable. Upon the investigation I carried out from his records, I found out that his foreign business consultant who would have trace the account died earlier before the deceased. Therefore, this is a confidential and sealed deal.<BR>&nbsp;<BR>For the success of this transaction, you should apply and act as the only existing NEXT-OF-KIN to the deceased which our bank will replace the deceased account information through proper documentation in position of your own account. This transaction is risk-free, it will never harm your good reputation in your society because no one can trace the account, and on the instant of the transfer of the fund into your account, the chapter of this transaction will be closed entirely.<BR>&nbsp;<BR>Note that in a business of this nature, the bank dont want to know your difference between the deceased country, religion or believe because our bank inheritance law is against that. So, it is a preference for us achieve this success without any problem.<BR>Please note down that once the fund get transferred into your account, you will take 39% of the total sum while the rest will be for me as I will arrange myself down to your count
# From: harryugo@zipmail.com.br
# From: mike kone <mikkon5@hotmail.fr>
# From: "Dave Yorke." <dyorke@freenet.de>
# From: "Mrs  Farah Al-hashemi" <msalhak@yahoo.com>
# From: "Mrs  Farah Al-hashemi" <msalhak@yahoo.com>
# From: Eric Johnson <ericjohnson6@myway.com>
# From: sahidi ngoma <sahidi_ngoma13@hotmail.fr>
# From: mike kone <mikeko018@hotmail.fr>
# From: tony anthony <tonywach4@hotmail.com>
# From: PROF CHARLES SOLUDO <mrsbakare@rediffmail.com>
# From: urgentmatter@sunumail.sn
# X-SA-Exim-Mail-From: urgentmatter@sunumail.sn
#   h=Message-ID:Received:Date:From:Subject:To:MIME-Version:Content-Type;
# From: "REV.WILSON MORGAN" <inheritance_fund00@o2.pl>
# From: "REV.WILSON MORGAN" <inheritance_fund00@o2.pl>
# From: janetbradford@sunumail.sn
# X-SA-Exim-Mail-From: janetbradford@sunumail.sn
# From: Gary William <stella.sigcau4@virgilio.it>
# From: "Mr Aphisak Tantiworawong" <aphisak.project@yahoo.co.th>
# From: J_KEMPWELCH01 <jkemp1968@yahoo.co.uk>
#   h=Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
#   h=Received:Date:From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "Mr.Morgan Wimpoe" <morgan.wimpoe01@yahoo.com>
# From: <alima_kkk10@centrum.cz>
# From: "Adekunle michael." <dmike0013@o2.pl>
# From: QIN LI WANG <buddycrk@fuse.net>
# From: idris makafi <idris_makafi167@hotmail.fr>
#   h=Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
#   h=Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "DR. CLEMENT ASUZU" <clementasuzu@yahoo.it>
# From: emma tano <ball16@hotmail.fr>
# From: "Bank of America" <Banking@Bankofamerica.com>
# From: Mou Xinsheng <spiritsanct@onetel.com>
# From: "Prof.Charles.C.Soludo" <cbnpayment.org@host45.porar.com>
# From: matinread@turbonett.com
# From: "jen_marthin" <jen_marthin@centrum.sk>
#   h=Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
#   h=Received:Date:From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "aziz moustafa" <aziz_moustafa100@hotmail.com>
# From: MM BB <mbd095@hotmail.com>
# From: "Mrs Farah al-Hashemi" <mrsfarah30@yahoo.co.uk>
# Subject: From:Mrs Farah al-Hashemi :I will appreciate your reply
# From: kanazoe alidaa <kanazoe_alidaa0007@hotmail.fr>
# From: williams susan <wil_li_net0064@hotmail.fr>
# From: "bajoga bajoga" <bajoga@latinmail.com>
# From: "Robert Zulugan." <rubzuul@freenet.de>
# From: "Mrs. Farah al-Hashemi" <mrsfarah30@yahoo.co.uk>
# Subject: From:Mrs Farah al-Hashemi :I will appreciate your reply
# From: Jaron Abbas <jaron_abbass@yahoo.de>
# From: Jaron Abbas <jaron_abbass@yahoo.de>
# From: adams swill <adams5swill@hotmail.com>
# From: susan  john <susan_john203@yahoo.co.uk>
# From: "GOBLOUSO SOLANGE " <gosolanges@latinmail.com>
# From: Prince David Djedjess <djedjess007@hotmail.com>
# From: adams kabora <adams_kabora11@hotmail.com>
# From: adams kabora <adams_kabora31@hotmail.com>
# From: "Christopher  Wilson" <christopherwilson@sunumail.sn>
# X-SA-Exim-Mail-From: christopherwilson@sunumail.sn
#   h=Message-ID:Received:Date:From:Subject:To:MIME-Version:Content-Type;
# From:Sarat Hassan
# From:Sarat Hassan<BR>
# From: <chantalveroniq2@yahoo.fr>
# From: JOHN HILL <johnhill87@aol.fr>
# From: CAROL HARVEY <esoil_gasltd231@yahoo.com.hk>
#   h=Message-ID:Received:Date:From:Subject:To:MIME-Version:Content-Type;
# From: isedore lawan <mr_isedore_lawan0053@hotmail.fr>
#   h=X-YMail-OSG:Received:Date:From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "Mr A.B Solarino" <benjaminosolarin4u@yahoo.co.uk>
# From: HARRISON FELISSA <felissajen115@hotmail.fr>
# From: MR NELSON BROWN <mrscarolyn@virgilio.it>
# From: "Sunoco Sun Oil Company Ltd" <onlineli@phreego.com>
# From: "Sunoco Sun Oil Company Ltd" <onlineli@phreego.com>
# From: joel thomson <joelthomson804@hotmail.com>
# From: HANG SENG BANK <peter@hangsengbank.com.hk>
#   h=Message-ID:Received:Date:From:Subject:To:MIME-Version:Content-Type;
# Subject: From:Miss Grace Onuoha
#   From:Miss Grace Onuoha
#  <DIV>From:Miss Grace Onuoha </DIV>  <DIV>&nbsp;</DIV>  <DIV>In brief introduction, I am Miss Grace Onuoha from the republic of South Afirca , I am 22 years old I have two younger ones, John and Linda Onuoha, we have lost our Father and Mother. My late Father Mr. Mustapha Onuoha before his death
# From: "Steven Lee"<stevnlee010@sify.com>
# From: <ch_20007@centrum.cz>
#   h=X-YMail-OSG:Received:Date:From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: LIUYANMAILPOST <liuyan_office@yahoo.com.hk>
# From: "MR. KENNETH MASHABA" <kmashaba1@myway.com>
# From:Mr.Kenneth Mashaba
# From: "The SHIGA BANK LTD" <ooxxee.ooxxeee03@laposte.net>
# From: "Louis (Business).." <femirhodes@virgilio.it>
# From: "The SHIGA BANK LTD" <ooxxee.ooxxeee03@laposte.net>
# From: "MRS. ANNAH KRUGA" <a_annah50@hotmail.com>
# From: nafmohd101@yahoo.fr
# From: "julia.chen.shenhua.group@hotmail.com" <ooxxee.ooxxeee03@laposte.net>
# From: nelson mansuguri <mansuguri63@hotmail.com>
# From: kali oddo <kali_oddo017@hotmail.fr>
# From: "james bongani" <jamesbongani10015@latinmail.com>
# From: us zongo <us_zongo35@hotmail.fr>
# From: Mr Usman Zongo African Development Bank (ADB)Ouagadougou , Burkina Fa=
# From:&nbsp;Mr Usman Zongo&nbsp;<BR>African Development Bank (ADB)<BR>Ouagad=
# From: Vincent Cheung <gladvince01@yahoo.co.uk>
# From: "BARR.JONATHAN WRIGHT" <wrightchember@gmail.com>
# From: petertaylor <petertayloruk2@yahoo.de>
# From: Jaron Abbas <jaron_abbass@yahoo.de>
# From: patrick jombo <mrjombo23@hotmail.fr>
# From: abl musa <ablmusa_03@hotmail.fr>
# From: "Dr. David Smith" <dickson_robert1@virgilio.it>
# From: IDRIS ADAMU <idris40adamu@hotmail.fr>
# From: KENNETH OBI <kennethobia5@hotmail.com>
# From: "HENRY ALLEN" <henryallenci@seznam.cz>
# From: Mr John Davids <mobeef@birch.net>
# From: Khaled Bin al- Walid <mobeef@birch.net>
# From: Mother Doris Killam <motherdorisk93@hotmail.com>
# From: "Fernando Gonzalez" <best.list@laposte.net>
# From: "From: Dr. Jackson Gaius-Obaseki" <tony_eselu2@virgilio.it>
# Subject: From: Dr. Jackson Gaius-Obaseki
# From: michealagu0255@zipmail.com.br
# From: ali sherif <ali_sherif252@hotmail.fr>
# From: Mr Ali Sherif. African Development Bank (ADB)Ouagadougou , Burkina Fa=
# <DIV>From: Mr Ali Sherif. <BR>African Development Bank (ADB)<BR>Ouagadougou=
# From: Dr Usman Ibrahim Danko <drusmanibrahimtg08@hotmail.fr>
# From: Mother Doris Killam <motherdorisk61@hotmail.com>

# %% [markdown]
# But that’s not giving us exactly what we want. If you take a look at our test file, we could figure out why and fix it, but instead, let’s use Python’s re module and do it with regular expressions!
#
# We’ll start by importing Python’s re module. Then, we’ll use a function called re.findall() that returns a list of all instances of a pattern we define in the string we’re looking at.

# %%
import re

for line in re.findall("From:.*", fh):
    print(line)

# %% [markdown]
# his is essentially the same length as our raw Python, but that’s because it’s a very simple example. The more you’re trying to do, the more effort Python regex is likely to save you.
#
# Before we move on, let’s take a closer look at re.findall(). This function takes two arguments in the form of re.findall(pattern, string). Here, pattern represents the substring we want to find, and string represents the main string we want to find it in. The main string can consist of multiple lines. In this case, we’re having it search through all of fh, the file with our selected emails.
#
# The .* is a shorthand for a string pattern.

# %% [markdown]
# Common Python Regex Patterns
# The pattern we used with re.findall() above contains a fully spelled-out out string, "From:". This is useful when we know precisely what we’re looking for, right down to the actual letters and whether or not they’re upper or lower case. If we don’t know the exact format of the strings we want, we’d be lost. Fortunately, regex has basic patterns that account for this scenario. Let’s look at the ones we use in this tutorial:
#
# w matches alphanumeric characters, which means a-z, A-Z, and 0-9. It also matches the underscore, _, and the dash, -.
#
# d matches digits, which means 0-9.
#
# s matches whitespace characters, which include the tab, new line, carriage return, and space characters.
#
# S matches non-whitespace characters.
#
# . matches any character except the new line character n.
#
# With these regex patterns in hand, you’ll quickly understand our code above as we go on to explain it.

# %%
#We can now explain the use of .* in the line re.findall("From:.*", text) above. Let’s look at . first:
for line in re.findall("From:.", fh):
    print(line)

# %% [markdown]
# By adding a . next to From:, we look for one additional character next to it. Because . looks for any character except n, it captures the space character, which we cannot see. We can try more dots to verify this.

# %%
for line in re.findall("From:...........", fh):
    print(line)

# %% [markdown]
# It looks like adding dots does acquire the rest of the line for us. But, it’s tedious and we don’t know how many dots to add. This is where the asterisk symbol, *, comes in.
#
# * matches zero or more instances of a pattern on its left. This means it looks for repeating patterns. When we look for repeating patterns, we say that our search is “greedy.” If we don’t look for repeating patterns, we can call our search “non-greedy” or “lazy.”

# %%
for line in re.findall("From:.*", fh):
    print(line)
# Out:
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>
# From: "Mr. Ben Suleman" <bensul2004nng@spinfinder.com>
# From: "PRINCE OBONG ELEME" <obong_715@epatra.com>
# From: "PRINCE OBONG ELEME" <obong_715@epatra.com>
# From: "Maryam Abacha" <m_abacha03@www.com>
# From: Kuta David <davidkuta@postmark.net>
# From: "Barrister tunde dosumu" <tunde_dosumu@lycos.com>
# From: "William Drallo" <william2244drallo@maktoob.com>
# From: "MR USMAN ABDUL" <abdul_817@rediffmail.com>
# From: "Tunde  Dosumu" <barrister_td@lycos.com>
# From: MR TEMI JOHNSON <temijohnson2@rediffmail.com>
# From: "Dr.Sam jordan" <sjordan@diplomats.com>
# From: p_brown2@lawyer.com
# From: Barrister Peter Brown
# From: mic_k1@post.com
# From: "COL. MICHAEL BUNDU" <mikebunduu1@rediffmail.com>
# From: "MRS MARIAM ABACHA" <elixwilliam@usa.com>
# From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>
# From: " DR. ANAYO AWKA " <anayoawka@hotmail.com>
# From: "Victor Aloma" <victorloma@netscape.net>
# From: "Victor Aloma" <victorloma@netscape.net>
# From: "JAMES NGOLA" <james_ngola2002@maktoob.com>
# From: "MARTIN CHIME" <martinchime@usa.com>
# From: "Mr George Mboro" <mboro1555@post.com>
# From: "MARTIN  CHIME" <martinchime@borad.com>
# From: "MARTIN  CHIME" <martinchime@borad.com>
# From: <edema_mb@phantomemail.com>
# From: <edema_mb@phantomemail.com>
# From: "ADE WILLIAMS" <adewilliams_ade@lawyer.com>
# From: smithkam2@post.com
# From: "MRS. M SESE-SEKO" <sesm@omaninfo.com>
# From: "obina okoro" <obinaokoro@37.com>
# From: "DR. JAMES  ALBERT" <jamesalbert0@eircom.net>
# From: software-seminar@eecs.UM
# From: adamuohiroma adamuohiroma <adamuohiroma.adamuohiroma@caramail.com>
# From: "MR FRED OBI." <fredobi3@omaninfo.com>
# From: "mbeki ngumeni" <mbengu@37.com>
# From: mahoyi mamudu <mmahoyi@caramail.com>
# From: "Mr. David Agu" <adgua@mail.com>
# From: "bell.idr bell.idr" <bbell.idr@caramail.com>
# From: "idris.bello idris.bello" <iidris.bello@caramail.com>
# From: john2002@bluemail.ch
# From: "CLEMENT APUTE" <clem-apute@consultant.com>
# From: "MR GODWIN IGBUNU" <g.godwin12345@caramail.com>
# From: "bell.idr bell.idr" <bbell.idr@caramail.com>
# From: "Mr. David Agu" <dav84@mail.com>
# From: "deborah kabila" <kabila72b@37.com>
# From: Khalifa Sese <kss07@go.com>
# From: Khalifa Sese <kss07@go.com>
# From: "MOHAMMED BELLO (Ph.D)" <mohammed_bello_1@yahoo.com>
# From: "PETER WILLIAMS" <cooooofoooooooo@rediffmail.com>
# From: "Oliveira Savimbi" <olivsav@netscape.net>
# From: "Mr. Daniel Osondu" <tdannosondu@mail.com>
# From: Mr.Daniel Osondu
# From: <williamsdaniel1@phantomemail.com>
# From: "Ruka" <rulagg@excite.com>
# From: "IDRIS ADAMU" <idris2003942@aol.com>
# From: "DR.  SANNI  SABO" <davidmensoh@mail.com>
# From: "DR.  SANNI  SABO" <davidmensoh@mail.com>
# From: "Ibrahim Galadima" <ig_esq@rediffmail.com>
# From: ademola1950@hknetmail.com
# From: "Mohammed Abacha" <a_mabachas@yahoo.co.uk>
# From: "PRINCE TUNDE O ADISARAKI" <princeadisaraki5@usa.com>
# From: "judeestrada" <judeestrada2@dmailman.com>
# From: "JONATHAN  MOKOENA" <davidmensoh@mail.com>
# From: olu@mailservice.ms
# From: "res bob12" <resbobi2@al-islam.com>
# From: "LADY MARYAM ABACHA " <mariam.abacha58@boredmail.com>
# From: "MR.TUNDE  BALOGUN" <tundebalogun@omaninfo.com>
# From: "MR.BENSON  ATTAH" <mrbenson_attah@omaninfo.com>
# From: "MR.BENSON  ATTAH" <mrbenson_attah@omaninfo.com>
# From: "MR.TUNDE  BALOGUN" <tundebalogun@omaninfo.com>
# From: "LADY MARYAM ABACHA " <mariam.abacha57@boredmail.com>
# From: "DR.  SANNI  SABO" <davidmensoh@mail.com>
# From: "Dr Luisa Pimental Estrada" <luisaestrada2002@luisapestrada.zzn.com>
# From: "Graham Douglas" <douglas.graham@caramail.com>
# From: luis oboh <oluis2@caramail.com>
# From: luis oboh <oluis2@caramail.com>
# From:Savimbi Denis
# From: "savimbidenis@www.com" <savimbidenis@www.com>
# From: "Nsekou Mobutu Sesekou" <sekou_family@mailsurf.com>
# From: "DR. BELLO MUSA" <dr_bellomusa01@omaninfo.com>
# From: Frank Williams <frankwilliams2@starmedia.com>
# From: Mr. Frank Williams.
# From: "=?iso-8859-1?Q?lawrence.smith?=" <lawrence.smith@voila.fr>
# From: "DONALD  ATTAH" <donaldattah@netzero.com>
# From: "daniel innocent" <daninno555@37.com>
# From: "deborah kabila" <kabila72i@37.com>
# From: "peter" <peter_savimbi20@phantomemail.com>
# From: "joseph benson" <josephbenson@weedmail.com>
# From: mr_bb@hknetmail.com
# From: "pat odogu" <pat11@weedmail.com>
# From: felix lamine <felix.lamine@caramail.com>
# From: "PATRICK  MOHAMMED" <patrickmohammed@omaninfo.com>
# From: "PATRICK  MOHAMMED" <patrickmohammed@omaninfo.com>
# From: "Mr. Lawrence Abba" <lawrenceabba@operamail.com>
# From: bill_james4@bluemail.ch
# From: Mr Benard Gelicah Sankoh.
# From: "MALCOM TUTU" <macontu05@yahoo.com>
# From: Mr. MALCOM TUTU  (chief auditor)
# From: "MALCOM TUTU" <macontu05@yahoo.com>
# From: Mr. MALCOM TUTU  (chief auditor)
# From: stevens bangura <stevens.bangura@caramail.com>
# From: "MR. DONALD ATTAH" <donaldattah@omaninfo.com>
# From: "Dr mariam abacha" <marabac011@hotmail.com>
# From: Frank Ikpendu <frankikpendu3@mail.co.za>
# From: "jeffery hill" <jeffery_hill10007@hotmail.com>
# From: "malcom tutu" <macontu028@yahoo.com>
# From: "malcom tutu" <macontu028@yahoo.com>
# From: "sam aluko" <samaluko1@37.com>
# From: "GEORGE  KABILA" <ggeorgekabyl@caramail.com>
# From: "CYRIL AKWARANDU" <madu_invest@yahoo.com>
# From: "CYRIL AKWARANDU" <madu_invest@yahoo.com>
# From: "MR.YARO BAMIYI" <doomer@themail.com>
# From: "barr.femi" <barr.femi@caramail.com>
# From: "DR DOUGLAS NWANKWO" <douglankwo@yahoo.com>
# From: "Mrs. Safi  Al Mustapha" <leathercity1@irangate.net>
# From: "Mrs. Safi  Al Mustapha" <leathercity1@irangate.net>
# From: "Dr Mariam abacha" <mariam.aba@caramail.com>
# From: "Dr.Moses" <moses1970@englishexpert.com>
# From: "Dr.Moses" <moses1970@englishexpert.com>
# From: "DR. OLUSEGUN SMITH" <olu002@phantomemail.com>
# From: "Dr. Bernard Makelele" <benkelele@phantomemail.com>
# From: chiedo_jonathan2@netzero.com
# From: "kaseke kenneth" <kasekek@email.com>
# From: willbanigo003@juntos.com
# From: "DR ABDULL RASAQ" <drabdullrasaq@phantomemail.com>
# From: "DR ABDULL RASAQ" <drabdullrasaq@phantomemail.com>
# From: "williame ume" <kkalume@bluemail.ch>
# From: jisrael2@breathe.com
# From: "KENNETH ILOKA" <umarb@themail.com>
# From: charlesnwodo@excite.com
# From: Mr. Charles Nwodo
# From: "Oliveira Savimbi" <olivsav@netscape.net>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: "James DeSouza." <jdsouza1@hotvoice.com>
# From: chinaeke7@juno.com
# From: "PAPA BELLO" <papabello@lawyer.com>
# From: "Dr. Don Arturo Ramitez." <don_1000@fastermail.com>
# From: "E E" <foryourconsumption_2@hotmail.com>
# From: "KABILA" <greenkab@email.com>
# From: "Oliveira Savimbi" <olivsav@netscape.net>
# From: "MR DANIEL KALU" <danielkalukalu@netscape.net>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: SOLOMON azeez <sameezx6@go.com>
# From: "NOSA" <ni452003@yahoo.com>
# From: "MR TUNDA" <tundatx@zapo.net>
# From: "DR STEPHEN UMAH" <u.stephen1@caramail.com>
# From: "Dr stephen umah" <u.stephen@caramail.com>
# From: "JOHN CHOMA" <jochom12@hotmail.com>
# From: "DR TONY COLE" <tony3@ecplaza.net>
# From: "DR TONY COLE" <tony3@ecplaza.net>
# From: "DR. GOODWILL MPENZA" <savim_5@email.com>
# From: wbanigo@anfmail.com
# From: "Engr. William Goye" <wgoye@ecplaza.net>
# From: "FRANK  GUEI JNR." <frank_jnr3@myself.com>
# From: solochuks5000@breathe.com
# From: Farouk Al-Bashar <falbashar@olumo.net>
# From: "WILLIAM   OKAFOR" <fowika@ecplaza.net>
# From: Farouk Al-Bashar <falbashar@olumo.net>
# From: "DR STEPHEN AKIGA" <ohunola@latinmail.com>
# From: "DR STEPHEN AKIGA" <ohunola@latinmail.com>
# From: "Ola Kelvin" <olakelv3@ecplaza.net>
# From: MRS CECILIA MARK AKU <mrscecilliaak@ecplaza.net>
# From: "MR.DON UBALA," <donubala@ecplaza.net>
# From: "Dr. Wilson" <itwilson33@netscape.net>
# From: James Kabila.
# From: dayonaps04@aol.com
# From: "Oliveira Savimbi" <olisav@netscape.net>
# From: "Dr Pascal Ugoti" <pascal_962@myself.com>
# From: "Dr Pascal Ugoti" <pascal_962@myself.com>
# From: "Professor Frank Obi" <professorfranko@netscape.com>
# From: "koffi joseph" <offjo@hotmail.com>
# From: "ENGR: KUMALO DILIZA" <kumalodiliza6@ecplaza.net>
# From: "MR GBENRO ADEGBOLA" <salisu_bola@yahoo.com>
# From: "MAKO OKERE" <okere1972@netscape.net>
# From: "GBENGA ALUKO" <gbealuko@voila.fr>
# From: "MR, DOMAS K, YANK" <kecityy@netscape.net>
# From: "Oliveira Savimbi" <olisav@netscape.net>
# From: "DR. PAUL BABS." <paulbabs@caramail.com>
# From: "grace abba-gana" <gabbagana@albawaba.com>
# From: "salatu_ibru300" <salatu_ibru300@indiatimes.com>
# From: "ADEROJU MUYIWA" <ademuyiwa1950@rediffmail.com>
# From: "Mr Olu Martins" <olu_martins007@yahoo.com>
# From: "maryam  abacha" <maryamy2k@indiatimes.com>
# From: "MRS ROSE SAVIMBI" <rosesavibmi@rediffmail.com>
# From: luisaastrada@portugalmail.com
# From: MARIAM ABACHA <mariamabacha202@ecplaza.net>
# From: "Bola  Harry" <bolaharryt@tiscali.co.uk>
# From: "Bola  Harry" <bolaharryt@tiscali.co.uk>
# From: "DR.TUNJI OWO" <tunjiowo@regards.net>
# From: Owen Mubane <muowen^%&@mmail.com>
# From: "DR.TUNJI OWO" <tunjiowo@regards.net>
# From: Mohammed Abacha <orionventures@go.com>
# From:Muhammed Abacha
# From: "ENGR ZULUMAKALENI." <zulumakaleni1@netscape.net>
# From: "DR (MRS) MARIAM ABACHA" <koolizzy@hotmail.com>
# From: "MR. TAMBO" <engranthony_zuma@lycos.com>
# From: Dukat Kabila <dukatka_s22@rediffmail.com>
# From: "Dr. Bouguiba Samuel" <samaguiba1@ecplaza.net>
# From: James Oni <jamesoni2000@go.com>
# From: James Oni <jamesoni2000@go.com>
# From: James Oni <jamesoni2000@go.com>
# From: CARLOS SAVIMBI <carlos_sav@go.com>
# From: "MRS, AMINA BOLA IGE" <isa_kaitha2002@yahoo.com>
# From: "Andy Bello" <andy_bello2003@rediffmail.com>
# From: "Andy Bello" <andy_bello2003@rediffmail.com>
# From: "AHMED MARTINS. D" <martinsdanjuma@mail15.com>
# From: Gabriel Kali <gadikali@gatechambers.com>
# From: "Mr.Kola Awosika" <kola.awosika@caramail.com>
# From: "SAAD A.ALLI" <husseinalli33@zwallet.com>
# From: "JOHNSON ABBAS" <johnsonabbas@zwallet.com>
# From: "Dr.Tito Sithole." <macusgee@hotmail.com>
# From: KATURA BANGA <mrkatban@netscape.net>
# From: "MADAM MARYAM" <maryamy2k@indiatimes.com>
# From: "DELE MARTINS" <delemartins@indiatimes.com>
# From: saidi fatou <saidifatou@moldova.com>
# From: "Mrs. Mariam M. Sese-seko" <Liusa11@totalise.co.uk>
# From: "MICHAEL AFOLABI" <frankemeni@ecplaza.net>
# From: NZANGA MOBUTU <Nzangamobutu@phantomemail.com>
# From: NZANGA MOBUTU <Nzangamobutu@phantomemail.com>
# From: "CHUKS ANTHONY" <chuksanthony05@netscape.net>
# From: "godfrey eche3" <godfreyeche3@albawaba.com>
# From: "godfrey eche3" <godfreyeche3@albawaba.com>
# From: "Muhammad Khalil Hasan" <khalil_muhammad@myownemail.com>
# From: "Muhammad Khalil Hasan" <khalil_muhammad@myownemail.com>
# From: "Hamzat Sulaiman" <hamzatsulaiman@unionintbanks.com>
# From: "keven wei" <envoltbattery@163.com>
# From: ami44000@netzero.com
# From: ami44000@netzero.com
# From: "Mr Chuks Anthony" <chuksanthony05@netscape.net>
# From: " JOHNSON ELENDU " <jelendu@nzoomail.com>
# From: "Mike Jide" <mijez2001_nnpc@indiatimes.com>
# From: "Mike Jide" <mijez2001_nnpc@indiatimes.com>
# From: wale_williams@post.cz
# From: "Fred Mbonu" <mfrred@hknetmail.com>
# From: "Fred Mbonu" <mfrred@hknetmail.com>
# From: JOHN COLEMEN <johncolemen1970@netscape.net>
# From: j_remitance@hknetmail.com
# From: "Mrs. Mariam M. Sese-seko" <liusaxxxx@totalise.co.uk>
# From: "MakamSomo" <sa_03@breathe.com>
# From: "Engr. Musa  Akim." <engr_musa@hknetmail.com>
# From: "Engr. Musa  Akim." <engr_musa@hknetmail.com>
# From: "DR.MATTHEW OKOYE" <mattokoye@didamail.com>
# From: "abram nkomo" <ab_nkomo@hotmail.com>
# From: maira ssesko <sseko019@go.com>
# From: Joseph Mobutu Sese-Seko <jmobutu189@latinmail.com>
# From: "Mariam Abacha" <myriaj03@femail.com.au>
# From: Joseph Mobutu Sese-Seko <jmobutu189@latinmail.com>
# From: "PRINCE FOLU FADAKA" <folufadaka@netzero.com>
# From: sussy emma <e.sussy@caramail.com>
# From: "Harry O Harry" <harry1@hknet.com>
# From: Drmoore James <jdrmoore@personal.ro>
# From: "PRINCE WILLIAMS" <princewilliamson99@portugalmail.pt>
# From: "PRINCE M  WILLIAMS" <princewilliamson99@portugalmail.pt>
# From: "MRS CECILIA  AKU" <aku_cmrs2002@surfy.net>
# From: MECK MAHABILE <mahabile10@netscape.net>
# From: "FRANK BELLO" <fbellojr39@hotmail.com>
# From: "FRANK BELLO" <fbellojr39@hotmail.com>
# From: "Mr. Mike Obodoh" <mike.obodoh@caramail.com>
# From: "Barrister. Bassey  Owo" <basseyowo300@hknetmail.com>
# From: "MUYIWA IGE" <bechmank@yahoo.com>
# From: "Dr.Tunde Cole" <tundecole@uboot.com>
# From: "Dr Tunde Cole" <tundecole@uboot.com>
# From: "williamume" <willyume@zapo.net>
# From: "Mr.Philip Jones" <philjones1@uboot.com>
# From:Mr.Philip Jones.
# From: solosavimbi@netscape.com
# From: "LEO  WILLIAMS" <leowilliams3@ipost.cz>
# From: =?iso-8859-1?Q?makathy?= <makathy@libero.it>
# From: "MRS MARY SANKOH" <sank_mary6@popmail.com>
# From: "Mr.Bom Uche" <mrbom@fastermail.com>
# From: "Mr.Bom Uche" <mrbom@fastermail.com>
# From: ikhayere obinyan <ikhayere6000@addlebrain.com>
# From: "Mr. Daniel Abass." <danielabass@afmail.com>
# From: BASHER MOBUTU <basher39@lycos.com>
# From: evans peter <evanspeter@hkonline.com>
# From: "CHIEF(DR.)BODE GEORGE" <bode_george@xuppa.com>
# From: "CHIEF(DR.)BODE GEORGE" <bode_george@xuppa.com>
# From: "GREGORY PREMIER" <gregoryprem@incamail.com>
# From: "....." <xxxxnnnnaaaa@netscape.net>
# From: "Mr.Fred Obi" <fredobi02@zwallet.com>
# From: idris umar <idrisumar94@go.com>
# From: idris umar <idrisumar94@go.com>
# From: idris umar <idrisumar94@go.com>
# From: "daniel bello" <danbello07@hotmail.com>
# From: "Mohammed Abacha" <dansekou@voila.fr>
# From: "Mohammed Abacha" <dansekou@voila.fr>
# From: "mrs m mbeki" <mrsmbeki@juno.com>
# From: "Kola Daniel" <kolad05@indiatimes.com>
# From: E-Loan Consumer Department <consumer.support@e-loan.com>
# From: E-Loan Consumer Department <consumer.support@e-loan.com>
# From: E-Loan Consumer Department <consumer.support@e-loan.com>
# From: princeige@mail3000.com
# From:
# From: "Francis Sonto Mbomam" <dr_francis_mboma0@lycos.com>
# From: Wells Fargo Accounting <wfba.accounting@wellsfargo.com>
# From: Wells Fargo Accounting <wfba.accounting@wellsfargo.com>
# From: Wells Fargo Accounting <wfba.accounting@wellsfargo.com>
# From: frank <frankzambani42@netscape.net>
# From: "Pandindra" <>
# From: Dr. Uba Jega.
# From: usman aminu <dr_aminuusman@anytimenow.com>
# From: "Dr .Titi okonkwo" <titi_okonkwo@yahoo.com>
# From: "Dr .Titiokonkwo" <titiokonkwo234@yahoo.com>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: "Godwin Ekpontu Sangana, Esq" <ejieego@netscape.net>
# From: ENGR MARK DAVID <igho200@netscape.net>
# From: "Fadaka Randebe" <randebe@kalpoint.com>
# From: "Fadaka Randebe" <randebe@kalpoint.com>
# From: Ali Mohammed <ali_mohammed@123.com>
# From: "First Bank Nig. Plc.( Dr. Femi Johnson.)" <fbplcnig@nzoomail.com>
# From: "carlos savimbi" <savimbicar1@dogmail.co.uk>
# From: vumeh704@hknetmail.com
# From: "CHIEF(DR.)BODE GEORGE" <bodegeorge@pisem.net>
# From: mariam abachas <mariamabachs@go.com>
# From: "ALI AHMED" <aliahmed@ecplaza.net>
# From: "Abu Kyari." <akyari1@sudanmail.net.sd>
# From: alimabu@tiscali.co.uk
# From: "Joseph Savimbi" <joseph_1ang@zwallet.com>
# From: "Joseph Savimbi" <joseph_1ang@zwallet.com>
# From: "prince george duke" <naa8m@mail.com>
# From: okijames@latinmail.com
# From: "Mr. Jeffrey Daniels" <jeffreydaniels2@excite.com>
# From: "Mr. Jeffrey Daniels" <jeffreydaniels4@excite.com>
# From: "ADA USMAN!" <adausman@popmail.com>
# From: "Daniel  Kargbu" <dankar3@zwallet.com>
# From: "Mr. John Nlobo" <johnnlobo@yahoo.com>
# From: <ajala8000@rediffmail.com>
# From:Mr.Wilson Ajala
# From: "Dr.Kunle Owolo" <kunowolo3@tiscali.co.uk>
# From: "Dr.Kunle Owolo" <kunowolo3@tiscali.co.uk>
# From: "MRSJENNIFER KOBE" <mrsjennikobe@hknetmail.com>
# From: jackamala@tiscali.co.uk
# From: "DR THOMAS AUDU" <thomasaudu@mail.com>
# From: kalu idika <kaluidikak@go.com>
# From: makalele01@xzapmail.com
# From: g_ineh@tiscali.co.uk
# From: "Michael Stevens Junior." <marksteven301@netscape.net>
# From: "Hajia Maryam Abacha" <maraba234@anfmail.com>
# From: "Hajia Maryam Abacha" <maraba234@latinmail.com>
# From: "BARRISTER MATHEW IKE" <mathewike212@juno.com>
# From: engedetamanah@post.cz
# From: "MR.ODIASE GEORGE" <sunnyokogwo@post.cz>
# From: "DEACON ZIK R. DON" <deacon_zik@yaoo.com>
# From: "Nzanga Mobutu" <mobkuz3@kukamail.com>
# From: adew1@mail3000.com
# From: adew1@mail3000.com
# From: "DR.MUHAMMED MUSTAFA" <muhammed303@arabtop.net>
# From: "BARRISTER, HOPKINS MBEKI" <hopkinsmbeki@hknetmail.com>
# From: ndandla@latinmail.com
# From: <mcabacha@freesurf.fr>
# From: "Mr Ugochukwu .W" <ugoch_8@z6.com>
# From:Mr.UGOCHUKWU WILLIAM. URGENT REQUEST FOR ASSISTANCE Tel: 00971-50-7155760. Private e-mail:(ugochukwu9@yahoo.co.uk) Dear sir, This letter might surprises you because we have met neither in person nor by correspondence.But I believe it is one day that you got to know somebody either physical or through correspondence,I got your contact through the web-site when I was searching for a reliable trusth-worthy foreign partner to work with. However I am the son of Ex-Minister of Finance Mr.Ugochukwu, a formal Minister of Finance during Late President Laurent Kabila of Democratic Republic of Congo. Infact, I left my country because it was no longer save for me. My father is now in detention awaiting trial because of his involvement againt the government of President Joseph Kabila, who is presently the president of my country. My father called my attention and informed me that he lodged some funds on a Trunk Box with a security firm with an open beneficiary status.I am making thi!
# From: shaabanbait@primposta.com
# From: shaabanbait@primposta.com
# From: consultant_ng3@send-mail.co.uk
# From: mike odey <modey06@go.com>
# From: "DR. AKIN DADA." <akindada@indiatimes.com>
# From: "barrister vincent usman" <2003vincent@freesurf.fr>
# From: "JAMIE  OPUKU." <jamie777@mail.biz.ly>
# From: <jerrypeter2@freesurf.fr>
# From: "mona noah" <mnoah3@hotmail.com>
# From: "MICHEAL  OSSAI" <JUDE@YAHOO.COM>
# From: test@yahoo.com
# From: test@yahoo.com
# From: "Peter Bongo" <mrbongo@themail.com>
# From: MASTER HAROLD MBEKI <akumembeki@netscape.net>
# From: "maryaabacha8 maryam " <mmaryaabacha8@caramail.com>
# From: Mrs Maryam Abacha
# From: "maryaabacha8 maryam " <mmaryaabacha8@caramail.com>
# From: Mrs Maryam Abacha
# From: "H B" <hansob@123.com>
# From: diaka tshombe <dtshombe2@123.com>
# From: EKONG BASSEY <ekong.bassey2@caramail.com>
# From: Vasil Nanchev <vas_imoti@abv.bg>
# From: frank okonjo <frankokonjo5@123.com>
# From: "DR. GODWIN KALALA" <gokalala1@tiscali.co.uk>
# From: EKONG BASSEY <ekong.bassey2@caramail.com>
# From: HELLEN SHAKA ZUMA <hellenshaka@netscape.net>
# From: Akande fredrick <fredsam@123.com>
# From: esama kingdom <esamakingdom@fsmail.net>
# From: MARY ABASS <mary_abass2@123.com>
# From: frank okonjo <frankokonjo6@123.com>
# From: "vino koni" <vinokoni5@hotmail.com>
# From: sarah.mutete@caramail.com
# From: "DAVIDS ANDERSON." <anders01_lb@post.cz>
# From: diaka tshombe <dtshombe3@123.com>
# From: markedeozo@freesurf.fr
# From: allan Sheriff
# From: abu_saeed4@tiscali.co.uk
# From: elosub@freesurf.fr
# From: "Yetunde Bassey" <yetunde@mail2world.com>
# From: "Yetunde Bassey" <yetunde@mail2world.com>
# From: "lary kamokai" <lary_kamokai1@hotmail.com>
# From: "micheal ado santigo" <micheal_ado@hotmail.com>
# From: <fredkuma@freesurf.fr>
# From: wolny_olkusz@latinmail.com
# From: "DR. George Ibrahim Quattara" <dr_georgequattara@indiatimes.com>
# From: "Mr..John Chukwu" <johnchukwu1@caramail.com>
# From: "DR BELLO BATURE" <dr.bell_bat@portugalmail.com>
# From: "maryaabacha8 maryam " <mmaryaabacha8@caramail.com>
# From: Mrs Maryam Abacha
# From: "Mrs. Juliet Bello." <ladyj4u@mail2cherry.com>
# From: "Mrs. Serena  Jones" <serenajones$$7@netscape.net>
# From: Mrs Serena Jones
# From: "chuks Anthony" <chuksanthony05@netscape.net>
# From: =?us-ascii?Q?jide=20williams?= <jide.williams@seznam.cz>
# From: yinkadavi@mailbox.hu
# From: "MR.WILLIAM" <william_d@zwallet.com>
# From: "MR.WILLIAM" <william_d@zwalley.com>
# From: karimusesay@whipmail.com
# From: chesson_joseph@mail2world.com
# From: J.Rodney chesson jr
# From: "Nelson Abia" <nelson_abia203@hotmail.com>
# From: "MR ALI AMED" <prince_amed011@hotmail.com>
# From: "muhammed abacha" <abamohammed@ananzi.co.za>
# From: "HASSAN DIKO" <hassandiko@fsmail.net>
# From: "OLUWATOBI E.BOYE" <oluwatobiboye@dcemail.com>
# From: "OLUWATOBI E.BOYE" <oluwatobiboye@dcemail.com>
# From: "Mr Nelson Abia" <nelson_abia203@hotmail.com>
# From: "Fred Okoli" <redokoli42@yahoo.com>
# From: "haji musa diya" <musa_diya@fastermail.com>
# From: "haji musa diya" <musa_diya@fastermail.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: "From: Mrs. Victoria Bucknor" <victoriabucknor23@mail15.com>
# From: Mrs Serena Jones <ssarejo355@netscape.net>
# From: Mrs Serena Jones
# From: "prince duke" <aa44@rt.nl>
# From: "MRS M. SESE SEKO" <nanaseko3@web-mail.com.ar>
# From: Mac Jonson Bonida <jonsonbonida_mac$77@latinmail.com>
# From: "Mrs.Floxy Page" <floxypage44@hknetmail.com>
# From: "PETER OKOYE" <opeter6@caramail.com>
# From: "PETER OKOYE" <opeter6@caramail.com>
# From: "MRS.MARYAM ABACHA" <firstlady234@post.cz>
# From: "MRS M. SESE SEKO" <nanaseko4@web-mail.com.ar>
# From: "MOHAMMED" <port1.net@email.it>
# From: "MOHAMMED" <port1.net@email.it>
# From: "MOHAMMED" <port1.net@email.it>
# From: "HAJIA MARYAM ABACHA" <hajia2000@i2828.com>
# From: =?us-ascii?Q?mogua=20mogogo?= <moguam@seznam.cz>
# From: selina_gabrielmarinze <selina_gabrielmarinze@voila.fr>
# From: y a <project101@123.com>
# From: "MRS AMINA MOHAMMED" <aminamohammed311@netscape.net>
# From: MRS SUSAN <mrs_susan2@123.com>
# From: "Dr.Faroq Uztaz[Regional Director]" <faroqz10@hotmail.com>
# From: MR JANG DOO-HWAN <jangdo1@hknetmail.com>
# From: ken dikko <kendikko01@123.com>
# From: "Mr Ugochukwu" <ugochukwu_8@z6.com>
# From: "from prince duke" <d11@rt.nl>
# From: "from prince duke" <van77@rt.nl>
# From: Thomas Taylor <thomutete@netscape.net>
# From: "Mr.Michael Dohn" <m_doh4@zwallet.com>
# From: "Mr.Michael Dohn" <m_doh4@zwallet.com>
# From: jonbwaya@tiscali.co.uk
# From: jonbwaya@tiscali.co.uk
# From: william Isiaka <williamisiaka55@123.com>
# From: "DR. MRS. MARIAM ABACHA" <hmariam234@rediffmail.com>
# From: "MR MICHAEL EWALD" <mikeewald@eudoramail.com>
# From: abayomidavies@yahoo.com
# From:  Davies
# From: errol_marshall2@albawaba.com
# From: mrsjane abdullah <mrsjaneabdullah@123.com>
# From: Yetunde Bassey <yet_bassey@123.com>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MOHAMMED ABACHA" <mohammed_ab000@go.com>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MOHAMMED ABACHA" <mohammedabacha000@tiscali.co.uk>
# From: "MARK AKPU" <markakpu@tiscali.co.uk>
# From: susan shabangu <sussy_shab@123.com>
# From: "Mr. Nasser Nasiri." <nassernasiri2003@uaemail.com>
# From: "Mr. Nasser Nasiri." <nassernasiri2003@uaemail.com>
# From: "Mr. Nasser Nasiri." <nassernasiri2003@uaemail.com>
# From: "sogolo_hmd@juno.com" <sogolo_hmd@juno.com>
# From: sogolo_hmd@juno.com
# From: "prince duke" <laa@rt.nl>
# From: jrchesson@rediffmail.com
# From: J. Rodney Chesson
# From: Mrs Serena Jones <serenajones1@rediffmail.com>
# From: Mrs Serena Jones
# From: MR BASHE MOBUTU SESE SEKO <mobutbashe3@rediffmail.com>
# From: "PETER BUNO" <peterbuno@rediffmail.com>
# From: "PETER BUNO" <peterbuno@rediffmail.com>
# From: jeffmboma@tiscali.co.uk
# From: "ABDULKAREEM USMAN" <abdulkareem_39@findology.com>
# From: "Mr. Duke Nze" <dukenze@123.com>
# From: "Mr. Duke Nze" <dukenze@123.com>
# From: "Phill Ipenza" <philpenza@ecplaza.com>
# From: james kyari <jameskyari22@netscape.net>
# From: "DR DONALD" <dr_don_ike@hknetmail.com>
# From: mariama seseko <mmssko2@123.com>
# From: "NETHERLOTTO CORPORATION." <netherlotto@corporation.com>
# From: "MR.DANDY NNAJI" <dandy_nnaji@yahoo.com>
# From: "MR.DANDY NNAJI" <dandy_nnaji@yahoo.com>
# From: "PETERSON BULINGA" <peson@zwallet.com>
# From: MR JOSEPH MOBUTU SESE SEKO <josephmobutu200$@latinmail.com>
# From: dada abu <dada@fsmail.net>
# From: Yetunde Bassey <yet_bassey@123.com>
# From: susan shubangu <susanshubangu@123.com>
# From: kayode phillip <kayodephillip@fsmail.net>
# From: Mrs Jumai YOUSSEF <juma2003@thepostbox.co.uk>
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: "DR Peter Clapton" <wasa@was.com>
# From: The Desk of Dr.PETER CLAPTON
# From: The Desk of Dr.PETER CLAPTON<BR>Director, Investments and Portfolio
# From: Alexander Afadia <eeaesq@123.com>
# From: "MUSA AHMED ZULU" <musma_adb@ny.com>
# From: issacwimpoehato@yahoo.com
# From: Mallam Bello Ali <mallam_bello@123.com>
# From: james morgan <jamesmorgan@fsmail.net>
# From: "Fred Okoli" <fredokoli300@yahoo.com>
# From: "Fred Okoli" <fredokoli300@yahoo.com>
# From: "MR.lucman Watson" <lucman_watson@macmail.com>
# From: "KAZEEM AHMED" <kazeemahmed@gawab.com>
# From: JULIET UGAGA <julietugaga22@netscape.net>
# From: Frank Bello <fbello1@megamail.pt>
# From: Frank Bello <fbello1@megamail.pt>
# From: "MR FEMI MARTINS" <femi-martins876@fsmail.net>
# From: "laurent_nkono@zwallet.com" <laurent_nkono@zwallet.com>
# From: "MRS. MARIAM ABACHA (WIDOW)." <bonakama232322de45@eudoramail.com>
# From: manuelsisilu@latinmail.com
# From: "Mohammed Mustafa" <mohammedmustafa@arabtop.net>
# From: abachafamily4@tiscali.co.uk
# From: "THEMBI" <thembi79@zwallet.com>
# From: kojadams <kojadams@voila.fr>
# From: "Carl Eblon" <carleblon@zwallet.com>
# From: "DAVIS TUTU" <davistutu@yahoo.co.uk>
# From: "SAM KOROMA" <sarakoroma@hotmail.com>
# From: "" <mjaja02@libero.it>
# From: hildatoms@Eudoramail.com
# From: "Rose Savimbi" <rosesav1@webave.com>
# From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123.com>
# From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123.com>
# From: "From Mr Nelson Bidi ." <mrnelsonbidi_3@123.com>
# From: usman_ali@tiscali.co.uk
# From: henrich agah <hc_agah555@fsmail.net>
# From: "FROM MRS RAMA IDRIS" <rama1@whipmail.com>
# From: "FROM  PRINCE WILLIAMS  TAYOLR." <princewillams773@z6.com>
# From: "FROM  PRINCE WILLIAMS  TAYOLR." <princewillams773@z6.com>
# From: joseph.williamvaye@caramail.com
# From: "collins" <collinsngobe@fsmail.net>
# From: "collins" <collinsngobe@fsmail.net>
# From: kaladah@epatra.com
# From: "DR OKON PHILIP" <okphilip1@tiscali.co.uk>
# From: "Donga Kabaka" <dongakabaka@tiscali.co.uk>
# From: james momodu <Bruno.Daems@pandora.be>
# From: "MR IBRAHIM YADUDU." <ibrahimyadudu@tiscali.co.uk>
# From: "DR. JOHNSON KENNETH" <jjoh3000@yahoo.co.uk>
# From: "DR. JOHNSON KENNETH" <jjoh3000@yahoo.co.uk>
# From: gregorykabila333@mail.bg
# From: mary alade <maryalade66@fsmail.net>
# From: K.M.ZONDI@foxfire.mr.itd.UM (REV),
# From: "DANJUMA WILLIAMS M" <danjumawilliams@fsmail.net>
# From: dr kabo hammed <ka_hammed@fsmail.net>
# From: maryam abacha <mar_maryam@fsmail.net>
# From: "KEN GOMAN" <ukpd@web-mail.com.ar>
# From: mohameed_aba1@tiscali.co.uk
# From: mohameed_aba@tiscali.co.uk
# From: "george akin" <george2000@wp.pl>
# From: robert harare <rharare1@spinfinder.com>
# From: mohameed_aba@tiscali.co.uk
# From: "J.C.G" <jocg102@netscape.net>
# From: "oliver  yengeni" <oliveryengeni@tiscali.co.uk>
# From: kufor2000 <kufor2000@tatanova.com>
# From: "matthew molefe" <matthewmolefe3@webmail.co.za>
# From: tblmichl <tblmichl@voila.fr>
# From: DR USMAN BELLO <dr_usmanbello@fsmail.net>
# From: her29@rediffmail.com
# From: 03mariam@tiscali.co.uk
# From: jewel taylor <jeweltaylor_274@fsmail.net>
# From: "James Mercy Sankoh" <sankoh.james@caramail.com>
# From: "James Mercy Sankoh" <sankoh.james@caramail.com>
# From: "Mr Zakir Mahmood" <zakirmahmood@primposta.com>
# From: "Mr Zakir Mahmood" <zakirmahmood@primposta.com>
# From: "MR. JAMES NICHOLAS" <jamesnicholas@zwallet.com>
# From: "Dr.Wahid Mallam" <wahidmallam@fsmail.net>
# From: Bello Musa <bmusa11@fsmail.net>
# From: "MR. BASIL EZE" <bakko_bakko@yahoo.com>
# From: "Dr. Felix William" <felix_william123@hotmail.com>
# From: steveuwa <steveuwa@telstra.com>
# From: steveuwa2@tiscali.co.uk
# From: steveuwa2@tiscali.co.uk
# From: "KAMARA WILLIAM" <kamara1000w@hotmail.com>
# From: "MRS.ROSE OBASEKI" <roseoba1@webmail.co.za>
# From: "jj_walter9@netzero.com" <jj_walter9@netzero.com>
# From: jj_walter9@netzero.com
# From: "Dardossi" <b.goronyo1@caramail.com>
# From: Dr.Goronyo Baba..
# From: MRS MUDIWA ZUKA <zuka2004@netscape.net>
# From: "Mrs. Jumai Abdul Azad." <fatima_abdul@sify.com>
# From: Zuka <zuka2005@netscape.net>
# From: "Mariam Mustapha" <marab_ha@weedmail.com>
# From: jubeeg venture <jubeegv@fsmail.net>
# From: Kanu Chijuka <dr_kanuchijuka@fsmail.net>
# From: "Robinson Dike" <dr.robinson.dike@webmail.co.za>
# From: "Robinson Dike" <dr.robinson.dike@webmail.co.za>
# From: "Robinson Dike" <dr.robinson.dike@webmail.co.za>
# From: =?iso-8859-1?Q?michael_=A0nkomo?= <nkomo2004_026@fsmail.net>
# From: =?iso-8859-1?Q?michael_=A0nkomo?= <nkomo2004_026@fsmail.net>
# From: "kolapo omidire" <kolapoomidire2@webmail.co.za>
# From: abdullah_andani@z6.com
# From: abdullah_andani@z6.com
# From: patrick atike <patrickatike2@fsmail.net>
# From: nze_moore <nze_moore@voila.fr>
# From: mngomeni james <mngomeni4@fsmail.net>
# From: Engineer Tony Edem <engrtonyedem@fsmail.net>
# From: Engineer Tony Edem <engrtonyedem@fsmail.net>
# From: kufor_1000 <kufor_1000@tatanova.com>
# From: "MR JOHN MENSAH" <johnmensah@past.cz>
# From: "Mr. Zakir Mehmood" <mood_zakir22@primposta.com>
# From: MRS LOI C ESTRADA <mrrssjjjoseph@netscape.net>
# From: MRS LOI C ESTRADA <mrrssjjjoseph@netscape.net>
# From: "MRS LOI C. ESTRADA" <estradason2@tiscali.co.uk>
# From: "MRS LOI C. ESTRADA http://www.iro.bsp.gov.ph/whoswhoprint.asp?ID=30
# From: George Nduumba <georgenduumba@fsmail.net>
# From: "Susan Martins" <smartins1@webmail.co.za>
# From: Mrs.Susan Martins
# From: WILLIAMS OLUFEMI <barrisolu@fsmail.net>
# From: "frank damas" <frankdamas34@webmail.co.za>
# From: "PRINCE OGO" <princeogo20043000@yahoo.com>
# From: "PRINCE OGO" <princeogo20043000@yahoo.com>
# From: "blessed ogbe" <blog333@webmail.co.za>
# From: "PRINCE CHARLES ZUMA" <prince_charlzuma@fsmail.net>
# From: ohams oham <ohams1@fsmail.net>
# From: "DR WILLIAMS FREDRICK" <drwilldrick25@fsmail.net>
# From: paul bugati <paul147_422@fsmail.net>
# From: "SA" <suleoketayo@alexandria.cc>
# From: Mr Usman Ramat <mrramatu@fsmail.net>
# From: blessed ogbe <blog555ng@fsmail.net>
# From: "michael nkomo" <nkomo_2004@cosmo.com>
# From: "michael nkomo" <nkomo_2004@cosmo.com>
# From: "JONAS SAVIMBI" <sourcetrans@weedmail.com>
# From: "aishatu            ahmed" <aishatuahmed006@hotmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: "JOHNSON SAVIMBI" <sourcetrans@weedmail.com>
# From: s.shabangu2@freenet.de
# From: Mrs. Susan Shabangu.<br>
# From: Martins Aku <martinsaku01@truthmail.com>
# From: Martins Aku <martinsaku01@truthmail.com>
# From: "Mr. Zuhair Idris" <idris_z@primposta.com>
# From: "Mr. Zuhair Idris" <idris_z@primposta.com>
# From: "SA" <suleoketayo@alexandria.cc>
# From: "ahmed abu" <ahmedabu@e-tapaal.com>
# From: ".." <ewossawk@netscape.net>
# From: "FROM DANIEL TUNDE" <daniel09@yahoo.com>
# From: "Mr Richard Akwasi" <Akwasi101@52.com>
# From: abu_saeed04@tiscali.co.uk
# From: mzimba_vivian@hotmail.com
# From: "KEN AMOBI" <ukpd2@email.cz>
# From: "Dr. Lukman Rilwanu" <luckmankkk@netscape.net>
# From: Kalister Maunda <kalika@tiscali.co.uk>
# From: "Usman Ramat" <ramatemail@cosmo.com>
# From: "Usman Ramat" <ramatemail@cosmo.com>
# From: larryacb <larryacb@voila.fr>
# From: larryacb <larryacb@voila.fr>
# From: "Barrister Maxwell Obiekwu ." <barristermaxwell1@macmail.com>
# From: "MARIAM ABACHA" <marian_abacha@indiatimes.com>
# From: "David Aku" <dudu1234@webmail.co.za>
# From: ends in numbers
# From: "MR JERRY OZUBA" <j_ozuba@fsmail.net>
# From: onyemauk2004 <onyemauk2004@voila.fr>
# From: "Dr. Kelly William" <kellywiliam2@telstra.com>
# From: "Susan Martins" <swodi111@hotmail.com>
# From: "Richard Akueze" <richardakueze@cosmo.com>
# From: "MADAM STELLA SIGCAU" <madamstellasigcau_8@fsmail.net>
# From: "MADAM STELLA SIGCAU" <madamstellasigcau_8@fsmail.net>
# From: "jeffersila04" <jeffersila04@libero.it>
# From: JOHNSON  <johnsontwilliams@netscape.net>
# From: "Peter Saseh" <sasehpeter@latinmail.com>
# From: Rashidat Azmil <r_azmil@email.si>
# From: "fred mende" <fredmende04@zwallet.com>
# From: SIMON OKOH1 <simonokoh1@fsmail.net>
# From: "Engr Mansur Ahmed" <manahmed@sify.com>
# From: bmohammend@themail.com
# From: bmohammend@themail.com
# From: bmohammend@themail.com
# From: bmohammend@themail.com
# From: "Dr. Mchenry Douglas" <mchenry911@tiscali.co.uk>
# From: franck1@wooow.it
# From: larrybrown@starspath.com
# From: "Mr. Kizie Mulumba" <kizie_mulumba@myway.com>
# From: "Mr. Kizie Mulumba" <kizie_mulumba@myway.com>
# From: "MR. PASCAL IBE" <pascalibe1@mail.nu>
# From: arapmoi.gideon@caramail.com
# From: "mariam abacha" <mariam_9999@atlas.cz>
# From: abacha80 <abacha80@voila.fr>
# From: MR TONY  OBA
# From: MR TONY&nbsp; OBA<BR>REPLY MY MAIL THROUGH THIS EMAIL ADDRESS: <U><FONT color=#0000ff><A href="mailto:ike_oba1@yahoo.co.uk">ike_oba1@yahoo.co.uk</A></FONT></U><BR>Dear Sir/Madam, <BR>I am Mr Baldwin Gozie, Bank Manager of Diamond BANK , Lagos Branch. I have urgent and very confidential business proposition for you.I got your contact from the World Trade Center (W.T.C) regional office in Lagos,Nigeria although the details of my intention was not made known to them. On June 6 1997, an American oil consultant/contractor with the Nigerian National Petroleum Corporation, Mr. Barry Kelly made a numbered time (Fixed) deposited for twelve calendar months, valued at US$11,600,000.00 (Eleven Million,Six Hundred Thousand Dollars) in my branch. Upon maturity, I sent a routine notification to his forwarding address but got no reply. After a month, we sent a reminder and finally we discovered from his contract employers, Nigerian National Petroleum Corporation that Mr. Barry Ke!
# From: MR TONY  OBA
# From: MR TONY&nbsp; OBA<BR>REPLY MY MAIL THROUGH THIS EMAIL ADDRESS: <U><FONT color=#0000ff><A href="mailto:ike_oba1@yahoo.co.uk">ike_oba1@yahoo.co.uk</A></FONT></U><BR>Dear Sir/Madam, <BR>I am Mr Baldwin Gozie, Bank Manager of Diamond BANK , Lagos Branch. I have urgent and very confidential business proposition for you.I got your contact from the World Trade Center (W.T.C) regional office in Lagos,Nigeria although the details of my intention was not made known to them. On June 6 1997, an American oil consultant/contractor with the Nigerian National Petroleum Corporation, Mr. Barry Kelly made a numbered time (Fixed) deposited for twelve calendar months, valued at US$11,600,000.00 (Eleven Million,Six Hundred Thousand Dollars) in my branch. Upon maturity, I sent a routine notification to his forwarding address but got no reply. After a month, we sent a reminder and finally we discovered from his contract employers, Nigerian National Petroleum Corporation that Mr. Barry Ke!
# From: solomon owen <wwwsolomon@mail.co.za>
# From: sekomariam2001 <sekomariam2001@telstra.com>
# From: MRBATESALANN@netscape.net
# From: BEL-ZULU SANI AHMED <belsa@acazamail.com>
# From: julliet03 <julliet03@voila.fr>
# From: MRBATESALAN@netscape.net
# From: "Kelly William" <kellywilliam@telstra.com>
# From: marzuba <marzuba@telstra.com>
# From: "pikka saaiman" <psaaiman2@mail.az>
# From: "Frank Shabalala" <mr_frank2020@hotmail.com>
# From: Mr John Obi.
# From: steve_kam11@yahoo.com
# From: sadmarah@sapo.pt
# From: sadmarah@sapo.pt
# From: "MOHAMMED ABACHA" <mohammed2@mail15.com>
# From: "DR.LUISA ESTRADA" <mrsluisaestrada1@emailaccount.com>
# From: "William Fufua" <williamfufua@yahoo.com>
# From: "FROM  DR.  HASSOUN   ODHIAMBO" <hassounodhiambo4@z6.com>
# From: "FROM  DR.  HASSOUN   ODHIAMBO" <hassounodhiambo4@z6.com>
# From: cromjohn@postino.it
# From: BALA MANCHA <balamancha@telstra.com>
# From: "MRS. LINDA CAMARA." <linda02@luxmail.com>
# From: "DR. MARCUS COLE" <freshcole@netscape.net>
# From: "FROM  DR.  HASSOUN   ODHIAMBO." <drhassounodhiambo@arabtop.net>
# From: semassaq@o2.pl
# From: "dr_frances" <dr_frances@libero.it>
# From: "dr_frances" <dr_frances@libero.it>
# From: johnkabilaa@rt.nl
# From: JOHN KABILA
# From: danjumansule <danjumansule@bigpond.com>
# From: danjumansule <danjumansule@bigpond.com>
# From: danjumansule <danjumansule@bigpond.com>
# From: "James Obulu" <jobulu1@torba.com>
# From: "James Obulu" <jobulu1@torba.com>
# From: "Oladimeji Afolabi" <afolabi_olu@hotvoice.com>
# From: dpatrick88 <dpatrick88@telstra.com>
# From: dpatrick88 <dpatrick88@telstra.com>
# From: dpatrick88 <dpatrick88@telstra.com>
# From: "Chamberlin Klugman" <chamberlin@drunkandstoned.com>
# From: kamasutu <kamasutu@telstra.com>
# From: "Dr,A. Almack." <dr_tta1@hotmail.com>
# From: "PRINCESS" <princessifeoma@702mail.co.za>
# From: nzani3 <nzani3@telstra.com>
# From: USMAN ISA <iusmanng2@telstra.com>
# From:  Barrister Isa Usman & Co.,
# From: "cyril8" <cyril8@telkom.net>
# From:Cyril Konan.
# From: "MATAMELA C. RAMAPHOSA" <cyrilmata1@zwallet.com>
# From: james001@postino.it
# From: The Desk of Ajibola James
# From: "Mercy Kume" <kumemercy@netzero.com>
# From: "Princess Ifeoma." <princess_ifeoma@excite.com>
# From: "Princess Ifeoma." <princess_ifeoma@excite.com>
# From: "Mr.Chan Fung." <chanfung123@indiatimes.com>
# From: "SAMSON K.MANI" <manifamily3@hotmail.com>
# From: James Nandu <jamesnandu11@mac.com>
# From: semassaq4@o2.pl
# From: semassaq4@o2.pl
# From: "DR. ABU HASSAN" <abu@go.com>
# From:DR.ABU  HASSAN
# From: memunamousa@zwallet.com
# From: memunamousa@zwallet.com
# From: Barrister Philip Ajayi
# From: "AHMED SANI" <mohdsule@fsmail.net>
# From: "p.mass" <p.mass@telstra.com>
# From: "Mr.Johnson Gube" <mrgube_john@hotmail.com>
# From: "monica martins" <monicamtf11@galmail.co.za>
# From: Mrs.Monica Martins
# From: mkhasan01<mkhasan01@tatanova.com>
# From: "john carlos" <johncarlos26@webmail.co.za>
# From: "PRINCESS" <princessifeoma@702mail.co.za>
# From: "Thomas Chilunda" <thomaschilundaa40@hotmail.com>
# From: "Mercy Kume" <mercykume121@netzero.com>
# From: semassaq4@o2.pl
# From: johncoro@o2.pl
# From: "Daniel  Mukaila" <daniel_m@123.com>
# From: "Daniel  Mukaila" <daniel_m@123.com>
# From: "Daniel  Mukaila" <daniel_m@123.com>
# From: "Mr.Kizie Mulumba" <kizie_mulumba2@humanux.com>
# From: barrister_dennkerry@telstra.com
# From: "mr   kala  kabila" <kkkabila2003@yahoo.com>
# From: royalmajesty <royalmajesty@telstra.com>
# From: johncoro@o2.pl
# From: "Dr.Tony Williams" <tony_williams77@hotmail.com>
# From: "BUNOR DICKINS" <bunor_dickins@yahoo.com>
# From: "Reverend Ngoly" <ngo@mail32.com>
# From: "hassanahmed" <hassanahmed@moldova.cc>
# From: "MRS. LINDA CAMARA." <linda02@luxmail.com>
# From: "Mr Bruno Williams" <brunowiliams04@voila.fr>
# From: "MR. PASCAL IBE" <pascal_ibe102@yahoo.co.in>
# From: "mohammed .s. abacha" <moabas1@netscape.net>
# From: "Okpara Addey" <addeyokpara@yahoo.co.uk>
# From: "Mr Stephen Bello" <stbello55th@yahoo.co.in>
# From: "MRS, FATIMA RASHEED KHALIFA" <Mrs_fatima@z6.com>
# From: semassaq@fastmail.fm
# From: "MR  COLINS  BROWN" <colins_brown@yehey.com>
# From: "john paul"<john_paul@email.cz>
# From: "john paul"<john_paul@email.cz>
# From: "Dr  Mrs  Estrada" <dr_mrs_estrada@homenetmail.com>
# From: "Dr  Mrs  Estrada" <dr_mrs_estrada@homenetmail.com>
# From: "Philip Dickson" <philipdickson35@hotmail.com>
# From: semassaq@netscape.net
# From: solomon_mudani8<solomon_mudani8@tatanova.com>
# From: semassaquoe23g@yehey.com
# From: semassaquoe23g@yehey.com
# From: ri_mboweni@telstra.com
# From: fmlucy112@netscape.net
# From: R@M
# From: monicayangani250@netscape.net
# From: "Mrs Juliana Faith Peters" <mrsjfp11@tiscali.co.uk>
# From: Mrs. Juliana Faith Peters
# From: "Mrs Juliana Faith Peters" <mrsjfp11@tiscali.co.uk>
# From: Mrs. Juliana Faith Peters
# From: "Bakura BJ Zamani" <bakurawae@fa.org>
# From: "Bakura BJ Zamani" <bakurawae@fa.org>
# From: "Mrs. Monica Kofi" <monicakofi@voila.fr>
# From: semassaq@mail.az
# From: "PRINCESS HASIHATU SESSEY COLA." <princesshasihatu@myway.com>
# From: seeem4@mail.az
# From: aminawazi@netscape.net
# From: "daniel kabila" <dankabila001@yehey.com>
# From:Daniel Kabila<BR>Johannesburg,South Africa</P>
# From: "Mrs Fatima Rasheed Khalifa" <fatima_khalifa2004@Z6.com>
# From: ilist-owner@krusty.si.UM
# From:    drallo_wd4@yahoo.com
# From: =?iso-8859-1?q?william=20drallo?= <drallo_wd4@yahoo.com>
# From: ilist-request@lists.si.UM
# From: "Dr Frank Obi" <frankobi@direccion.com>
# From: davidbongani@netscape.net
# From: solomon_mudani8<solomon_mudani8@tatanova.com>
# From: Rahim Sule <x9k5@yahoo.com>
# From: Dan Wilson <dan@danielm.org>
# From: Dan Wilson <dan@danielm.org>
# From:Dan Wilson
# From:Dan Wilson
# From: mohammed-abacha@whipmail.com
# From: "markduke2004" <markduke2004@libero.it>
# From: "Lawyer" <barristerpeter2@emaila.nu>
# From: michael_nwa1@iol.pt
# From: "SUSAN SHABANGU" <ss@yahoo.com>
# From: tsepovusi@netscape.net
# From: tsepovusi@netscape.net
# From: "SESAY MASSAQUOE" <semassaq3@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq3@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq3@o2.pl>
# From: massaq1@di-ve.com
# From: sitholebaloy@netscape.net
# From: "MR GEORGE AMACHREE" <georgeamachree_2@hotmail.com>
# From: "MR GEORGE AMACHREE" <georgeamachree_2@hotmail.com>
# From: "MR GEORGE AMACHREE" <georgeamachree_2@hotmail.com>
# From: willamsj@tiscali.co.uk
# From: davidnelson3010@tiscali.co.uk
# From: davis2010@tiscali.co.uk
# From: idumar55@di-ve.com
# From: idumar55@di-ve.com
# From: idumar55@di-ve.com
# From: "boyd ololo" <boydololo1@tiscali.co.uk>
# From: "susan shabangu" <shabang2susan@webmail.co.za>
# From: "hubert kliuvert" <cbforg_1@hotmail.com>
# From: "williams\.onwa" <williams.onwa@laposte.net>
# From: "Josef Bala" <josef_bala@x-sub.de>
# From: ndidi_uwoma@jumpy.it
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR.MICHEAL EDET DUKE" <mich_e_duke@omaninfo.com>
# From: "MR, MIKE KOFI" <mikekofi@wowmail.com>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: massaq1@di-ve.com
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: williammabaye@netscape.net
# From: williammabaye@netscape.net
# From: williammabaye@netscape.net
# From: "JAMES STEIN" <steinjames1@netscape.net>
# From: "Alhaji Hamza Aliu." <shellpetrocoltd@sify.com>
# From: williammabaye@netscape.net
# From: "james nzama" <jamesnzama012@hotmail.com>
# From: "larry_ed1" <larry_ed1@libero.it>
# From: "james nzama" <jamesnzama012@hotmail.com>
# From: tonynjaba2@iol.pt
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: abmaryam <abmaryam@voila.fr>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: "SESAY MASSAQUOE" <semassaq@o2.pl>
# From: abmaryam <abmaryam@voila.fr>
# From: SAVIMBI <savimbi098@netscape.net>
# From: shadak_foundation12@tiscali.co.uk
# From: "Abu m.Sesay" <abuabu@o2.pl>
# From: rev_drosvaldopj@tiscali.co.uk
# From: jonathanbongani1@netscape.net
# From: jonathanbongani1@netscape.net
# From: jonathanbongani1@netscape.net
# From: "Balarabe Zamani" <balarabe_zamani@voila.fr>
# From: naybet@aeneasmail.com
# From: "DR,GAIUS OBASEKI" <dittrich2000@fastermail.com>
# From: "Martins Awele" <awele_martins@tiscali.co.uk>
# From: michealmumbaza@jumpy.it
# From: lee_tsong@tiscali.it
# From: "Mercy Kume" <mckume@yahoo.com>
# From: "Mohammed Abacha" <mohammed_abacha2004@indiatimes.com>
# From: "Mohammed Abacha" <mohammed_abacha2004@indiatimes.com>
# From: "Mohammed Abacha" <mohammed_abacha2004@indiatimes.com>
# From: bg-misc-owner@cs.CU
# From: mohammed abacha <moha@dixinet.com>
# From: contactiyang@postino.it
# From: "MRS. MARIAM ABACHA" <abachafamily20052005@yahoo.com>
# From: "Mr.Stephen Koseff" <koseft@katamail.com>
# From: Abel Guobadia <ab@merakdemo.com>
# From: "Rev Mark Bome" <bomefoundation2@voila.fr>
# From: "Abu M.Sesay" <abuabu3@pro.hu>
# From: "Abu M.Sesay" <abuabu3@pro.hu>
# From: DR RANI JUMA <dr.rani.ali.2001@caramail.com>
# From: "MR. JOHN PETERS" <mr_john_peters@telstra.com>
# From: "MR. JOHN PETERS" <mr_john_peters@telstra.com>
# From: "bongo wale" <bongowale2002@hotmail.com>
# From: DR RANI JUMA <dr.rani.ali.2001@caramail.com>
# From: claudiamafikeng@caltanet.it
# From: aminawazi@netscape.net
# From: aminawazi@netscape.net
# From: "Dr.Benard Mcarthy" <banking17@tiscali.co.uk>
# From: "Barr. Chris Edu" <edu2@fuorissimo.com>
# From: "Mr Chris Ogiemwonyi." <chri@mail.com>
# From: charityattention@netscape.net
# From: charityattention@netscape.net
# From: charityattention@netscape.net
# From: "Barr. Chris Edu" <ed@fuorissimo.com>
# From: "Barr. Chris Edu" <ed@fuorissimo.com>
# From: "MR JOHN DICKSON" <jon_dic101@quick.cz>
# From: "Dr (Mrs) BETTY PEDRO" <betty_pedro01@jumpy.it>
# From:Dan Wilson
# From:Dan Wilson
# From: "james obi" <jamesobi1@classicmail.co.za>
# From: "james obi" <jamesobi@classicmail.co.za>
# From: all-atl@eecs.UM
# From: "Dr Mrs Mariam Abacha" <mariamabacha@yahoo.com>
# From: "james obi" <jamesobi1@classicmail.co.za>
# From: "james obi" <jamesobi1@classicmail.co.za>
# From: "MRS. PATRIKA KOVAC" <errtty@hotmail.com>
# From: "MRS. PATRIKA KOVAC" <errtty@hotmail.com>
# From: "Shadak Shari" <shadak_shari5@albawaba.com>
# From: "Shadak Shari" <shadak_shari6@albawaba.com>
# From: "Shadak Shari" <shadak_shari@albawaba.com>
# From: "ROBERT MAJUS" <robe878@tiscali.it>
# From: "Engr. Ukot Thomas Ukot" <thomas_ukot1@rediffmail.com>
# From: "MRS. PATRIKA KOVAC" <ertrttyt@hotmail.com>
# From: "DR. HARRY OBUM" <harryobum@sudanmail.net>
# From: "Mr. Dicka Dumas" <dicka@galmail.co.za>
# From: "Mr. Dicka Dumas" <dicka@galmail.co.za>
# From: "DR. EKIYOH MARTINS" <ekiyohmartins@netscape.net>
# From: "Mr.Harry Hakeem" <harryhakeem1956@netscape.net>
# From: princefwbolkiah2000 <princefwbolkiah2000@yahoo.com>
# From: "John Mikado" <mjohn004@netscape.net>
# From: "John Mikado" <mjohn004@netscape.net>
# From: "MRS MAVIS KAKI" <johnkakiz@netscape.net>
# From: "MRS MAVIS KAKI" <johnkakiz@netscape.net>
# From: "Mr Frank" <frank13_@mailsurf.com>
# From: "info@crack-ag.com" <info@crack-ag.com>
# From: jamestshabalala@netscape.net
# From: jamestshabalala@netscape.net
# From: jamestshabalala@netscape.net
# From: "SAMSON K.MANI" <samson_k_mani01@voila.fr>
# From: "Mr frank" <frank13_@mailsurf.com>
# From: "oliver"<oliverfpaul@aib.com>
# From: "oliver"<oliverfpaul@aib.com>
# From: "Terry" <gimlabpnuipfi@rocketmail.com>
# From: sitholebaloy@netscape.net
# From: sitholebaloy@netscape.net
# From: sitholebaloy@netscape.net
# From: sitholebaloy@netscape.net
# From: "yaya" <dr_tyh@hotmail.com>
# From: "yaya" <dr_tyh@hotmail.com>
# From: "sessay massaquoe" <sessay1_7o2.pl@seeqmail.com>
# From: "sessay massaquoe" <sessay1_7o2.pl@seeqmail.com>
# From: "sessay massaquoe" <sessay1_7o2.pl@seeqmail.com>
# From: "Paul Jacksoncole." <mrp_jack@bankersmail.com>
# From: "BAR.MYKE UTAKI" <attorneymyke@justice.com>
# From: xiao gang <xg2004@ofir.dk>
# From: "Tony" <zlblzm@sohu.com>
# From: "Tony" <zlblzm@sohu.com>
# From: "Dr. mustafa mohammed" <mohammed_mustafa@voila.fr>
# From: "Dr. muystafa mohammed" <mohammed_mustafa@voila.fr>
# From: sunlolly@caltanet.it
# From: harryhakeem1956@netscape.net
# From: "FROM ME PLEASE REPLY" <rita20000@quick.cz>
# From: "MR BEKO EZE" <bek@macmail.com>
# From: "Charles Taylor" <charlestayloraap@iqsecure.com>
# From: mr john paul <john_paul@email.cz>
# From: "Kumalo Debe" <kumalodebe1@netscape.net>
# From: "oliver"<aiboliv@aib.com>
# From: "oliver"<aiboliv@aib.com>
# From: harryhakeem988@netscape.net
# From: harryhakeem988@netscape.net
# From: "MOHAMED  ZUBA" <muhab_zuba@ourwest.com>
# From: "chris" <chris_nwoke100@amnetsal.com>
# From: alfreddouglas2@virgilio.it
# From: "Lt. Col. Richard Egwu" <egwu_17@yahoo.co.uk>
# From: "Lt. Col. Richard Egwu" <egwu_17@yahoo.co.uk>
# From: "Lt. Col. Richard Egwu" <egwu_17@yahoo.co.uk>
# From: "Mattew Molefe" <mattewmolefe6@yehey.com>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "DR.WILLIAMS KOFFI" <dr_williams@atlas.cz>
# From: "BIKO ZULATO" <bikozulato@yahoo.co.uk>
# From: markbiya@netscape.net
# From: markbiya@netscape.net
# From: markbiya@netscape.net
# From: "Raad Ibrahim" <raad004@netscape.net>
# From: "Raad Ibrahim" <raad004@netscape.net>
# From: "Abu M.Sesay" <abu-m-sesay@eeism.com>
# ...
# From: "Mr. Moreno Garcia" <morenogarcia@web2mail.com>
# From: "Mrs.Mary Saleh Galal" <mrssalehgalal@myway.com>
# From: nelsonsmith033@terra.es
# From: Barrister Gareth Jones Mobile +44 703 184 4817
# From: "Barrister Gareth Jones" <info@bebemous.co.za>
# From: Barrister Gareth Jones=0D=0ATel: +44 703 184 4817=0D=0AFax: +44 870 4=
# From: "Edward Moore & Associates" <edwardmoore99@yahoo.co.uk>
# From: "Mr John Jasper" <johnp11@iwon.com>
# From: marie ange attah <attahmarieange23@hotmail.fr>
# From: Edward Moore & Associates(Urgent)
# From: "Edward Moore & Associates" <edward_moore22@yahoo.co.uk>
# From: Edward Moore & Associates(Urgent)
# From: "Edward Moore & Associates" <edward_moore22@yahoo.co.uk>
# From: Edward Moore & Associates(Urgent)
# From: "Edward Moore & Associates" <edward_moore22@yahoo.co.uk>
# From: Edward Moore & Associates(Urgent)
# From: "Edward Moore & Associates" <edward_moore22@yahoo.co.uk>
# From: Robert Williams <robertwills@pre.sltnet.lk>
# From: adnanhram@aim.com
# From: Michael Jones <michjones@mickyjones.co.uk>
# From: Koutaba jean <koutab0078@hotmail.com>
# From: Phillip Croce <bullfrog812@charter.net>
# From: asinthe nignan <asinthe_nignan33@hotmail.fr>
# From: Robert Williams <robertwills@pre.sltnet.lk>
# From: emekaben@aol.co.uk
# From: "Edward Moore & Associates" <edwardmoore99@yahoo.co.uk>
# From: "Mr. Gamudi Mboma" <gmboma2@hotmail.com>
# From: mrcolinshand20 <mrcolinshand20@poczta.pf.pl>
# From: richard bongo <richard_bongo112za@hotmail.com>
# From: richard bongo <richard_bongo112za@hotmail.com>
# From: Koutaba jean <koutab0025@hotmail.com>
# From: DR AHMED SHALAA <drahmed_sh14@hotmail.com>
# From: COLLINS LYONS <collins_lyons73@yahoo.co.uk>
# From: "Mr.Jonathan Mutambara" <rahim.attah1@virgilio.it>
# From: Mr.Jonathan Mutambara.
# From: "FREDERICK WILLIAMS." <fred_williams05@o2.pl>
# From: amir jasmin <amija_1035@hotmail.com>
# From: "Mahmud Azzam" <mamud_islandoil@yahoo.com.hk>
# From: "Mahmud Azzam" <mamud_islandoil@yahoo.com.hk>
# From: CHRIS ANDERSON <chris_anderson@universia.com.br>
# From: ben coroma <bencoroma12@hotmail.com>
# From: "MRS. LARISA SOSNITSKAYA" <larisasosnkayapawou@mail2russia.com>
# From:Mr.Kenneth Mashaba=0D=0AEmail:kmashaba@myway.com=0D=0ATel:=
# From: MR WILLIAM KABILA <williamkabila05@gmail.com>
# From: LIKA CHEUNG HOLDINGS LIMITED <joemelosi@charter.net>
# From: "MRS. LARISA SOSNITSKAYA" <larisasosnkayanxly@mail2russia.com>
# From: " MR james roberts" <james_roberts007@navegante.com.sv>
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding;
# From: "Dr. Paul A. Sule" <drpaulsule1950@o2.pl>
# From: john alison <johnali20@hotmail.com>
# From: "alimoheamed1" <alimoheamed1@mynet.com>
# From: "Mr. Joseph Chau." <info_unionbankofchain007@adelphia.net>
# From: Mr Paul Baloyi <patrickokonta10@virgilio.it>
# From: Mr. Paul Baloyi.
# From: Mr. Paul Baloyi.
# From: Mr Paul Baloyi <patrickokonta10@virgilio.it>
# From: Mr. Paul Baloyi.
# From: Mr. Paul Baloyi.
# From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: nabjib ibrahim <nabjib_n27@hotmail.fr>
# From: nabjib ibrahim <nabjib_n27@hotmail.fr>
# From: "Mr. Albert Sitholi" <sitholi@webmail.co.za>
# From: fredrick thambo <fredrick.thambo.107@hotmail.com>
# From: Barrister Fredrick Thambo=20
# From: Barrister Fredrick Thambo </STRONG></D=
# From: musa saladin <musa_saladin030@hotmail.com>
# From: "PETER NDABA" <peterndaba@fsmail.net>
# From: kouajo@hotmail.fr
# From: "DR DAVID RAY" <david_ray202@yahoo.co.uk>
# From: david_ray202@yahoo.co.uk
# From: JOHN ABOH <meetic@meetic.com>
# From: "Mikhail Khodorkovsky" <mikhail@yukosoil.com>
# From: koajoo_aka@yahoo.com
# From: theresa coleman <mrst5heresa@hotmail.fr>
# From:Reply-To:Subject:To:MIME-Version:Content-Type;
# From: JOSEPH hOPONU <hoponuj101@yahoo.co.jp>
# From: "A.B. Solarin" <alexandro_solarin1973@yahoo.co.uk>
# From: "Martins Mazuri" <mart_mazuri03@yahoo.ca>
# From: "Mr. Peter Leon" <mr66leon@hotmail.com>
# From: chantal kouakou <kouakou_chantou15@hotmail.fr>
# From: chantal kouakou <kouakou_chantou15@hotmail.fr>
# From: sahidi ngoma <sahidi_ngoma14@hotmail.fr>
# From: Capt James C Willians <officialmail@realmail.co.uk>
# From: "IRS"<refund@irs.gov>
# From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "MR. MARK ADAMS" <m_adams1102@walla.com>
# From: "MR. MARK ADAMS" <m_adams1102@walla.com>
# From: "bala kabore" <bala_kabore48@hotmail.fr>
# From: "DR.IDRISSA SEKK" <d_dudu@virgilio.it>
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: gerald zongo <geraldzongo_38@hotmail.fr>
# From: chantal kouakou <chant004@hotmail.fr>
# From: princess gesinta <princess_gesinta016@hotmail.fr>
# From: MR JAMES ROBERTS <williambrown@virgilio.it>
# From: Tim McCarron <pre91@pre.sltnet.lk>
# From: "Chief Anthony Enahoro. JP" <coalition_protect@yahoo.fr>
# From: "Richard Akintunde"<r.akintunde@yahoo.it>
# From: "Martins Akim" <martinsakim@handbag.com>
# From: "Dr. Ahmed Hassan" <ahassan1696@gmail.com>
# From: "Dr. Ahmed Hassan" <ahassan1696@gmail.com>
# From: "LUISA ESTRADA" <luisa@blue-conn.de>
# From:Evangelist Lindy Mike(Widow).
# From: "Evangelist Lindy Mike (Widow)." <evlindymike@myway.com>
# From:Evangelist Lindy Mike(Widow).
# From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: Edward Moore & Associates
# From: "Edward Moore & Associates" <edward.moore20@yahoo.com>
# From: Edward Moore & Associates
# From: "Edward Moore & Associates" <edward.moore99@yahoo.co.uk>
# From: "bjsri budak" <bjsri072@hotmail.com>
# From: Barrister Al Mohammed El Said <benmowilliamss@lawyer.com>
# From: Gary William <stella.sigcau4@virgilio.it>
# From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "Mr. Robin Shephard" <fredmaxwell@virgilio.it>
# From: "Martin J. Waghorn" <leonardmuller@virgilio.it>
# From:Mr. Martin J. Waghorn
# From: "Didan Kimati" <kimati_didan@excite.com>
# From: MR LAAD cologo <mrlaad_cologo13@hotmail.fr>
# From: Mr LAAD COLOGOManager,Audit/Account SectionAfrican Development BankOuagadougou Burkina-Faso    Dear FRIEND,   How are you today? Hope all is well. Please be informed that I have decided to contact you for a fund transfer transaction worth the sum of US$22,300,000.00 into your reliable bank account as the sole NEXT-OF-KIN to the foreign deceased customer of our bank (an International Billionaire French Businessman) who was killed with his entire family by PLANE-CRASH in Central England atmost 3 years ago. Since his death occured, no body have show up as his next of kin for the claim because the account is untraceable. Upon the investigation I carried out from his records, I found out that his foreign business consultant who would have trace the account died earlier before the deceased. Therefore, this is a confidential and sealed deal. For the success of this transaction, you should apply and act as the only existing NEXT-OF-KIN to the deceased which our bank will replace the deceased account information through proper documentation in position of your own account. This transaction is risk-free, it will never harm your good reputation in your society because no one can trace the account, and on the instant of the transfer of the fund into your account, the chapter of this transaction will be closed entirely. Note that in a business of this nature, the bank dont want to know your difference between the deceased country, religion or believe because our bank inheritance law is against that. So, it is a preference for us achieve this success without any problem.Please note down that once the fund get transferred into your account, you will take 39% of the total sum while the rest will be for me as I will arrange myself down to your country to take my share. I need your urgent response and include your private telephone/mobile numbers for easy communication.Please reply if you can be trusted in this deal.Thanks,  Mr.LAAD COLOGO.
# From: Mr LAAD COLOGO<BR>Manager,Audit/Account Section<BR>African Development Bank<BR></STRONG><SPAN id=EC_lw_1184178655_0 style="BACKGROUND: none transparent scroll repeat 0% 0%; CURSOR: hand; BORDER-BOTTOM: #0066cc 1px dashed; HEIGHT: 1em"><STRONG>Ouagadougou Burkina-Faso</STRONG></SPAN><BR><STRONG>&nbsp;&nbsp;&nbsp; <BR>Dear FRIEND,&nbsp; <BR>&nbsp;<BR>How are you today? Hope all is well. Please be informed that I have decided to contact you for a fund transfer transaction worth the sum of US$22,300,000.00 into your reliable bank account as the sole NEXT-OF-KIN to the foreign deceased customer of our bank (an International Billionaire French Businessman) who was killed with his entire family by PLANE-CRASH in Central England atmost 3 years ago. Since his death occured, no body have show up as his next of kin for the claim because the account is untraceable. Upon the investigation I carried out from his records, I found out that his foreign business consultant who would have trace the account died earlier before the deceased. Therefore, this is a confidential and sealed deal.<BR>&nbsp;<BR>For the success of this transaction, you should apply and act as the only existing NEXT-OF-KIN to the deceased which our bank will replace the deceased account information through proper documentation in position of your own account. This transaction is risk-free, it will never harm your good reputation in your society because no one can trace the account, and on the instant of the transfer of the fund into your account, the chapter of this transaction will be closed entirely.<BR>&nbsp;<BR>Note that in a business of this nature, the bank dont want to know your difference between the deceased country, religion or believe because our bank inheritance law is against that. So, it is a preference for us achieve this success without any problem.<BR>Please note down that once the fund get transferred into your account, you will take 39% of the total sum while the rest will be for me as I will arrange myself down to your count
# From: harryugo@zipmail.com.br
# From: mike kone <mikkon5@hotmail.fr>
# From: "Dave Yorke." <dyorke@freenet.de>
# From: "Mrs  Farah Al-hashemi" <msalhak@yahoo.com>
# From: "Mrs  Farah Al-hashemi" <msalhak@yahoo.com>
# From: Eric Johnson <ericjohnson6@myway.com>
# From: sahidi ngoma <sahidi_ngoma13@hotmail.fr>
# From: mike kone <mikeko018@hotmail.fr>
# From: tony anthony <tonywach4@hotmail.com>
# From: PROF CHARLES SOLUDO <mrsbakare@rediffmail.com>
# From: urgentmatter@sunumail.sn
# From: urgentmatter@sunumail.sn
# From:Subject:To:MIME-Version:Content-Type;
# From: "REV.WILSON MORGAN" <inheritance_fund00@o2.pl>
# From: "REV.WILSON MORGAN" <inheritance_fund00@o2.pl>
# From: janetbradford@sunumail.sn
# From: janetbradford@sunumail.sn
# From: Gary William <stella.sigcau4@virgilio.it>
# From: "Mr Aphisak Tantiworawong" <aphisak.project@yahoo.co.th>
# From: J_KEMPWELCH01 <jkemp1968@yahoo.co.uk>
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "Mr.Morgan Wimpoe" <morgan.wimpoe01@yahoo.com>
# From: <alima_kkk10@centrum.cz>
# From: "Adekunle michael." <dmike0013@o2.pl>
# From: QIN LI WANG <buddycrk@fuse.net>
# From: idris makafi <idris_makafi167@hotmail.fr>
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "DR. CLEMENT ASUZU" <clementasuzu@yahoo.it>
# From: emma tano <ball16@hotmail.fr>
# From: "Bank of America" <Banking@Bankofamerica.com>
# From: Mou Xinsheng <spiritsanct@onetel.com>
# From: "Prof.Charles.C.Soludo" <cbnpayment.org@host45.porar.com>
# From: matinread@turbonett.com
# From: "jen_marthin" <jen_marthin@centrum.sk>
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From:Reply-To:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "aziz moustafa" <aziz_moustafa100@hotmail.com>
# From: MM BB <mbd095@hotmail.com>
# From: "Mrs Farah al-Hashemi" <mrsfarah30@yahoo.co.uk>
# From:Mrs Farah al-Hashemi :I will appreciate your reply
# From: kanazoe alidaa <kanazoe_alidaa0007@hotmail.fr>
# From: williams susan <wil_li_net0064@hotmail.fr>
# From: "bajoga bajoga" <bajoga@latinmail.com>
# From: "Robert Zulugan." <rubzuul@freenet.de>
# From: "Mrs. Farah al-Hashemi" <mrsfarah30@yahoo.co.uk>
# From:Mrs Farah al-Hashemi :I will appreciate your reply
# From: Jaron Abbas <jaron_abbass@yahoo.de>
# From: Jaron Abbas <jaron_abbass@yahoo.de>
# From: adams swill <adams5swill@hotmail.com>
# From: susan  john <susan_john203@yahoo.co.uk>
# From: "GOBLOUSO SOLANGE " <gosolanges@latinmail.com>
# From: Prince David Djedjess <djedjess007@hotmail.com>
# From: adams kabora <adams_kabora11@hotmail.com>
# From: adams kabora <adams_kabora31@hotmail.com>
# From: "Christopher  Wilson" <christopherwilson@sunumail.sn>
# From: christopherwilson@sunumail.sn
# From:Subject:To:MIME-Version:Content-Type;
# From:Sarat Hassan
# From:Sarat Hassan<BR>
# From: <chantalveroniq2@yahoo.fr>
# From: JOHN HILL <johnhill87@aol.fr>
# From: CAROL HARVEY <esoil_gasltd231@yahoo.com.hk>
# From:Subject:To:MIME-Version:Content-Type;
# From: isedore lawan <mr_isedore_lawan0053@hotmail.fr>
# From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: "Mr A.B Solarino" <benjaminosolarin4u@yahoo.co.uk>
# From: HARRISON FELISSA <felissajen115@hotmail.fr>
# From: MR NELSON BROWN <mrscarolyn@virgilio.it>
# From: "Sunoco Sun Oil Company Ltd" <onlineli@phreego.com>
# From: "Sunoco Sun Oil Company Ltd" <onlineli@phreego.com>
# From: joel thomson <joelthomson804@hotmail.com>
# From: HANG SENG BANK <peter@hangsengbank.com.hk>
# From:Subject:To:MIME-Version:Content-Type;
# From:Miss Grace Onuoha
# From:Miss Grace Onuoha
# From:Miss Grace Onuoha </DIV>  <DIV>&nbsp;</DIV>  <DIV>In brief introduction, I am Miss Grace Onuoha from the republic of South Afirca , I am 22 years old I have two younger ones, John and Linda Onuoha, we have lost our Father and Mother. My late Father Mr. Mustapha Onuoha before his death
# From: "Steven Lee"<stevnlee010@sify.com>
# From: <ch_20007@centrum.cz>
# From:Subject:To:MIME-Version:Content-Type:Content-Transfer-Encoding:Message-ID;
# From: LIUYANMAILPOST <liuyan_office@yahoo.com.hk>
# From: "MR. KENNETH MASHABA" <kmashaba1@myway.com>
# From:Mr.Kenneth Mashaba
# From: "The SHIGA BANK LTD" <ooxxee.ooxxeee03@laposte.net>
# From: "Louis (Business).." <femirhodes@virgilio.it>
# From: "The SHIGA BANK LTD" <ooxxee.ooxxeee03@laposte.net>
# From: "MRS. ANNAH KRUGA" <a_annah50@hotmail.com>
# From: nafmohd101@yahoo.fr
# From: "julia.chen.shenhua.group@hotmail.com" <ooxxee.ooxxeee03@laposte.net>
# From: nelson mansuguri <mansuguri63@hotmail.com>
# From: kali oddo <kali_oddo017@hotmail.fr>
# From: "james bongani" <jamesbongani10015@latinmail.com>
# From: us zongo <us_zongo35@hotmail.fr>
# From: Mr Usman Zongo African Development Bank (ADB)Ouagadougou , Burkina Fa=
# From:&nbsp;Mr Usman Zongo&nbsp;<BR>African Development Bank (ADB)<BR>Ouagad=
# From: Vincent Cheung <gladvince01@yahoo.co.uk>
# From: "BARR.JONATHAN WRIGHT" <wrightchember@gmail.com>
# From: petertaylor <petertayloruk2@yahoo.de>
# From: Jaron Abbas <jaron_abbass@yahoo.de>
# From: patrick jombo <mrjombo23@hotmail.fr>
# From: abl musa <ablmusa_03@hotmail.fr>
# From: "Dr. David Smith" <dickson_robert1@virgilio.it>
# From: IDRIS ADAMU <idris40adamu@hotmail.fr>
# From: KENNETH OBI <kennethobia5@hotmail.com>
# From: "HENRY ALLEN" <henryallenci@seznam.cz>
# From: Mr John Davids <mobeef@birch.net>
# From: Khaled Bin al- Walid <mobeef@birch.net>
# From: Mother Doris Killam <motherdorisk93@hotmail.com>
# From: "Fernando Gonzalez" <best.list@laposte.net>
# From: "From: Dr. Jackson Gaius-Obaseki" <tony_eselu2@virgilio.it>
# From: Dr. Jackson Gaius-Obaseki
# From: michealagu0255@zipmail.com.br
# From: ali sherif <ali_sherif252@hotmail.fr>
# From: Mr Ali Sherif. African Development Bank (ADB)Ouagadougou , Burkina Fa=
# From: Mr Ali Sherif. <BR>African Development Bank (ADB)<BR>Ouagadougou=
# From: Dr Usman Ibrahim Danko <drusmanibrahimtg08@hotmail.fr>
# From: Mother Doris Killam <motherdorisk61@hotmail.com>

# %% [markdown]
# Because * matches zero or more instances of the pattern indicated on its left, and . is on its left here, we are able to acquire all the characters in the From: field until the end of the line. This prints out the full line with beautifully succinct code.
#
# We might even go further and isolate only the name. Let’s use re.findall() to return a list of lines containing the pattern "From:.*" as we’ve done before. We’ll assign it to the variable match for neatness. Next, we’ll iterate through the list. In each cycle, we’ll execute re.findall again, matching the first quotation mark to pick out just the name:

# %%
match = re.findall("From:.*", fh)

for line in match:
    print(re.findall('\".*\"', line))
# Out:
# ['"MR. JAMES NGOLA."']
# ['"Mr. Ben Suleman"']
# ['"PRINCE OBONG ELEME"']
# ['"PRINCE OBONG ELEME"']
# ['"Maryam Abacha"']
# []
# ['"Barrister tunde dosumu"']
# ['"William Drallo"']
# ['"MR USMAN ABDUL"']
# ['"Tunde  Dosumu"']
# []
# ['"Dr.Sam jordan"']
# []
# []
# []
# ['"COL. MICHAEL BUNDU"']
# ['"MRS MARIAM ABACHA"']
# ['" DR. ANAYO AWKA "']
# ['" DR. ANAYO AWKA "']
# ['"Victor Aloma"']
# ['"Victor Aloma"']
# ['"JAMES NGOLA"']
# ['"MARTIN CHIME"']
# ['"Mr George Mboro"']
# ['"MARTIN  CHIME"']
# ['"MARTIN  CHIME"']
# []
# []
# ['"ADE WILLIAMS"']
# []
# ['"MRS. M SESE-SEKO"']
# ['"obina okoro"']
# ['"DR. JAMES  ALBERT"']
# []
# []
# ['"MR FRED OBI."']
# ['"mbeki ngumeni"']
# []
# ['"Mr. David Agu"']
# ['"bell.idr bell.idr"']
# ['"idris.bello idris.bello"']
# []
# ['"CLEMENT APUTE"']
# ['"MR GODWIN IGBUNU"']
# ['"bell.idr bell.idr"']
# ['"Mr. David Agu"']
# ['"deborah kabila"']
# []
# []
# ['"MOHAMMED BELLO (Ph.D)"']
# ['"PETER WILLIAMS"']
# ['"Oliveira Savimbi"']
# ['"Mr. Daniel Osondu"']
# []
# []
# ['"Ruka"']
# ['"IDRIS ADAMU"']
# ['"DR.  SANNI  SABO"']
# ['"DR.  SANNI  SABO"']
# ['"Ibrahim Galadima"']
# []
# ['"Mohammed Abacha"']
# ['"PRINCE TUNDE O ADISARAKI"']
# ['"judeestrada"']
# ['"JONATHAN  MOKOENA"']
# []
# ['"res bob12"']
# ['"LADY MARYAM ABACHA "']
# ['"MR.TUNDE  BALOGUN"']
# ['"MR.BENSON  ATTAH"']
# ['"MR.BENSON  ATTAH"']
# ['"MR.TUNDE  BALOGUN"']
# ['"LADY MARYAM ABACHA "']
# ['"DR.  SANNI  SABO"']
# ['"Dr Luisa Pimental Estrada"']
# ['"Graham Douglas"']
# []
# []
# []
# ['"savimbidenis@www.com"']
# ['"Nsekou Mobutu Sesekou"']
# ['"DR. BELLO MUSA"']
# []
# []
# ['"=?iso-8859-1?Q?lawrence.smith?="']
# ['"DONALD  ATTAH"']
# ['"daniel innocent"']
# ['"deborah kabila"']
# ['"peter"']
# ['"joseph benson"']
# []
# ['"pat odogu"']
# []
# ['"PATRICK  MOHAMMED"']
# ['"PATRICK  MOHAMMED"']
# ['"Mr. Lawrence Abba"']
# []
# []
# ['"MALCOM TUTU"']
# []
# ['"MALCOM TUTU"']
# []
# []
# ['"MR. DONALD ATTAH"']
# ['"Dr mariam abacha"']
# []
# ['"jeffery hill"']
# ['"malcom tutu"']
# ['"malcom tutu"']
# ['"sam aluko"']
# ['"GEORGE  KABILA"']
# ['"CYRIL AKWARANDU"']
# ['"CYRIL AKWARANDU"']
# ['"MR.YARO BAMIYI"']
# ['"barr.femi"']
# ['"DR DOUGLAS NWANKWO"']
# ['"Mrs. Safi  Al Mustapha"']
# ['"Mrs. Safi  Al Mustapha"']
# ['"Dr Mariam abacha"']
# ['"Dr.Moses"']
# ['"Dr.Moses"']
# ['"DR. OLUSEGUN SMITH"']
# ['"Dr. Bernard Makelele"']
# []
# ['"kaseke kenneth"']
# []
# ['"DR ABDULL RASAQ"']
# ['"DR ABDULL RASAQ"']
# ['"williame ume"']
# []
# ['"KENNETH ILOKA"']
# []
# []
# ['"Oliveira Savimbi"']
# ['"James DeSouza."']
# ['"James DeSouza."']
# ['"James DeSouza."']
# ['"James DeSouza."']
# []
# ['"PAPA BELLO"']
# ['"Dr. Don Arturo Ramitez."']
# ['"E E"']
# ['"KABILA"']
# ['"Oliveira Savimbi"']
# ['"MR DANIEL KALU"']
# []
# []
# []
# []
# []
# ['"NOSA"']
# ['"MR TUNDA"']
# ['"DR STEPHEN UMAH"']
# ['"Dr stephen umah"']
# ['"JOHN CHOMA"']
# ['"DR TONY COLE"']
# ['"DR TONY COLE"']
# ['"DR. GOODWILL MPENZA"']
# []
# ['"Engr. William Goye"']
# ['"FRANK  GUEI JNR."']
# []
# []
# ['"WILLIAM   OKAFOR"']
# []
# ['"DR STEPHEN AKIGA"']
# ['"DR STEPHEN AKIGA"']
# ['"Ola Kelvin"']
# []
# ['"MR.DON UBALA,"']
# ['"Dr. Wilson"']
# []
# []
# ['"Oliveira Savimbi"']
# ['"Dr Pascal Ugoti"']
# ['"Dr Pascal Ugoti"']
# ['"Professor Frank Obi"']
# ['"koffi joseph"']
# ['"ENGR: KUMALO DILIZA"']
# ['"MR GBENRO ADEGBOLA"']
# ['"MAKO OKERE"']
# ['"GBENGA ALUKO"']
# ['"MR, DOMAS K, YANK"']
# ['"Oliveira Savimbi"']
# ['"DR. PAUL BABS."']
# ['"grace abba-gana"']
# ['"salatu_ibru300"']
# ['"ADEROJU MUYIWA"']
# ['"Mr Olu Martins"']
# ['"maryam  abacha"']
# ['"MRS ROSE SAVIMBI"']
# []
# []
# ['"Bola  Harry"']
# ['"Bola  Harry"']
# ['"DR.TUNJI OWO"']
# []
# ['"DR.TUNJI OWO"']
# []
# []
# ['"ENGR ZULUMAKALENI."']
# ['"DR (MRS) MARIAM ABACHA"']
# ['"MR. TAMBO"']
# []
# ['"Dr. Bouguiba Samuel"']
# []
# []
# []
# []
# ['"MRS, AMINA BOLA IGE"']
# ['"Andy Bello"']
# ['"Andy Bello"']
# ['"AHMED MARTINS. D"']
# []
# ['"Mr.Kola Awosika"']
# ['"SAAD A.ALLI"']
# ['"JOHNSON ABBAS"']
# ['"Dr.Tito Sithole."']
# []
# ['"MADAM MARYAM"']
# ['"DELE MARTINS"']
# []
# ['"Mrs. Mariam M. Sese-seko"']
# ['"MICHAEL AFOLABI"']
# []
# []
# ['"CHUKS ANTHONY"']
# ['"godfrey eche3"']
# ['"godfrey eche3"']
# ['"Muhammad Khalil Hasan"']
# ['"Muhammad Khalil Hasan"']
# ['"Hamzat Sulaiman"']
# ['"keven wei"']
# []
# []
# ['"Mr Chuks Anthony"']
# ['" JOHNSON ELENDU "']
# ['"Mike Jide"']
# ['"Mike Jide"']
# []
# ['"Fred Mbonu"']
# ['"Fred Mbonu"']
# []
# []
# ['"Mrs. Mariam M. Sese-seko"']
# ['"MakamSomo"']
# ['"Engr. Musa  Akim."']
# ['"Engr. Musa  Akim."']
# ['"DR.MATTHEW OKOYE"']
# ['"abram nkomo"']
# []
# []
# ['"Mariam Abacha"']
# []
# ['"PRINCE FOLU FADAKA"']
# []
# ['"Harry O Harry"']
# []
# ['"PRINCE WILLIAMS"']
# ['"PRINCE M  WILLIAMS"']
# ['"MRS CECILIA  AKU"']
# []
# ['"FRANK BELLO"']
# ['"FRANK BELLO"']
# ['"Mr. Mike Obodoh"']
# ['"Barrister. Bassey  Owo"']
# ['"MUYIWA IGE"']
# ['"Dr.Tunde Cole"']
# ['"Dr Tunde Cole"']
# ['"williamume"']
# ['"Mr.Philip Jones"']
# []
# []
# ['"LEO  WILLIAMS"']
# []
# ['"MRS MARY SANKOH"']
# ['"Mr.Bom Uche"']
# ['"Mr.Bom Uche"']
# []
# ['"Mr. Daniel Abass."']
# []
# []
# ['"CHIEF(DR.)BODE GEORGE"']
# ['"CHIEF(DR.)BODE GEORGE"']
# ['"GREGORY PREMIER"']
# ['"....."']
# ['"Mr.Fred Obi"']
# []
# []
# []
# ['"daniel bello"']
# ['"Mohammed Abacha"']
# ['"Mohammed Abacha"']
# ['"mrs m mbeki"']
# ['"Kola Daniel"']
# []
# []
# []
# []
# []
# ['"Francis Sonto Mbomam"']
# []
# []
# []
# []
# ['"Pandindra"']
# []
# []
# ['"Dr .Titi okonkwo"']
# ['"Dr .Titiokonkwo"']
# ['"Godwin Ekpontu Sangana, Esq"']
# ['"Godwin Ekpontu Sangana, Esq"']
# ['"Godwin Ekpontu Sangana, Esq"']
# ['"Godwin Ekpontu Sangana, Esq"']
# []
# ['"Fadaka Randebe"']
# ['"Fadaka Randebe"']
# []
# ['"First Bank Nig. Plc.( Dr. Femi Johnson.)"']
# ['"carlos savimbi"']
# []
# ['"CHIEF(DR.)BODE GEORGE"']
# []
# ['"ALI AHMED"']
# ['"Abu Kyari."']
# []
# ['"Joseph Savimbi"']
# ['"Joseph Savimbi"']
# ['"prince george duke"']
# []
# ['"Mr. Jeffrey Daniels"']
# ['"Mr. Jeffrey Daniels"']
# ['"ADA USMAN!"']
# ['"Daniel  Kargbu"']
# ['"Mr. John Nlobo"']
# []
# []
# ['"Dr.Kunle Owolo"']
# ['"Dr.Kunle Owolo"']
# ['"MRSJENNIFER KOBE"']
# []
# ['"DR THOMAS AUDU"']
# []
# []
# []
# ['"Michael Stevens Junior."']
# ['"Hajia Maryam Abacha"']
# ['"Hajia Maryam Abacha"']
# ['"BARRISTER MATHEW IKE"']
# []
# ['"MR.ODIASE GEORGE"']
# ['"DEACON ZIK R. DON"']
# ['"Nzanga Mobutu"']
# []
# []
# ['"DR.MUHAMMED MUSTAFA"']
# ['"BARRISTER, HOPKINS MBEKI"']
# []
# []
# ['"Mr Ugochukwu .W"']
# []
# []
# []
# []
# []
# ['"DR. AKIN DADA."']
# ['"barrister vincent usman"']
# ['"JAMIE  OPUKU."']
# []
# ['"mona noah"']
# ['"MICHEAL  OSSAI"']
# []
# []
# ['"Peter Bongo"']
# []
# ['"maryaabacha8 maryam "']
# []
# ['"maryaabacha8 maryam "']
# []
# ['"H B"']
# []
# []
# []
# []
# ['"DR. GODWIN KALALA"']
# []
# []
# []
# []
# []
# []
# ['"vino koni"']
# []
# ['"DAVIDS ANDERSON."']
# []
# []
# []
# []
# []
# ['"Yetunde Bassey"']
# ['"Yetunde Bassey"']
# ['"lary kamokai"']
# ['"micheal ado santigo"']
# []
# []
# ['"DR. George Ibrahim Quattara"']
# ['"Mr..John Chukwu"']
# ['"DR BELLO BATURE"']
# ['"maryaabacha8 maryam "']
# []
# ['"Mrs. Juliet Bello."']
# ['"Mrs. Serena  Jones"']
# []
# ['"chuks Anthony"']
# []
# []
# ['"MR.WILLIAM"']
# ['"MR.WILLIAM"']
# []
# []
# []
# ['"Nelson Abia"']
# ['"MR ALI AMED"']
# ['"muhammed abacha"']
# ['"HASSAN DIKO"']
# ['"OLUWATOBI E.BOYE"']
# ['"OLUWATOBI E.BOYE"']
# ['"Mr Nelson Abia"']
# ['"Fred Okoli"']
# ['"haji musa diya"']
# ['"haji musa diya"']
# ['"From: Mrs. Victoria Bucknor"']
# ['"From: Mrs. Victoria Bucknor"']
# ['"From: Mrs. Victoria Bucknor"']
# ['"From: Mrs. Victoria Bucknor"']
# []
# []
# ['"prince duke"']
# ['"MRS M. SESE SEKO"']
# []
# ['"Mrs.Floxy Page"']
# ['"PETER OKOYE"']
# ['"PETER OKOYE"']
# ['"MRS.MARYAM ABACHA"']
# ['"MRS M. SESE SEKO"']
# ['"MOHAMMED"']
# ['"MOHAMMED"']
# ['"MOHAMMED"']
# ['"HAJIA MARYAM ABACHA"']
# []
# []
# []
# ['"MRS AMINA MOHAMMED"']
# []
# ['"Dr.Faroq Uztaz[Regional Director]"']
# []
# []
# ['"Mr Ugochukwu"']
# ['"from prince duke"']
# ['"from prince duke"']
# []
# ['"Mr.Michael Dohn"']
# ['"Mr.Michael Dohn"']
# []
# []
# []
# ['"DR. MRS. MARIAM ABACHA"']
# ['"MR MICHAEL EWALD"']
# []
# []
# []
# []
# []
# ['"MOHAMMED ABACHA"']
# ['"MOHAMMED ABACHA"']
# ['"MOHAMMED ABACHA"']
# ['"MOHAMMED ABACHA"']
# ['"MOHAMMED ABACHA"']
# ['"MARK AKPU"']
# []
# ['"Mr. Nasser Nasiri."']
# ['"Mr. Nasser Nasiri."']
# ['"Mr. Nasser Nasiri."']
# ['"sogolo_hmd@juno.com"']
# []
# ['"prince duke"']
# []
# []
# []
# []
# []
# ['"PETER BUNO"']
# ['"PETER BUNO"']
# []
# ['"ABDULKAREEM USMAN"']
# ['"Mr. Duke Nze"']
# ['"Mr. Duke Nze"']
# ['"Phill Ipenza"']
# []
# ['"DR DONALD"']
# []
# ['"NETHERLOTTO CORPORATION."']
# ['"MR.DANDY NNAJI"']
# ['"MR.DANDY NNAJI"']
# ['"PETERSON BULINGA"']
# []
# []
# []
# []
# []
# []
# ['"DR Peter Clapton"']
# []
# []
# ['"DR Peter Clapton"']
# []
# []
# ['"DR Peter Clapton"']
# []
# []
# ['"DR Peter Clapton"']
# []
# []
# []
# ['"MUSA AHMED ZULU"']
# []
# []
# []
# ['"Fred Okoli"']
# ['"Fred Okoli"']
# ['"MR.lucman Watson"']
# ['"KAZEEM AHMED"']
# []
# []
# []
# ['"MR FEMI MARTINS"']
# ['"laurent_nkono@zwallet.com"']
# ['"MRS. MARIAM ABACHA (WIDOW)."']
# []
# ['"Mohammed Mustafa"']
# []
# ['"THEMBI"']
# []
# ['"Carl Eblon"']
# ['"DAVIS TUTU"']
# ['"SAM KOROMA"']
# ['""']
# []
# ['"Rose Savimbi"']
# ['"From Mr Nelson Bidi ."']
# ['"From Mr Nelson Bidi ."']
# ['"From Mr Nelson Bidi ."']
# []
# []
# ['"FROM MRS RAMA IDRIS"']
# ['"FROM  PRINCE WILLIAMS  TAYOLR."']
# ['"FROM  PRINCE WILLIAMS  TAYOLR."']
# []
# ['"collins"']
# ['"collins"']
# []
# ['"DR OKON PHILIP"']
# ['"Donga Kabaka"']
# []
# ['"MR IBRAHIM YADUDU."']
# ['"DR. JOHNSON KENNETH"']
# ['"DR. JOHNSON KENNETH"']
# []
# []
# []
# ['"DANJUMA WILLIAMS M"']
# []
# []
# ['"KEN GOMAN"']
# []
# []
# ['"george akin"']
# []
# []
# ['"J.C.G"']
# ['"oliver  yengeni"']
# []
# ['"matthew molefe"']
# []
# []
# []
# []
# []
# ['"James Mercy Sankoh"']
# ['"James Mercy Sankoh"']
# ['"Mr Zakir Mahmood"']
# ['"Mr Zakir Mahmood"']
# ['"MR. JAMES NICHOLAS"']
# ['"Dr.Wahid Mallam"']
# []
# ['"MR. BASIL EZE"']
# ['"Dr. Felix William"']
# []
# []
# []
# ['"KAMARA WILLIAM"']
# ['"MRS.ROSE OBASEKI"']
# ['"jj_walter9@netzero.com"']
# []
# ['"Dardossi"']
# []
# []
# ['"Mrs. Jumai Abdul Azad."']
# []
# ['"Mariam Mustapha"']
# []
# []
# ['"Robinson Dike"']
# ['"Robinson Dike"']
# ['"Robinson Dike"']
# []
# []
# ['"kolapo omidire"']
# []
# []
# []
# []
# []
# []
# []
# []
# ['"MR JOHN MENSAH"']
# ['"Mr. Zakir Mehmood"']
# []
# []
# ['"MRS LOI C. ESTRADA"']
# []
# []
# ['"Susan Martins"']
# []
# []
# ['"frank damas"']
# ['"PRINCE OGO"']
# ['"PRINCE OGO"']
# ['"blessed ogbe"']
# ['"PRINCE CHARLES ZUMA"']
# []
# ['"DR WILLIAMS FREDRICK"']
# []
# ['"SA"']
# []
# []
# ['"michael nkomo"']
# ['"michael nkomo"']
# ['"JONAS SAVIMBI"']
# ['"aishatu            ahmed"']
# ['"JOHNSON SAVIMBI"']
# ['"JOHNSON SAVIMBI"']
# ['"JOHNSON SAVIMBI"']
# ['"JOHNSON SAVIMBI"']
# []
# []
# []
# []
# ['"Mr. Zuhair Idris"']
# ['"Mr. Zuhair Idris"']
# ['"SA"']
# ['"ahmed abu"']
# ['".."']
# ['"FROM DANIEL TUNDE"']
# ['"Mr Richard Akwasi"']
# []
# []
# ['"KEN AMOBI"']
# ['"Dr. Lukman Rilwanu"']
# []
# ['"Usman Ramat"']
# ['"Usman Ramat"']
# []
# []
# ['"Barrister Maxwell Obiekwu ."']
# ['"MARIAM ABACHA"']
# ['"David Aku"']
# []
# ['"MR JERRY OZUBA"']
# []
# ['"Dr. Kelly William"']
# ['"Susan Martins"']
# ['"Richard Akueze"']
# ['"MADAM STELLA SIGCAU"']
# ['"MADAM STELLA SIGCAU"']
# ['"jeffersila04"']
# []
# ['"Peter Saseh"']
# []
# ['"fred mende"']
# []
# ['"Engr Mansur Ahmed"']
# []
# []
# []
# []
# ['"Dr. Mchenry Douglas"']
# []
# []
# ['"Mr. Kizie Mulumba"']
# ['"Mr. Kizie Mulumba"']
# ['"MR. PASCAL IBE"']
# []
# ['"mariam abacha"']
# []
# []
# ['"mailto:ike_oba1@yahoo.co.uk"']
# []
# ['"mailto:ike_oba1@yahoo.co.uk"']
# []
# []
# []
# []
# []
# []
# ['"Kelly William"']
# []
# ['"pikka saaiman"']
# ['"Frank Shabalala"']
# []
# []
# []
# []
# ['"MOHAMMED ABACHA"']
# ['"DR.LUISA ESTRADA"']
# ['"William Fufua"']
# ['"FROM  DR.  HASSOUN   ODHIAMBO"']
# ['"FROM  DR.  HASSOUN   ODHIAMBO"']
# []
# []
# ['"MRS. LINDA CAMARA."']
# ['"DR. MARCUS COLE"']
# ['"FROM  DR.  HASSOUN   ODHIAMBO."']
# []
# ['"dr_frances"']
# ['"dr_frances"']
# []
# []
# []
# []
# []
# ['"James Obulu"']
# ['"James Obulu"']
# ['"Oladimeji Afolabi"']
# []
# []
# []
# ['"Chamberlin Klugman"']
# []
# ['"Dr,A. Almack."']
# ['"PRINCESS"']
# []
# []
# []
# ['"cyril8"']
# []
# ['"MATAMELA C. RAMAPHOSA"']
# []
# []
# ['"Mercy Kume"']
# ['"Princess Ifeoma."']
# ['"Princess Ifeoma."']
# ['"Mr.Chan Fung."']
# ['"SAMSON K.MANI"']
# []
# []
# []
# ['"DR. ABU HASSAN"']
# []
# []
# []
# []
# ['"AHMED SANI"']
# ['"p.mass"']
# ['"Mr.Johnson Gube"']
# ['"monica martins"']
# []
# []
# ['"john carlos"']
# ['"PRINCESS"']
# ['"Thomas Chilunda"']
# ['"Mercy Kume"']
# []
# []
# ['"Daniel  Mukaila"']
# ['"Daniel  Mukaila"']
# ['"Daniel  Mukaila"']
# ['"Mr.Kizie Mulumba"']
# []
# ['"mr   kala  kabila"']
# []
# []
# ['"Dr.Tony Williams"']
# ['"BUNOR DICKINS"']
# ['"Reverend Ngoly"']
# ['"hassanahmed"']
# ['"MRS. LINDA CAMARA."']
# ['"Mr Bruno Williams"']
# ['"MR. PASCAL IBE"']
# ['"mohammed .s. abacha"']
# ['"Okpara Addey"']
# ['"Mr Stephen Bello"']
# ['"MRS, FATIMA RASHEED KHALIFA"']
# []
# ['"MR  COLINS  BROWN"']
# ['"john paul"']
# ['"john paul"']
# ['"Dr  Mrs  Estrada"']
# ['"Dr  Mrs  Estrada"']
# ['"Philip Dickson"']
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Mrs Juliana Faith Peters"']
# []
# ['"Mrs Juliana Faith Peters"']
# []
# ['"Bakura BJ Zamani"']
# ['"Bakura BJ Zamani"']
# ['"Mrs. Monica Kofi"']
# []
# ['"PRINCESS HASIHATU SESSEY COLA."']
# []
# []
# ['"daniel kabila"']
# []
# ['"Mrs Fatima Rasheed Khalifa"']
# []
# []
# []
# []
# ['"Dr Frank Obi"']
# []
# []
# []
# []
# []
# []
# []
# []
# ['"markduke2004"']
# ['"Lawyer"']
# []
# ['"SUSAN SHABANGU"']
# []
# []
# ['"SESAY MASSAQUOE"']
# ['"SESAY MASSAQUOE"']
# ['"SESAY MASSAQUOE"']
# []
# []
# ['"MR GEORGE AMACHREE"']
# ['"MR GEORGE AMACHREE"']
# ['"MR GEORGE AMACHREE"']
# []
# []
# []
# []
# []
# []
# ['"boyd ololo"']
# ['"susan shabangu"']
# ['"hubert kliuvert"']
# ['"williams\\.onwa"']
# ['"Josef Bala"']
# []
# ['"MR.MICHEAL EDET DUKE"']
# ['"MR.MICHEAL EDET DUKE"']
# ['"MR.MICHEAL EDET DUKE"']
# ['"MR.MICHEAL EDET DUKE"']
# ['"MR, MIKE KOFI"']
# ['"Abu m.Sesay"']
# []
# ['"SESAY MASSAQUOE"']
# ['"SESAY MASSAQUOE"']
# ['"SESAY MASSAQUOE"']
# []
# []
# []
# ['"JAMES STEIN"']
# ['"Alhaji Hamza Aliu."']
# []
# ['"james nzama"']
# ['"larry_ed1"']
# ['"james nzama"']
# []
# ['"SESAY MASSAQUOE"']
# ['"Abu m.Sesay"']
# ['"Abu m.Sesay"']
# ['"Abu m.Sesay"']
# ['"SESAY MASSAQUOE"']
# ['"SESAY MASSAQUOE"']
# []
# ['"SESAY MASSAQUOE"']
# ['"SESAY MASSAQUOE"']
# ['"SESAY MASSAQUOE"']
# []
# []
# []
# ['"Abu m.Sesay"']
# []
# []
# []
# []
# ['"Balarabe Zamani"']
# []
# ['"DR,GAIUS OBASEKI"']
# ['"Martins Awele"']
# []
# []
# ['"Mercy Kume"']
# ['"Mohammed Abacha"']
# ['"Mohammed Abacha"']
# ['"Mohammed Abacha"']
# []
# []
# []
# ['"MRS. MARIAM ABACHA"']
# ['"Mr.Stephen Koseff"']
# []
# ['"Rev Mark Bome"']
# ['"Abu M.Sesay"']
# ['"Abu M.Sesay"']
# []
# ['"MR. JOHN PETERS"']
# ['"MR. JOHN PETERS"']
# ['"bongo wale"']
# []
# []
# []
# []
# ['"Dr.Benard Mcarthy"']
# ['"Barr. Chris Edu"']
# ['"Mr Chris Ogiemwonyi."']
# []
# []
# []
# ['"Barr. Chris Edu"']
# ['"Barr. Chris Edu"']
# ['"MR JOHN DICKSON"']
# ['"Dr (Mrs) BETTY PEDRO"']
# []
# []
# ['"james obi"']
# ['"james obi"']
# []
# ['"Dr Mrs Mariam Abacha"']
# ['"james obi"']
# ['"james obi"']
# ['"MRS. PATRIKA KOVAC"']
# ['"MRS. PATRIKA KOVAC"']
# ['"Shadak Shari"']
# ['"Shadak Shari"']
# ['"Shadak Shari"']
# ['"ROBERT MAJUS"']
# ['"Engr. Ukot Thomas Ukot"']
# ['"MRS. PATRIKA KOVAC"']
# ['"DR. HARRY OBUM"']
# ['"Mr. Dicka Dumas"']
# ['"Mr. Dicka Dumas"']
# ['"DR. EKIYOH MARTINS"']
# ['"Mr.Harry Hakeem"']
# []
# ['"John Mikado"']
# ['"John Mikado"']
# ['"MRS MAVIS KAKI"']
# ['"MRS MAVIS KAKI"']
# ['"Mr Frank"']
# ['"info@crack-ag.com"']
# []
# []
# []
# ['"SAMSON K.MANI"']
# ['"Mr frank"']
# ['"oliver"']
# ['"oliver"']
# ['"Terry"']
# []
# []
# []
# []
# ['"yaya"']
# ['"yaya"']
# ['"sessay massaquoe"']
# ['"sessay massaquoe"']
# ['"sessay massaquoe"']
# ['"Paul Jacksoncole."']
# ['"BAR.MYKE UTAKI"']
# []
# ['"Tony"']
# ['"Tony"']
# ['"Dr. mustafa mohammed"']
# ['"Dr. muystafa mohammed"']
# []
# []
# ['"FROM ME PLEASE REPLY"']
# ['"MR BEKO EZE"']
# ['"Charles Taylor"']
# []
# ['"Kumalo Debe"']
# ['"oliver"']
# ['"oliver"']
# []
# []
# ['"MOHAMED  ZUBA"']
# ['"chris"']
# []
# ['"Lt. Col. Richard Egwu"']
# ['"Lt. Col. Richard Egwu"']
# ['"Lt. Col. Richard Egwu"']
# ['"Mattew Molefe"']
# ['"DR.WILLIAMS KOFFI"']
# ['"DR.WILLIAMS KOFFI"']
# ['"DR.WILLIAMS KOFFI"']
# ['"DR.WILLIAMS KOFFI"']
# ['"BIKO ZULATO"']
# []
# []
# []
# ['"Raad Ibrahim"']
# ['"Raad Ibrahim"']
# ['"Abu M.Sesay"']
# ['"Abu M.Sesay"']
# []
# ['"Mr. Momoni  Adoh"']
# ['"MR.PAUL MPOYO"']
# ['"BADMUS IGWE"']
# ['"BADMUS IGWE"']
# ['"BADMUS IGWE"']
# []
# ['"Abu m. Sesay"']
# ['"Nathaniel Iredia"']
# []
# []
# []
# []
# ['"brr. j.t martins & associates"']
# ['"Ian Small-Smith"']
# ['"Ian Small-Smith"']
# ['"Tony"']
# ['"Tony"']
# ['"Tony"']
# ['"Mr Moni Millat"']
# []
# []
# ['"Dr.Edward Hilson."']
# []
# []
# []
# ['"Dr&Mrs.Erick"']
# []
# []
# []
# []
# []
# ['"Ms Anita Obadan"']
# []
# ['"Dr. mohammed mustafa"']
# ['"Mary Kabah"']
# ['"Mary Kabah"']
# ['"MOHAMMED BELLO"']
# ['"MOHAMMED BELLO"']
# ['"MADAM  MAUREEN  WUSU."']
# ['"MR.  BOB  DAN"']
# ['"MRS MAGRET KELLE"']
# ['"Dr&Mrs.Erick"']
# ['"Mr. Williams Savimbi"']
# ['"Mr. Williams Savimbi"']
# []
# ['"Mr Jerry Moi"']
# ['"Dr.Donald Ike"']
# ['"Mark Okpara"']
# ['"Grace Obaseki"']
# ['"Mr Roberts"']
# ['"Mr Roberts"']
# []
# []
# []
# []
# ['"Mike Morgan"']
# []
# []
# ['"Mrs. Maryam"']
# ['"Prince Yobo"']
# ['"Mr. Martins Aku"']
# []
# []
# []
# []
# ['"Mr Bongani"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Mr.James Tobi"']
# ['"Mr.James Tobi"']
# ['"DR DAVID PARBLO"']
# []
# []
# []
# ['"John Mikado"']
# ['"John Mikado"']
# ['"Mrs. Elizabeth Ogali"']
# ['"ahmedakim"']
# ['"MRS JULLIET ABRAMS"']
# ['"Miss Funke Komana"']
# ['"Mrs. Jay Afolabi"']
# []
# []
# []
# []
# ['"Mrs. Mariam Khalifa"']
# ['"Joseph Zulu-Zata."']
# []
# ['"Mr. Mobin Kabila"']
# ['"ISA MOHAMMED"']
# ['"ISA MOHAMMED"']
# ['"ISA MOHAMMED"']
# ['"ahmed momoh"']
# []
# ['"ISA MOHAMMED"']
# ['"ISA MOHAMMED"']
# []
# []
# []
# []
# []
# []
# ['"Dr. Daniel Solow"']
# ['"Dr Peter Akinjide"']
# ['"Dr. Daniel Solow"']
# []
# ['"David Tungay"']
# []
# ['"Engr. Sule Alkali"']
# ['"Femia Bnagura."']
# ['"Femia Bnagura."']
# ['"Femia Bnagura."']
# []
# ['"Femia Bnagura."']
# ['"kenneth masuku."']
# []
# []
# ['"Mr.   AHMED   ALI."']
# ['"Mrs At .Reb"']
# ['"abbeygeorge26"']
# []
# []
# []
# []
# []
# ['"Elisabeth Kabba"']
# ['"Dr.Hilary Colsman"']
# ['"MS.KIMAEVA LIOUDMILA"']
# ['"MS.KIMAEVA LIOUDMILA"']
# ['"omaru aminu"']
# ['"Dr.Hilary Colsman"']
# []
# []
# []
# ['"Mumba Tama Koroma"']
# ['"salim ibrahim"']
# ['"Don Hose Nando"']
# ['"=?iso-8859-1?Q?akinsola=5Fakinfemiwa4@tiscali.fr?="']
# ['"Rasheed Abubakar"']
# []
# ['"Rasheed Abubakar"']
# []
# ['"Rasheed Abubakar"']
# []
# []
# []
# []
# ['"MRS LOUISA E. ESTRADA"']
# ['"OKOFOR DAVID"']
# []
# ['"Amir Ebrahimi "']
# ['"Vladislav Zhenechka"']
# ['""']
# []
# []
# []
# []
# ['"jeff smith"']
# ['"Ibrahim Dunga"']
# []
# []
# []
# []
# ['"Morgen Best"']
# []
# ['"Frank Jim"']
# []
# []
# []
# ['"Mr.Collince Addo"']
# ['"Frank Map"']
# ['"Mr.Gailu Fall."']
# ['"Mr.Gailu Fall."']
# ['"Mr.Gailu Fall."']
# ['"michael eze"']
# ['"Miss.Vivian Gueye"']
# ['"Miss.Vivian Gueye"']
# ['"Mrs.Erick"']
# ['"Mrs.Erick"']
# ['"Mrs.Erick"']
# []
# ['"Paul Otobo"']
# ['"Paul Otobo"']
# ['"MS. KIMAEVA LIOUDMILA."']
# ['"SAMSON BAMOGU"']
# ['"Dr.David Clovis"']
# ['"Dr.David Clovis"']
# ['"Dr.David Clovis"']
# ['"Dr.David Clovis"']
# ['"Dr.David Clovis"']
# ['"Dr.David Clovis"']
# ['"Dr.David Clovis"']
# ['"Dr.David Clovis"']
# []
# []
# ['"david morgan"']
# []
# []
# ['"Dr. Yinka Craig"']
# []
# []
# ['"John  Ogari"']
# []
# ['"John  Ogari"']
# ['"Paul O. Otobo"']
# []
# ['"Paul Otobo"']
# []
# ['"David Ankra"']
# []
# ['"Mr.Gordon"']
# ['"Mr.Gordon"']
# ['"Paul Otobo"']
# ['"Paul Otobo"']
# ['"Mrs.tutu"']
# ['"SAMSON BAMOGU"']
# ['"femia bangura"']
# []
# ['"FROM  REV   .W   . ADAMS"']
# []
# ['"tony smith"']
# []
# ['"ibram kamara"']
# ['"ibram kamara"']
# []
# []
# []
# []
# ['"Dr John Ike"']
# ['"WASSE."']
# []
# ['"Dr ROBERT WILAMS"']
# []
# ['"EL.Gaily Maliky."']
# ['"Mrs.T.Erick"']
# ['"John  Ogari"']
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Dr  John   Berg"']
# ['"Yuriy Lagutin"']
# ['"SABASTIAN   GOMEZ"']
# ['"CHIEF  SABASTIAN GOMEZ"']
# ['"Mr.Eric Ude"']
# ['"Mrs  Abdul  Ramat"']
# ['"Ms. Kimaeva  Lioudmila"']
# []
# []
# ['"FROM DR.ATEEQ RAHMAN KHAN"']
# ['"FROM DR.ATEEQ RAHMAN KHAN"']
# ['"Mr.Gordon W."']
# ['"Daren Carama"']
# ['"Daren Carama"']
# ['"FROM MRS MONICA  KABILA"']
# ['"Mr. John Mensah Sulikuh"']
# ['"BARRISTER TANJUMAH AHMED"']
# ['"alex jomoh"']
# []
# []
# ['"MR. LAURENT DESIRE KABILA (JUNIOR)"']
# []
# ['"ro wil"']
# []
# ['"SAMSON BAMOGU"']
# []
# []
# []
# []
# ['"Mr. Markus Bopp"']
# []
# ['"Mrs Howell"']
# []
# ['"John Obute"']
# ['"Micheal Bangura"']
# ['"Micheal Ipenza"']
# []
# []
# []
# []
# ['"Micheal Ipenza"']
# ['"Mr.Haitham Sharaff."']
# []
# []
# []
# []
# []
# []
# []
# ['"Harris Keith"']
# ['"Mrs Mary Clement."']
# []
# ['"MRS.SAMBU LIZZY"']
# ['"MRS.SAMBU LIZZY"']
# []
# ['"Micheal Ipenza"']
# ['"Mrs Mary Clement."']
# ['"SAMSON BAMOGU"']
# ['"Mr.Cheung Pui"']
# []
# []
# []
# []
# ['"MR ABATO"']
# ['"MRS  MARIAM ABACHA"']
# ['"Mr. Tom Adams"']
# ['"DONALD GAGE"']
# ['"Mr Sogolo"']
# []
# []
# []
# []
# []
# []
# []
# []
# ['"MARRIAM TAYLIR"']
# []
# ['"MR SHAKIR ABDUL"']
# ['"Miss Binta Wahid"']
# ['"nkomo robert"']
# ['"MRS. MARIAM"']
# ['"MRS. MARIAM"']
# ['"MRS. MARIAM"']
# ['"MRS. MARIAM"']
# ['"MRS. MARIAM"']
# ['"Donatus Okobi"']
# []
# ['"SENATOR VICTOR OYOFO"']
# []
# []
# ['"WILFRED OMETIE"']
# []
# ['"Robert Beaud"']
# ['"Robert Beaud"']
# []
# []
# []
# []
# []
# []
# ['"Raymond Lauder"']
# []
# []
# []
# []
# ['"mohammad urban"']
# ['"mohammad urban"']
# ['"Raymond Lauder"']
# []
# ['"Micheal Ipenza"']
# ['"Micheal Ipenza"']
# []
# []
# []
# ['"abacha_abj Abacha"']
# []
# []
# ['"MR S. CHARLES"']
# ['"Mr Turkin E. Onuorah"']
# ['"Barr. Helen Hill (ESQ)."']
# []
# []
# []
# ['"FROM MR HAITHAM SHARAF."']
# []
# []
# []
# ['"GENERAL VICTOR MALU"']
# ['"Mrs Beni Fredrick"']
# ['"MR ADU KOFFI"']
# ['"mark anderson"']
# []
# ['"Ludovic Johnson"']
# ['"Lee Chen"']
# ['"benard mcarthy mcarthy"']
# ['"benard mcarthy mcarthy"']
# ['"Mirolsav Vlado"']
# []
# []
# []
# ['"KIMAEVA LIOUDMILA"']
# ['"emmanuel briggs"']
# []
# []
# ['"ALHAJI IBRAHIM ABDULLAH."']
# ['"ALHAJI IBRAHIM ABDULLAH."']
# ['"Mr.Malick Camara"']
# ['"KOJO WILLIAM"']
# []
# []
# []
# []
# []
# ['"abacha ahmed"']
# ['"Dr.Joseph.Tenn"']
# ['"Demba Gaye"']
# ['"Dr.Joel Williams"']
# ['"thomas sarr"']
# []
# []
# []
# []
# ['"Mr. James William "']
# []
# ['"desu matthan"']
# ['"Mirolsav Vlado"']
# []
# []
# []
# ['"MR. KIMAEVA LIOUDMILA"']
# []
# []
# []
# []
# []
# []
# []
# ['"Mr. Funsho Peter "']
# []
# ['"Mr.Tony Malick."']
# ['"Micheal Ipenza"']
# ['"Mr.Gailu Fall"']
# ['"VIVIAN KABA"']
# []
# ['"RICHARD MOORE JR."']
# ['"ibrahimbaajisan"']
# []
# []
# []
# ['"Mr, Ahmed.Gueye"']
# []
# []
# []
# ['"Mr.Patrick Chima"']
# ['"MR. KARIM SULE"']
# ['"Mr Cyriel Kelvin."']
# []
# ['"Langley Williams"']
# ['"ife williams boko"']
# ['"ibrahimbaajisan"']
# []
# []
# []
# []
# ['"Silva Fall"']
# []
# ['"DANIEL BROSWER"']
# ['"Mrs.Erick"']
# ['"Mrs.Lydia Johnson & Son."']
# ['"Dr Mrs Luisa Estrada"']
# []
# []
# ['"IBRAHIM DIALLO"']
# ['"MRS MARIAM  TAYLOR"']
# ['"DAVID LALAH."']
# ['"james howard"']
# ['"ms taylor"']
# ['"Mike  Kamokai"']
# ['"Sally Usman"']
# ['"Dr. James Tshaba"']
# []
# []
# []
# ['"WILLIAM ANNA"']
# []
# ['"Patrick Chima"']
# []
# ['"peter khan"']
# ['"Binnet Kageme"']
# ['"Mr.G.Boka"']
# ['"ibrahimbaajisan"']
# ['"MRS CYNTHIA AMAKA MOBUTU KONA"']
# ['"DANIEL  WILLIAM"']
# ['"ibrahimbaajisan"']
# ['"mariam sinko"']
# ['"ibrahimbaajisan"']
# ['"georgeabbey43"']
# []
# ['"ibrahimbaajisan"']
# ['"Ata Yusuf"']
# ['"ibrahimbaajisan"']
# ['"patri"']
# []
# []
# ['"william & sister"']
# []
# []
# []
# []
# []
# ['"MR.TONY MALICK ."']
# ['"KIMAEVA LIOUDMILA"']
# []
# ['"mamadou sidibie"']
# ['"WILLIAM"']
# []
# []
# ['"JEFF R. GUEI"']
# []
# []
# ['"Mr.Liam Johnson"']
# []
# []
# []
# ['"mrs.mariama taylor"']
# []
# []
# ['"MRS.SUZANA NUHAN VAYE"']
# ['"Johnson"']
# []
# ['"solomon c."']
# ['"DANIEL WILLIAM"']
# ['"Kamara  Saydee"']
# ['"Mr Cyriel Kelvin"']
# []
# []
# []
# []
# []
# ['"ALIYU AHMED JNR."']
# []
# []
# []
# ['"from Mrs.Johnson"']
# ['"Godwin Akwesi"']
# []
# []
# []
# ['"Demba Gaye"']
# ['"Lilian Mbengani"']
# ['"Mr.Jerume"']
# []
# ['"MR.GIDEON KWAMI"']
# ['"micheal smith"']
# ['" mohamed59"']
# ['"VICTORIA  KAREGAYE"']
# ['"Comfort Somba."']
# ['"HENRI MOYO"']
# ['"Demba Gaye"']
# []
# ['"Barrister Jim Douglas"']
# ['"Barrister Jim Douglas"']
# []
# []
# []
# []
# []
# []
# ['"Mr Sam White"']
# ['"MR. KIMAEVA LIOUDMILA"']
# ['"john_simon2005"']
# ['"olusegun"']
# ['"sun moyo"']
# ['"From : Nicholas Mavis"']
# ['"Rev Fr. john  Cohen  dike"']
# ['"MR.ABBAH NASSER"']
# ['"MRS.SUZANA NUHAN VAYE"']
# ['"MRS.SUZANA NUHAN VAYE"']
# ['"JACKSON  SANTOX"']
# ['"MaryMendes"']
# ['"Mr Cyriel Kelvin."']
# []
# ['"johnson T kalute"']
# ['"musa ngueto"']
# ['"desu matthani"']
# ['"BONGIES ZULU"']
# []
# []
# ['"GRACE KOPI"']
# []
# []
# []
# []
# ['"Mr. Felix Kambala"']
# []
# []
# ['"DESU MATTHANI"']
# ['"Al bahar & Associates"']
# []
# ['"Mr Nais Mohamed"']
# ['"Mrs.Angelina Ebony Dazza"']
# ['"Mrs Mariama Taylor.."']
# []
# []
# []
# ['"Mrs.Mary Shinkafi Al Shinkafi"']
# ['"morgan  xhosa"']
# []
# ['"Mrs.  Fatima   Rasheed"']
# ['"joseph cabutti"']
# []
# []
# []
# []
# ['"Mr Bright W illiam"']
# []
# ['"KENNETH MUGAJI."']
# ['"KENNETH MUGAJI."']
# []
# ['"MR.martin arap moi"']
# ['"mrs.suha a."']
# ['"LOME GLORY"']
# ['"DESU MATTHANI"']
# []
# []
# []
# ['"Robbin Kuuk"']
# []
# ['"Adonis  Johnson"']
# []
# ['"Barr.  Ahmed  Mustafa"']
# ['"Mrs.Lydia Johnson"']
# ['"Mrs.Lydia Johnson"']
# ['"rose sondo"']
# ['"prisca_savana1"']
# ['"Lewis Musasike (lmusasike)"']
# []
# ['"NABIL ALLAWI"']
# ['"STELLA DIKKO SAMBA"']
# ['"Mr. Olsom Berghart"']
# ['"STELLA DIKKO SAMBA"']
# []
# []
# []
# []
# ['"Michael Hammer"']
# ['"Binnet  Kageme"']
# []
# ['"Elhadji Mohammed"']
# ['"Prof Charles Soludo"']
# ['"Prof Charles Soludo"']
# ['"Isaac Ezekiel"']
# ['"Marcus Botha"']
# ['"JOHN SAVIMBI"']
# ['"g_kamara"']
# []
# ['"MR FRED KABILA"']
# ['"MARCUS BOTHA"']
# ['"mohmed  yaya"']
# []
# ['"peter moyo"']
# ['"Ahmed  Moustapha"']
# []
# ['"Mr Zuma Prince"']
# ['"Mr Zuma Prince"']
# ['"Franca........."']
# ['"Mr. Wu Kwon"']
# ['"joy kwame"']
# ['"Mr.Malick Camara."']
# ['"Mrs.Nuchoni Yaoprasirth."']
# []
# ['"LEE YUNG (CMEC HUBEI CO)"']
# []
# ['"Mr.Peter Ottawa"']
# ['"mrssarasa bhakadyrov"']
# []
# []
# []
# ['"TONY KASAKA"']
# []
# []
# []
# []
# ['"Ms Mariam Mohamed"']
# ['"MRS. E. HERYATI"']
# ['"MRS. E. HERYATI"']
# ['"FROMMR JOHN WILLIAMS"']
# []
# []
# []
# ['"JACKSON SANTOX"']
# []
# []
# ['"DR. GOODLUCK ENNIS."']
# ['"MUSA EYADEMA"']
# []
# []
# ['"mark ellis"']
# ['"mark ellis"']
# ['"SUSAN HUAN"']
# ['"MRS. E. HERYATI"']
# []
# ['"aida"']
# []
# []
# ['"Ms.URLIKA OMERZEL JAGODIC"']
# ['"Ms.URLIKA OMERZEL JAGODIC"']
# ['"Mr. Patrick Francis Jr."']
# ['"Sadou K Hamal"']
# ['"ALI MARTINS"']
# ['"GEORGE SANOUSSI"']
# ['"Eloy Savimbi"']
# []
# ['" "']
# []
# ['"Mr Cyril Kelvin."']
# ['"Dr. Salif Mamadou."']
# []
# []
# []
# []
# ['" "']
# ['"Mrs. Aminatu Bolkiah"']
# []
# []
# []
# []
# []
# []
# []
# ['"WAKUH OTU"']
# ['"tony hill"']
# ['"MRS.LARISA NITSKAYAA"']
# []
# ['"Taylor Brown"']
# []
# ['"joseph bako"']
# []
# ['"Mr. Nooh Majd"']
# ['"Mr. Nooh Majd"']
# []
# ['"Justice Akhimaniza"']
# ['"Justice Akhimaniza"']
# ['"Mr Eloy Savimbi"']
# ['"Mr.Mark Wimble"']
# ['"Kenneth  Malfred"']
# []
# []
# ['"peter wang"']
# ['"MR. MOHAMED HASSAN"']
# ['"leonard okobi"']
# ['"leonard okobi"']
# ['"MR.SANTUS MUFASA."']
# ['"MR.SANTUS MUFASA."']
# ['"FROM MR MOHAMMED TANKOH"']
# []
# []
# ['"Mike Ato"']
# ['"Mr.Moses Paraiso"']
# []
# []
# []
# []
# []
# ['"MRS  ASIHA   HASSAN"']
# []
# []
# []
# []
# []
# ['"Mr.Dougan .O.Oyony"']
# ['"Dr.Obafemi Heinz"']
# []
# ['"Charles Conneh"']
# ['"victor onyema"']
# ['"MR.JEFF VILAGAZI"']
# ['"MR.JEFF VILAGAZI"']
# ['"Mr.Kabir Bello."']
# ['"Sir Adams"']
# ['"Alhaji Ibrahim Hassan dankwambo"']
# ['"Mr.George"']
# []
# ['"Mr Ahmed  yousf"']
# ['"Dan Kabo"']
# []
# ['"MRS.LARISA NITSKAYAA"']
# ['"taibu"']
# []
# ['"felixtaylor"']
# ['"jim.h"']
# ['"jim.h"']
# []
# []
# []
# ['"Mr. Anijah Akpundu"']
# ['"Mr. Anijah Akpundu"']
# ['"Mr. Anijah Akpundu"']
# ['"Mr. Anijah Akpundu"']
# ['"Dave Benton"']
# []
# ['"Frank Michelle"']
# []
# ['"dike mark"']
# []
# []
# []
# []
# ['"Mrs Cathrine Charles"']
# []
# ['"Mike Charles"']
# ['"Rajesh Anand Bhagwuan"']
# ['"John Naveed"']
# ['"Mr Cyril Kelvin."']
# ['"Steve"']
# ['"Koffi kosombo"']
# ['"MRS.SUZANA VAYE"']
# ['"halen kenne"']
# ['"FROM AHMED TANkOH"']
# []
# ['"Alexander Gedike"']
# []
# ['"deborah williams"']
# ['"cheung pui"']
# ['"cheung pui"']
# ['"cheung pui"']
# ['"Mr Cyril Kelvin."']
# []
# []
# ['"Mrs  Mariam   Taylor"']
# ['"Bill Franklyn"']
# []
# []
# []
# []
# []
# ['"Paul Osadebe"']
# ['"Mike Charles"']
# ['"goule doum"']
# []
# []
# ['"Mr Cyril Kelvin."']
# ['"Mr. Ali Raza Khan"']
# []
# ['"ROSEMARY ANI"']
# ['"KAMS"']
# ['"AMAH"']
# []
# []
# []
# ['"Mr.Albert Uga"']
# []
# []
# ['"Rabi Al Salih [r00001@pochta.ru]"']
# ['"Rabi Al Salih [r00001@pochta.ru]"']
# []
# ['"MRS.SUZANA NUHAN VAYE"']
# []
# []
# ['"DANIEL IBE"']
# ['"Dr David"']
# ['"MR FRANCIS KONYANG"']
# ['"Mrs.Amina.A.Bello."']
# ['"Sullivan Richard"']
# ['"tema williams"']
# []
# []
# []
# []
# ['"Dr.Ateeq Rahman Khan"']
# ['"Mrs. m.Diepreye Alamieyeseigha"']
# ['"ALEXEI ZANKHARENKO"']
# []
# []
# []
# ['"Mr. James Duncan"']
# []
# ['"David"']
# ['"lUIS Tasharofi .Jnr"']
# ['"Mr. Fredrick Andrew"']
# ['"Mariam Camara"']
# ['"MISS. AISHA  JOHNSON."']
# ['"MISS. AISHA  JOHNSON."']
# ['"ANGELA WILLIAMS"']
# ['"DANIEL MOORE"']
# ['"DANIEL MOORE"']
# []
# ['"Ben Otutu"']
# []
# []
# ['"alexander gedike"']
# []
# []
# []
# ['"felixeze123"']
# ['"felixeze123"']
# ['"Mrs. Fatima Rasheed."']
# []
# []
# ['"Banco Eze"']
# ['"Miss, Joli  Hamed"']
# ['"Miss, Joli  Hamed"']
# ['"DANIEZ PHILIPS [daniez_philips@pochta.ru]"']
# ['"Dr. John Kelly"']
# ['"Jacob Uderike"']
# ['"Jacob Uderike"']
# []
# []
# []
# []
# ['"Lydia"']
# ['"willico willico"']
# []
# ['"MRS MARRIAM TAYLOR"']
# ['"MAMI"']
# ['"Miss Linda Dickson"']
# []
# ['"Mr.Scott Reed"']
# []
# ['"MR. HAMDALA RAHAMA,"']
# ['"Miss, Maggreat Hogan"']
# ['"BARRISTER LUCKY JOE"']
# []
# ['"Mr. Ryszard Rulinski"']
# ['"Mr. Ryszard Rulinski"']
# []
# ['"Mr Yaya Diouf."']
# []
# ['"will.wilcox1@virgin.net"']
# ['"ENGGINEER. MATTAR AL TAYER"']
# ['"MS FATIMA FAHAD"']
# ['"Mr. Fredrick Andrew."']
# ['"DESTINY  MOMOH"']
# ['"Mr Henry Okoye [henryokoye1@pochta.ru]"']
# []
# ['"vivian mutan"']
# ['"Barr.Anthony Efe"']
# ['"MRS. SUZANA NUHAN VAYE"']
# []
# ['"MRS. SUZANA NUHAN VAYE"']
# []
# ['"DR SHERIFF AZEEZ"']
# []
# ['"Mrs. Suzana Nuhan Vaye."']
# ['"BARRISTER FRED BRIGGS"']
# []
# []
# []
# ['"Mr Cyril J. Garang."']
# ['"EDMOND ZONAH JR."']
# ['"Mr Mills Ofori"']
# []
# []
# []
# ['"STEPHEN AYLING"']
# ['"AHMED    TAYLOR"']
# ['"[g_c_4@pochta.ru]"']
# ['"Mr.Karonga Zungu"']
# ['"Mr.Karonga Zungu"']
# ['"Mr.Karonga Zungu"']
# ['"Mr.Karonga Zungu"']
# ['"garuba gambo"']
# ['"STEPHEN AYLING"']
# []
# ['"MARSHALL  KINGSMAN"']
# ['"Mr.Raynold Olds\'"']
# ['"eric wong"']
# ['"eric wong"']
# ['"eric wong"']
# ['"sullivan richard"']
# ['"Mariam Camara"']
# ['"Mrs Roseline Muleko"']
# ['"charakroultwells@adinet.com.uy"']
# ['"charakroultwells@adinet.com.uy"']
# ['"Mr. Fredrick Andrew"']
# ['"Rose Welsh"']
# []
# ['"Rose Welsh"']
# []
# ['"Rose Welsh"']
# []
# ['"Ahmed Ali"']
# ['"Ahmed Ali"']
# []
# ['"Johnson Kema"']
# ['"Miss Fatimatou Kaba."']
# ['"FROM DESSU METHAN"']
# ['"Mr Yaem Ahmed"']
# ['"eric wong"']
# ['"wong eric"']
# ['"vski.ziv@virgin.net"']
# ['"Mr.  Malick  Camara"']
# []
# []
# ['"Mr.Tony Omar."']
# []
# []
# ['"SAN FANI M UTAKI(ESQ)"']
# []
# ['"Mr. Michael Frein"']
# ['"Mr. Ateeq Rahman Khan"']
# ['"Jimmy Johnson"']
# ['"Mr. Christian Ubanah"']
# []
# ['"Martin Lucas"']
# []
# []
# []
# ['"Dr. Kaba"']
# ['"ELIZABETH GARANGE"']
# []
# ['"Mrs.AISHA MOHAMMED."']
# ['"FROM MR HASSAN DIOUF"']
# []
# []
# ['"MRS SHARONABED"']
# ['"mari gomogo"']
# []
# ['"From : Nicholas Mavis"']
# []
# ['"Abdulrazak Momodu"']
# []
# ['"AHMED SALIH"']
# ['"Madam Fatima"']
# ['"Dr. Ojei Uloaku"']
# ['"Mr Roland Desmond"']
# ['"Mr Roland Desmond"']
# ['"mariam boko"']
# ['"Mrs.AISHA MOHAMMED."']
# ['"eric wong"']
# ['"eric wong"']
# ['"eric wong"']
# ['"Mr. Nelson Mba"']
# ['"Mrs.AISHA MOHAMMED."']
# ['"Fatima."']
# []
# ['"FROM LUISA RAYMOND"']
# ['"Patrick Gabo."']
# []
# ['"david"']
# []
# ['"james kone"']
# ['"james kone"']
# ['"PHIRI ABOA."']
# []
# []
# []
# ['"Jimela Abbas"']
# []
# []
# ['"From Ms Johana"']
# ['"MR SALEEM MOHD AHMED MOHD"']
# ['"MR SALEEM MOHD AHMED MOHD"']
# []
# ['"KONE JAMES"']
# ['"KONE JAMES"']
# ['"Dr.Johnson Kwesi"']
# ['"Lewis Macias"']
# []
# ['"Melissa Pointer"']
# ['"usman bello"']
# ['"charles anthony"']
# ['"jocelyn jones"']
# []
# []
# ['"MRS.ELENA OWEN"']
# ['"MRS.ELENA OWEN"']
# ['"william zungu"']
# ['"Phiri Aboa"']
# ['"Dan Abdul"']
# ['"TONY SILVER"']
# ['"TONY SILVER"']
# ['"suzana vaye"']
# ['"suzana vaye"']
# ['"mallam mustapha"']
# ['"Mrs.Rita Diatta."']
# ['"Mr.Ken Quattara."']
# ['"Mr.Ken Quattara."']
# ['"MR.FRANK TETTEH"']
# ['"Smith Anderson."']
# ['"Smith Anderson."']
# ['"Smith Anderson."']
# ['"More Frankline"']
# []
# []
# []
# ['"Mrs.Chrrey mohameed"']
# ['"villaran nenita"']
# ['"Eng. Kentas Anderson"']
# ['"Abdul Manoni"']
# []
# ['"Mr.John"']
# ['"ibrahim bello"']
# []
# ['"Lin Geng"']
# []
# []
# []
# []
# []
# ['"Donald Greene"']
# ['"Mrs.Chrrey mohameed"']
# ['"HULFUMAN  DAVID"']
# []
# ['"Mrsvictoria Sankoh"']
# ['"Mr. Chin Weng Yin"']
# ['"PRINCE HASSAN SULEMAN"']
# ['"Nguyen Hoan T"']
# ['"Nelson Williams"']
# ['"YSSOUF NNEOMA WOLOSO"']
# ['"Olesito Armstrong"']
# ['"frank_ben5@myway.com"']
# ['"Davis Paul"']
# []
# []
# []
# ['"sem_bouabre"']
# []
# ['"FROM MR DAVID BAH"']
# []
# []
# ['"Engr. Moel Kobo"']
# ['"Mary Eyadema"']
# []
# []
# ['"GANI FEMI"']
# ['"joseph mobutu"']
# ['"elizabeth tambo"']
# ['"BEN S. ADAM"']
# []
# []
# ['"silver timi"']
# []
# []
# ['"Mr.Titus J. Morris"']
# []
# ['"Mr.Titus J. Morris"']
# []
# ['"mustapher mustapher"']
# ['"mustapher mustapher"']
# []
# []
# []
# ['"ericmorgan11"']
# []
# ['"ericmorgan01"']
# ['"James Jonbo"']
# []
# []
# []
# []
# ['"lord luke"']
# ['"Mrs Fatima Hinga"']
# ['"arbu mpula"']
# []
# []
# []
# ['"Mr Ag"']
# ['"Mr Ag"']
# []
# ['"PET KAYCE"']
# ['"sussan shubangu"']
# ['"COLLINS  VOLLEN"']
# ['"julia ngoli"']
# ['"Victoria Abuchi"']
# ['"Victoria Abuchi"']
# []
# []
# ['"dr.mohammed mustafa"']
# ['"philip desmond"']
# []
# ['"FROM: Mr RAY KABE."']
# []
# ['"raymond_david1"']
# []
# ['"john amos"']
# []
# []
# ['"pet kayce"']
# ['"Nepyyvoda Petro"']
# []
# []
# ['"Jessica Williams"']
# ['"dr daniel nando"']
# []
# ['"jerry_kabore03"']
# []
# ['"jerry_kabore03"']
# ['"dr daniel nando"']
# ['"ALHAJI  JUBRIL  ALIU"']
# ['"Mrs. Linda Johnson."']
# ['"Azura Amanda Akub"']
# []
# ['"Mrs. Patricia Sithole"']
# ['"JAMES MORGAN"']
# ['"james owusu"']
# ['"Michael Ezra."']
# ['"Michael Ezra."']
# ['"Michael Ezra."']
# []
# ['"Abdul Lawal"']
# ['"tanko usman"']
# ['"WILLIAMS ADAMS"']
# ['"WILLIAMS ADAMS"']
# ['"sanko junior"']
# ['"Michael Ezra."']
# []
# []
# ['"Barrister John Fisher"']
# ['"DR.PROF. k. MAXWELL,"']
# []
# []
# ['"nen_vill"']
# ['"DEAN GRAY"']
# ['"henry kabore"']
# []
# []
# []
# ['"FROM MS GLORYSUMA"']
# []
# []
# ['"ZUMA BARLEY"']
# []
# ['"y_konovalov"']
# []
# ['"sami_mohammad40"']
# []
# ['"jerry_kabore01"']
# []
# ['"jerry_kabore01"']
# ['"MR.DON KOFFI"']
# ['"Amina"']
# ['"Mrs.Amina.A.Bello."']
# []
# ['"ali_asita01"']
# []
# ['"ali_asita02"']
# []
# ['"pioneer5phm"']
# []
# ['"Mr. Kenneth Mckay"']
# ['"dr. mohammed mustafa"']
# ['"dr. mohammed mustafa"']
# ['"kevin woodgate"']
# []
# ['"DEAN GRAY"']
# ['"DEAN GRAY"']
# []
# ['"mark james"']
# ['"john moka"']
# []
# ['"Mrs.Amina.A.Bello."']
# []
# ['"sanou bello"']
# []
# ['"prince44hassan"']
# ['"ENGR.GEORGE EGOBIA"']
# []
# ['"mohamat ali"']
# []
# ['"Mrs.Rita Diatta."']
# ['"Tenders Board"']
# []
# []
# []
# []
# []
# ['"david moore"']
# ['"dessu methane"']
# []
# ['"Johnson Tijan Kalute"']
# ['"favour div"']
# ['"mr bello"']
# ['"Lanssana Kuyembeh"']
# ['"Mr.Kabir Bello."']
# ['"Mrs Azura Amanda Akub"']
# ['"Mr.Kabir Bello."']
# ['"Mrs MOHAMMED."']
# ['"SANDRA MENDES"']
# ['"Mr Biney I Saac"']
# ['"Mr Biney I Saac"']
# ['"ABDULAHI ISSA"']
# ['"asita"']
# []
# []
# ['"david obi"']
# ['"Mr.Kabir Bello."']
# []
# ['"Kenneth .c. Ndlovu"']
# []
# ['"cynthia_wood"']
# []
# ['"From Ms. Johana"']
# ['"From Ms. Johana"']
# ['"taylor robert"']
# []
# ['"From Ms. Johana"']
# []
# ['"anastesia  williams"']
# []
# ['"trevor_gumel2"']
# []
# []
# []
# []
# ['"privacy_informations"']
# []
# ['"MR ALFRED MAMBO"']
# ['"Internal Revenue Service"']
# []
# ['"mohamat1"']
# []
# ['"AIDA"']
# []
# ['"Gregory Thambo"']
# []
# ['"Paul Mills"']
# ['"Paul Mills"']
# []
# ['"safia feddag"']
# []
# ['"salif zongo"']
# []
# []
# ['"Mustapha Momodu"']
# []
# ['"JOHN MARK."']
# []
# []
# []
# ['"Miss Linda Bouka"']
# []
# ['"Comfort Mensa"']
# []
# ['"Harry Hilal"']
# ['"johnny jeffrey"']
# ['"daniel nando"']
# ['"mohamat ali"']
# []
# ['"mark kunta"']
# ['"Dr. John."']
# []
# []
# ['"iwendi eze"']
# []
# []
# ['"emi alin"']
# []
# ['"Mr.kelly wood"']
# ['"From Ms. Johana"']
# ['"mr. John Castro"']
# ['"Zuma Koffi"']
# []
# []
# []
# ['"princess fayad"']
# []
# ['"Ms Florence Achiah Rusanganwa."']
# []
# []
# ['"MR DAVID SMITH"']
# ['"joe"']
# ['"bala"']
# ['"MR.John Duf Ben"']
# []
# ['"MR.John Duf Ben"']
# ['"MR DAVID SMITH"']
# ['"Mrs.Amina.A.Bello"']
# ['"Mr. Abudullah Mohamed"']
# ['"Mrs.Kate Masul"']
# ['"DEAN GRAY"']
# ['"trevor gumel"']
# []
# []
# ['"Miss   Susan.."']
# []
# []
# ['"bala"']
# []
# []
# ['"Dr Hassan Dantata"']
# ['"Mr.Malick"']
# []
# []
# []
# []
# ['"From: Mr. Joseph.Garang"']
# []
# ['"barr stuart fielding (esq)"']
# []
# ['"From: Mr. Joseph.Garang"']
# []
# []
# ['"Ms M. Bornwick"']
# ['"musa  garuba"']
# ['"Evette Nuhan Vaye"']
# ['"Dr. Femi Petersen"']
# ['"MR JOHNSON MUGABE"']
# []
# []
# ['"sieso kabila"']
# ['"a hafaf"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Mrs Marriam Abacha"']
# ['"ALAN RODRIGUEZ"']
# ['"Mr Batholomew"']
# ['"MR JOHNSON MUGABE"']
# ['"MR JOHNSON MUGABE"']
# []
# []
# []
# []
# []
# []
# []
# ['"selah bekou"']
# ['"selah bekou"']
# ['"Mohamat Ali"']
# []
# []
# []
# ['"BRUNO LAMBERT"']
# []
# []
# ['"Emme Harry"']
# []
# ['"joel taylor"']
# ['"Revd. Fr. Peter Clark"']
# ['"Dr.CUMOO AZEEZ"']
# ['"Dr.CUMOO AZEEZ"']
# ['"BINTA CEESAY"']
# ['"Revd.Fr.Peter Clark"']
# ['"muye will"']
# ['"MR MARK"']
# []
# ['"Mr.David Sarr"']
# []
# []
# []
# []
# []
# []
# ['"Barr.Charles Brown"']
# ['"yusuf sami"']
# []
# []
# []
# []
# ['"jocelynjones"']
# []
# []
# ['"Dr Hassan Dantata"']
# []
# []
# ['"trevor gumel"']
# []
# []
# ['"Mr.Peter Herry"']
# ['"viviansaja"']
# []
# []
# []
# []
# []
# []
# []
# ['"princessmemuna iboudo"']
# []
# []
# []
# []
# []
# ['"Chief Dr.Phil E.Bernard"']
# []
# []
# []
# []
# []
# []
# ['"Dr Mbizala Paul"']
# ['"Chief Dr.Phil E.Bernard"']
# ['"Chief Dr. Phil E. Bernard"']
# []
# []
# ['"good school"']
# []
# []
# ['"Martin Mccourt"']
# []
# ['"Barrister Ken Shaw"']
# ['"MR. GEORGE BENNETH"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Mr.David Sarr"']
# ['"Mr.David Sarr"']
# []
# []
# []
# ['"david505@adinet.com.uy"']
# ['"azize_ouattara123"']
# []
# []
# ['"henry kabore"']
# ['"SMITH BAWELL"']
# ['"Dr. Kashiff"']
# []
# []
# []
# []
# []
# []
# ['"Mr. Clive Osborne"']
# ['"Chief Dr. Phil E. Bernard"']
# ['"Mrs.Amina.A.Bello."']
# ['"aisha mohammed"']
# ['"GARANG JANET"']
# []
# []
# ['"SORIE AND SAM."']
# []
# []
# ['"Mrs Hajia lilian"']
# ['"MR WILLAMS TERRY"']
# []
# []
# []
# ['"oluyemi adeniji"']
# ['"LINDA  MATATA"']
# []
# ['"FORM ISA"']
# []
# []
# []
# ['"mutsheayi_koffi"']
# ['"Mr. Ahmadou  Bamba"']
# []
# []
# ['"Frank Jim,"']
# ['"Revd. Fr. Peter Clark"']
# ['"suleiman ahmed"']
# []
# ['"b_tomson1"']
# []
# ['"Bhamini Lele"']
# ['"thomson stella"']
# ['"Adama Ibrahim"']
# ['"CBN NIGERIA"']
# []
# []
# ['"Micheal  Dudu"']
# []
# ['"Patrick   Makuum"']
# []
# []
# []
# []
# []
# []
# ['"Idris Ali"']
# []
# []
# []
# []
# []
# ['"Ben Maluleke"']
# ['"Ben Maluleke"']
# ['"Ben Maluleke"']
# ['"Ben Maluleke"']
# ['"Mrs  Amina  Bello"']
# ['"emeson joe"']
# ['"emeson joe"']
# ['"emeson joe"']
# []
# ['"emeson joe"']
# []
# []
# []
# []
# []
# []
# ['"MR.MARK HERNANDEZ"']
# ['"Sgt Eddie (olisaogbonnia)"']
# ['"Paul Moore"']
# []
# []
# ['"Mrs Farah al-Hashemi"']
# ['"Antwan Saloum"']
# []
# []
# []
# ['"=?iso-8859-1?q?MRS=20FAITH=20OPUTA.?="']
# []
# []
# []
# []
# []
# ['"DR.LARRY DOUGLES"']
# []
# ['"idris ali"']
# []
# []
# ['"Stella Robinson"']
# ['"mustafa joseph"']
# ['"Mr Ahmed Salihu"']
# ['"Mr.Benlock"']
# ['"Rev. Fr. David Clark"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"mjerry@adinet.com.uy"']
# ['"Ben Maluleke"']
# ['"FAN JEN-LIANG"']
# ['"FAN JEN-LIANG"']
# []
# []
# []
# ['"MR.DAVID HESKEY"']
# ['"joe kekabu"']
# ['"joe kekabu"']
# ['"joe kekabu"']
# ['"joe kekabu"']
# ['"joe kekabu"']
# ['"joe kekabu"']
# ['"joe kekabu"']
# ['"joe kekabu"']
# []
# ['"Engr. Idris Moha"']
# ['"Engr. Idris Moha"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Rev. Fr. David Clark"']
# []
# ['"MR. FRANK ABBA"']
# []
# []
# ['"Mr Williams Mmegi"']
# ['"willford breeks"']
# []
# []
# []
# []
# ['"IAN REED"']
# []
# ['"Wu Kwon"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"raj mohammed"']
# []
# []
# ['"mrs.mable kabila"']
# []
# []
# []
# ['"azize ouattara"']
# ['"idris ali"']
# ['"From,Farhan & Ashia Ghulam."']
# []
# ['"Stephen Wong"']
# ['"henry kabore"']
# ['"hassan ibrahim"']
# []
# []
# ['"dessui mathen"']
# []
# []
# []
# []
# ['"MRS REBECCA GARANG"']
# []
# []
# []
# ['"Smith E. Kimwal"']
# ['"williamspadmore"']
# ['"alexandre biaise"']
# []
# []
# ['"Monica   Gui"']
# ['"amina bello"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"color:green;"']
# ['"bruce nelson"']
# []
# ['"amiri babo"']
# []
# []
# ['"Mr Dennis Steveson."']
# ['"Mr Dennis Steveson."']
# ['"idris ali"']
# []
# []
# []
# ['"abu topia"']
# ['"Mr.Hamad Al"']
# ['"Mr.Hamad Al"']
# []
# ['"musa sani"']
# ['"Mr. ben ezeobi"']
# []
# []
# ['"Brooks Brooks"']
# ['"ALI IBRAHIM"']
# ['"charlessoludo_cbn101"']
# ['"HAJIA RAKIYA ZUBAIRU"']
# ['"joe44jk"']
# []
# ['"Mrs.Amina.A Bello."']
# ['"Mrs. Nazek Rafiq Hariri"']
# []
# ['"naba mohammed"']
# ['"martin"']
# []
# []
# ['"Mrs Teressa Stevens."']
# ['"Mrs. Hilda Ahmed ."']
# ['"ben"']
# ['"azize ouattara"']
# []
# ['"Mr. David Perry"']
# ['"Col. Steve Moore"']
# []
# ['"Mrs.Amina.A.Bello."']
# []
# ['"REVD.FR PETER CLARK"']
# ['"REVD.FR PETER CLARK"']
# ['"REVD.FR PETER CLARK"']
# []
# []
# []
# []
# ['"Mr.Don Kelly."']
# ['"Mrs Farah al-Hashemi"']
# ['"Mrs Farah al-Hashemi"']
# []
# []
# ['"REVD.FR PETER CLARK"']
# ['"mohame kabiro20013"']
# ['"Joseph Wong"']
# []
# ['"Mr.Raymond West"']
# []
# []
# []
# ['"Mrs Farah al-Hashemi"']
# ['"bala tomson"']
# ['"Mr Desmond Koffi"']
# ['"MRS AISHA MOHAMMED"']
# ['"Issac Andani."']
# []
# ['"Alhaji Yusuf A"']
# ['"Alhaji Yusuf A"']
# ['"ben coroma"']
# []
# ['"patrice kone"']
# ['"Jennifer Leary"']
# ['"FROM SUSAN &MUSA"']
# ['"ONLAE WINNER"']
# ['"ysouf arouna0004"']
# []
# []
# ['"john jacob"']
# ['"b_tomson3"']
# ['"james sakato"']
# ['"james sakato"']
# ['"Mrs Farah al-Hashemi"']
# ['"MRS AISHA MOHAMMED"']
# ['"Mr Eddy"']
# ['"Mr Eddy"']
# ['"Mrs Amina Dhari Ali al-Fayadh"']
# ['"Jerome Lewis"']
# []
# []
# ['"Mrs.Aisha Mohhamed"']
# []
# ['"Mrs.Aisha Mohhamed"']
# []
# ['"Kevin Brown"']
# ['"MOSE MALIKI"']
# ['"Prof. Frank Morris"']
# ['"Mrs.Atiya Mohameed"']
# ['"Charles Obiang"']
# []
# ['"mu ga"']
# ['"Revd.Fr. Peter Clark"']
# []
# ['"Sahu Aisha Arafat"']
# []
# []
# ['"olufemicole1\\@walla\\.com"']
# []
# []
# ['"doris luanda"']
# ['"Rev. Fr. David Clark"']
# []
# []
# ['"Mrs. Patricia Khalid ibn Saqr al Qasseemi"']
# ['"Dr. Phil Hodkinson"']
# ['"Mrs. Patricia Khalid ibn Saqr al Qasseemi"']
# []
# ['"Prof. Frank Morris"']
# []
# []
# []
# ['"Mrs Farah al-Hashemi"']
# ['"Nelson"']
# ['"THOMAS DOUGLAS"']
# []
# []
# ['"Qin"']
# ['"MR. Fednard Anih"']
# ['"Ms Rukkyatu Suleiman."']
# ['"usmanbello17"']
# ['"jenniferwils@terra.es"']
# ['"jenniferwils@terra.es"']
# ['"tanwiahmed7575"']
# ['"jenniferwils@terra.es"']
# []
# ['"faith adel"']
# ['"Mr. Fredrick"']
# ['"Mr. Fredrick"']
# ['"Mr. Fredrick"']
# ['"Mr Batholomew"']
# ['"Mrs Benita Sankara"']
# ['"FROM HOFFMAN  BANCOLEY"']
# []
# ['"Mrs Amina Dhari Ali al-Fayadh"']
# []
# []
# []
# ['"Lon Morton"']
# ['"gandu ayuba"']
# ['"Mrs. Patricia Khalid ibn Saqr al Qasseemi"']
# []
# []
# []
# ['"Prof. Frank Morris"']
# ['"Prof. Frank Morris"']
# ['"kofiachampon"']
# []
# []
# []
# []
# ['"mary manto"']
# []
# []
# ['"Mrs. Mariam Abacha"']
# []
# ['"rose coulibally"']
# []
# []
# []
# []
# []
# ['"halija_amed007"']
# ['"pioneer mohammed"']
# ['"DR AMARACHI SAVIMBI."']
# []
# ['"Mrss victoria Lulu"']
# []
# []
# ['"WEST BANK"']
# []
# []
# ['"MR. BRIAN SMITH"']
# ['"Mrs.Amina.A.Bello."']
# []
# ['"Mrs Teressa Stevens."']
# []
# ['"Ms Nasrinn N.Farooq"']
# []
# ['"dan asante"']
# []
# ['"ben_c_ben75"']
# ['"princess silvee09"']
# ['"david kofi"']
# []
# ['"MRS.ROHDA SAEED IBRAHIM."']
# []
# ['"Larisa Sosnitskaya"']
# []
# []
# []
# ['"M RAMSEY"']
# ['"MRS. JANET GARANG."']
# []
# ['"mamou mouna mbulu"']
# ['"mamou mouna mbulu"']
# ['"mrabdullazeez"']
# []
# ['"Mrs. Catherine O\'Connor"']
# []
# ['"Mr.Fred   Chima"']
# ['"Mr Morphil Bako"']
# []
# ['"Mrs Amina Hassan"']
# ['"Chase Online"']
# []
# []
# []
# []
# ['"nasco_haza1"']
# ['"linda kokori"']
# ['"Rebecca Hasan"']
# []
# []
# ['"gabriel baki"']
# []
# []
# ['"Wed lake Bell Guernsey Chambers"']
# ['"Wed lake Bell Guernsey Chambers"']
# ['"Wed lake Bell Guernsey Chambers"']
# []
# ['"Mr. Robin H. Clark"']
# ['"Mrs.AISHA MOHAMMED"']
# []
# []
# []
# ['"alice lacson"']
# ['"Mr Vincent Nicholas."']
# ['"Musa Garuba"']
# ['"nasco haza"']
# []
# ['"joseph taylor"']
# ['"GRAND  FECILITATIONS."']
# []
# []
# ['"2katherine"']
# []
# []
# ['"david ojoh"']
# []
# []
# []
# ['"yinus sulihatu"']
# []
# []
# []
# []
# ['"Mrs Victoria Lulu"']
# []
# []
# []
# ['"faith adel"']
# ['"MOZIE  RAPHAEL."']
# ['"MOZIE  RAPHAEL."']
# []
# ['"Florence Eteh"']
# ['"Mrs Farah al-Hashemi"']
# []
# ['"smart gordon"']
# []
# ['"From Mr Aziz"']
# []
# []
# []
# ['"Martin Goudale"']
# ['"yakube akim"']
# []
# []
# []
# ['"naba mohammed"']
# []
# ['"Sgt. Irvin Shawn."']
# []
# []
# ['"Mr.Jim Nelson"']
# []
# ['"jim"']
# []
# ['"drphilipk@adinet.com.uy"']
# []
# ['"muhamed bello"']
# []
# ['"James Nimely"']
# ['"azzem yaro"']
# ['"azzem yaro"']
# ['"Mrs Farah al-Hashemi"']
# ['"Mrs.Teressa Stevens."']
# ['"Mr Ben"']
# ['"James Nimely"']
# ['"GODFRED AKWESI"']
# []
# ['"Mrs.Suzzan Sainovic"']
# []
# []
# ['"MRA AISHA MOHAMMED"']
# ['"Mr  Phiri  Aboa"']
# ['"dr.jubril ibrahim"']
# ['"Mr. Esau Chirwa"']
# ['"mike"']
# ['"Mr Dennis Stevenson."']
# ['"MRS.LARISA NITSKAYA"']
# ['"CHIEF MAXWELL UDOKA."']
# ['"James Nimely"']
# []
# []
# ['"James Nimely"']
# ['"James Nimely"']
# []
# ['"MR PHILIP ADAM."']
# []
# ['"Mr. Leu Cheng"']
# ['"James Nimely"']
# ['"James Nimely"']
# ['"Mrs.Isabella Caromel"']
# ['"mrs_awa005 mrs_awa005"']
# []
# []
# ['"MR DAVID.R.BALA"']
# ['"Mrs Amina Hassan"']
# []
# ['"From Mr Macuty Udoa"']
# ['"george path"']
# ['"Dr.Kingsley William Mark"']
# ['"mark james"']
# ['"Dr.Kingsley Mark William"']
# ['"MR. GULLY GRACI"']
# ['"MR. GULLY GRACI"']
# []
# ['"sami yusuf"']
# []
# []
# []
# ['"mercyyatteh@adinet.com.uy"']
# ['"george path"']
# []
# ['"Mrs. Maureen Foley"']
# ['"MISS HALIMA ABDULRAHMAN."']
# ['"zhang"']
# ['"hassan  abdoulaye"']
# []
# []
# ['"MR. GULLY GRACI"']
# ['"NADEGE  BAMBA"']
# ['"joe44jk"']
# []
# []
# []
# ['"diratu musa"']
# []
# ['"Garuba Umaru"']
# ['"cbn infocs"']
# []
# []
# ['"Mrs Pilma Kortie"']
# ['"EDWARD  NKANGA"']
# ['"EDWARD  NKANGA"']
# ['"EDWARD  NKANGA"']
# ['"EDWARD  NKANGA"']
# ['"EDWARD  NKANGA"']
# ['"EDWARD  NKANGA"']
# ['"Mrs.Atiya Mohameed"']
# ['"tony reid"']
# ['"chrisbartholet092@adinet.com.uy"']
# ['"Mr. Peter Wallace"']
# []
# ['"Mr. Philips onuma"']
# ['"FROM MISS AICHA KEITA"']
# ['"zhang"']
# ['"ahmed karim"']
# ['"MISS KRA ROSALINE"']
# ['"MRS FARAH AL-HASHEMI"']
# ['"Mrs Farah al-Hashemi"']
# ['"Mrs Farah al-Hashemi"']
# ['"Mr.Jim Harry"']
# ['"mark"']
# ['"Mrs Farah al-Hashemi"']
# []
# []
# []
# ['"MRS FARAH AL-HASHEMI"']
# []
# ['"FROM:MRS.GLORIA DUBE"']
# ['"MRS Cyntia William"']
# ['"MRS LIZY KAMARA"']
# ['"Mrs Kathy Olds "']
# []
# []
# []
# ['"Dickson Dabar"']
# ['"MR. JACK ALAN"']
# ['"sudiq bawa"']
# ['"Huston J."']
# []
# ['"Mr.Idrissa Diop"']
# []
# ['"j.woodly"']
# []
# ['"Lehadi Consultancy"']
# ['"ismaila_ usman"']
# []
# ['"ateeq khan"']
# []
# []
# ['"aziz koffi"']
# ['"hassan   abdoulaye"']
# ['"Mr. Osanar Bonshaw."']
# ['"abdul idrisa030"']
# ['"estelle mamadou"']
# ['"Mrs Amina Hassan"']
# ['"Mrs Amina Hassan"']
# ['"COL KOBIA ABUOM"']
# ['"ibrahim rashid"']
# []
# ['"joe kekabu"']
# []
# []
# []
# []
# []
# ['"Mr. Arif Shaikh"']
# ['"Noel PANGA"']
# ['"Mr. Arif Shaikh"']
# ['"Saviour Toya"']
# ['"Dr. Thomas D. Owen Jr"']
# []
# ['"Dr. Thomas D. Owen Jr"']
# ['"Dr. Thomas D. Owen Jr"']
# []
# []
# ['"joe kekabu"']
# ['"Mr, Larry Willison Udo"']
# ['"Mrs. Zainab Muhamadu Fuseini."']
# ['"MRS FARAH AL-HASHEMI"']
# ['"YSOUF AROUNA"']
# ['"Mrs Farah al-Hashemi"']
# ['"DR RANI ALI JUMA."']
# ['"suleiman ahmed"']
# []
# []
# ['"Hamsa Ahmed"']
# ['"MISS BINTA IBRAHIM."']
# []
# ['"denis messou"']
# ['"jasir kelzi"']
# ['"mu ga"']
# ['"mu ga"']
# ['"Mr.Maxwell Tambo"']
# ['"Mrs.AISHA MOHAMMED."']
# ['"DR DENNIS RAYMOND"']
# ['"Mr.Mohamad Hassan."']
# ['"MRS AISHA MOHAMMED"']
# ['"mu ga"']
# []
# []
# []
# ['"godwin amiri"']
# []
# []
# ['"eric morgan"']
# ['"MRS sharonabed/Abidjan"']
# ['"Dr.Mark Chuks"']
# ['"Amina Hannah Hatleberg."']
# []
# ['"From Dr. Mohammed !"']
# ['"abdulaye baraze"']
# []
# ['"peter johnson"']
# ['"Mr. Hamad Sheikh"']
# ['"justus lee"']
# ['"babu martins"']
# ['"FROM@si.UM"']
# ['"FROM@si.UM"']
# ['"ADAMS IBRAHIM"']
# ['"ADAMS IBRAHIM"']
# ['"cynthia Bouabre"']
# ['"Mr. Ahmed Abdul Kadir"']
# ['"Mr. Ahmed Abdul Kadir"']
# ['"Mr. Johnson Gube"']
# ['"mrs ajaha ahmed"']
# ['"YSOUF AROUNA"']
# ['"YSOUF AROUNA"']
# ['"Mrs.Shelly Brown"']
# ['"Mrs Kimaeva Lioudmila"']
# ['"raji raji"']
# []
# ['"Seyes Campury"']
# []
# ['"FR RICHARD DAVID"']
# ['"Mr. Amos Tower"']
# ['"GOBIND SINGH DEO"']
# ['"Melvin Samson"']
# []
# ['"abumani ibru"']
# ['"TOURE KENNETH"']
# ['"henrykabore"']
# []
# []
# ['"MR DONALD COLLINS"']
# ['"Barr.Emmanuel Okafor"']
# ['"musa garuba"']
# ['"Mr.Abgottspon Ewald"']
# []
# ['"Atik Bassim"']
# ['"Atik Bassim"']
# ['"Mr  Simon Robson"']
# ['"James Williams"']
# ['"DR.USMAN ABUBAKAR"']
# ['"Rev.Mike Ezekiel"']
# ['"Aliu Salami"']
# ['"Denguele Samatigui"']
# ['"MOHAMED DADA FAHAR"']
# []
# []
# []
# ['"hassan musa"']
# ['"john edward"']
# ['"Mrs.Nancy Savimbi"']
# []
# ['"mrs aicha ahmed"']
# ['"Denguele Samatigui"']
# ['"Dr Suleman m"']
# ['"FATIMA ALI"']
# []
# []
# ['"Mrs.Alima Ahmed"']
# []
# ['"Mr. Arif Shaikh"']
# ['"TAMARA  KULO"']
# ['"Dr. KELVIN PROMCHAY"']
# ['"Dr. KELVIN PROMCHAY"']
# ['"FATIMA ALI"']
# ['"Noel PANGA"']
# ['"harrison compaore"']
# []
# ['"Mrs Haddiya Amina Hassan"']
# []
# ['"Mr.Adnan A.K.Ismail"']
# []
# ['"joe alex"']
# ['"Mohamed Zahir Moustafa"']
# []
# ['"george path"']
# ['"george path"']
# ['"Noel PANGA"']
# ['"danjuma ali"']
# []
# ['"Mr.Al_hadji Azizi ."']
# ['"Alpha Kone"']
# ['"Mr Usman Lama"']
# []
# []
# ['"MR.ANDREW GAMA"']
# ['"MR. ANDREW GAMA"']
# ['"Madinatu"']
# ['"Comhghall Partin"']
# ['"Rose D. Aboka"']
# []
# ['"mrs prisca konan"']
# ['"FATIMA ALI"']
# []
# []
# []
# ['"jonesalun@terra.es"']
# []
# ['"Mr.Wilson Ogodi"']
# []
# ['"Mr.Wilson Ogodi"']
# ['"ouadrago lssaka"']
# []
# []
# []
# ['"Mr James Owusu"']
# ['"Mr Usman Lama"']
# ['"Miss Lilian Abba"']
# ['"Mr Liow Hanoi"']
# []
# ['"Prince Joseph Taylor"']
# ['"Denguele Djaratigui"']
# ['"MRS SHADE IBRAHIM"']
# []
# ['"John Taylor."']
# []
# []
# []
# []
# ['"MRS NGONI ELITA TAWANDA"']
# ['"Ali Hussein"']
# ['"sammar   sisnene"']
# []
# []
# []
# []
# []
# ['"Mr. Wright Gilbson"']
# ['"jajasha_ ali0040"']
# ['"Mr.Simon Wong"']
# ['"David Clifford"']
# ['"Dr. Kingsley William Mark"']
# ['"rita abed"']
# []
# ['"Mrs.Mary Abavana"']
# []
# ['"ibrahim mustapha"']
# []
# []
# ['"aziz usman"']
# ['"jajasha_ ali0047"']
# ['"alhajisule@cmportal.com.ar"']
# ['"MOHAMMED HASSAN"']
# []
# ['"Waleed Ibrahim Mohamed"']
# ['"Waleed Ibrahim Mohamed"']
# []
# ['"Waleed Abdalla Ibrahim Mohamed"']
# ['"Waleed Abdalla Ibrahim Mohamed"']
# ['"Mr.Francis Williams"']
# []
# []
# ['"Mr.Paul BENSON"']
# []
# ['"FR RICHARD DAVID"']
# []
# ['"koffi michel"']
# []
# []
# ['"peter daniel"']
# ['"iru dunu"']
# ['"bintu pat"']
# ['"iru dunu"']
# ['"Mr. Thompson J. Alber"']
# ['"James Berry (Esq)"']
# ['"Mrs Farah al-Hashemi"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"MR. PAUL CLARKE"']
# ['"vikki meade"']
# ['"FATIMA ALI"']
# ['"FATIMA ALI"']
# []
# ['"Engr. Robert Edmond."']
# []
# []
# ['"Maria Rose Muduo"']
# ['"Rev.Thomas Douglas"']
# []
# ['"Princewill Nkoma "']
# ['"Dr Latif Abdul"']
# []
# ['"From . Mr. Simon Robson."']
# ['"yusuf ali"']
# ['"aminatu12006@excite.com"']
# []
# []
# []
# ['"alain konan"']
# ['"britt benson"']
# []
# ['"Dr.Allen. Smith."']
# []
# []
# []
# []
# ['"samuel_ petters08"']
# ['"woma lee"']
# []
# []
# []
# ['"Willison Van"']
# ['"Miss Rither Amadi"']
# ['"Dr.Chinedu Ego"']
# ['"Mr. Anuka Alex Ifufeh."']
# []
# ['"Mr. Anuka Alex Ifufeh."']
# []
# ['"Mr. Ahmed Abdul Kadir"']
# ['"G. Mattioli \\(Fondazione Di Vittorio\\)"']
# []
# ['"Mr, Ernest  williams"']
# []
# ['"Mr.Wilson Ogodi"']
# []
# []
# ['"kaka yobo"']
# []
# []
# []
# ['"mark nguessane"']
# ['"Mr. Peter Kwaku"']
# ['"MRS AISHA MOHAMMED"']
# ['"Dr. Ahmed Suleman"']
# ['"mark nguessane"']
# ['"Mr.Ajoy Sonya."']
# ['"joseph koliga"']
# ['"jones usman"']
# ['"Mrs.Atiya Mohameed"']
# ['"S.A.Rehman"']
# ['"Mr. Bill Karim"']
# []
# []
# ['"MR.ERIC STEPHEN"']
# ['"MR.ERIC STEPHEN"']
# ['"James Nimely"']
# []
# []
# ['"Mr.Abdull Nasser"']
# []
# []
# []
# ['"DR.MIKE JEFFERY"']
# []
# ['"Melika Diouf"']
# ['"Melika Diouf"']
# ['"SUSAN .H. ROSE"']
# ['"James Nimely"']
# ['"lillian21"']
# ['"lillian21"']
# ['"lillian21"']
# []
# []
# []
# ['"sa_dlo1@terra.es"']
# []
# []
# ['"william_muyek2006@yahoo.com"']
# ['"PLEASE REPLY SOON."']
# []
# ['"Dr Thomas Chess"']
# ['"Dr. Louis Ferdinand"']
# ['"dessue mathean"']
# ['"Mr.Francis Williams"']
# ['"usman bello"']
# []
# []
# []
# []
# []
# []
# ['"amina bello"']
# []
# ['"rose mathew"']
# []
# ['"Mrs Farah al-Hashemi"']
# ['"Mrs Farah al-Hashemi"']
# []
# []
# []
# ['"Talla  Dou"']
# []
# ['"DAVID   ROBERTS [BARCLAYS BANK]."']
# []
# ['"DAVID   ROBERTS [BARCLAYS BANK]."']
# []
# []
# ['"Mr.Max T."']
# ['"catherine schole"']
# []
# []
# ['"Melika Diouf"']
# ['"casparjjustin2@yahoo.co.uk"']
# ['"monica edmond"']
# []
# []
# ['"Dr.Ali Ibrahim"']
# []
# []
# ['"Mr. Abdul Taha & Sister."']
# ['"ibrahim_ mussa5"']
# []
# ['"joy"']
# ['"irfcv volunteers"']
# ['"Mrs. Alondra Jose-Carlos"']
# ['"SHANG FULIN"']
# ['"miss peace"']
# []
# ['"zuma bullians"']
# []
# []
# ['"miss fatoumata"']
# []
# ['"S.A.Rehman"']
# ['"MIKE ZANKO"']
# []
# []
# []
# ['"MR JAMES SILAS"']
# []
# []
# []
# []
# ['"zeid ahmadi"']
# ['"yes yes"']
# []
# ['"jerry berry"']
# ['"MRS VICTORIA BOLANO."']
# ['"DR.DON MIGINIS"']
# ['"DR.HENRY SALAMI."']
# ['"DR.HENRY SALAMI."']
# ['"MR.JONES ADEX"']
# ['"MR. JONES ADEX"']
# []
# []
# ['"mustafa ali"']
# ['"mustafa ali"']
# ['"Dr. Gill Mbabane"']
# []
# ['"James Nimely"']
# []
# []
# ['"alice lacson"']
# ['"CENTRALBANK_ FOREGINREMINTANCE.COM"']
# []
# ['"DR.DANIEL IBE."']
# ['"hagis jain"']
# ['"hagis jain"']
# ['"alhji imam"']
# []
# ['"Ajken udea"']
# ['"Peter Gungula"']
# ['"Mrs Amina Hassan"']
# ['"MUHAMED HASSANE"']
# ['"MUHAMED HASSANE"']
# []
# []
# ['"Al-Zarqawi Yusuf"']
# []
# ['"david zongo"']
# []
# ['"From: Lady Peggy Morrison,"']
# []
# []
# []
# ['"Mr Adams"']
# []
# ['"Dr.Mike Chibuzor"']
# ['"Mr. Johnson Moyo"']
# []
# ['"Mr Zedex Calvaho"']
# ['"MRS. PATRICIA SAVIMBI"']
# []
# ['"MRS. PATRICIA SAVIMBI"']
# []
# ['"Dr Willson Van"']
# []
# []
# ['"Mrs. Sandra White"']
# ['"Dr.David Bryan Ellis"']
# []
# []
# []
# []
# []
# []
# ['"Ms.Aminata B.Kabila"']
# ['"mona khalil"']
# ['"Oumarou Trikouni"']
# []
# ['"kaburo musa"']
# ['"mr ibrahim"']
# ['"Mr. Simon Robson"']
# ['"gambo abudul"']
# []
# ['"Mr Patrick K W Chan"']
# []
# ['"Mr Patrick K W Chan"']
# []
# ['"Mr Patrick K W Chan"']
# []
# ['"ousmane hamed"']
# ['"Mr. CLIVEWHITTAKER"']
# ['"Mr. Femi Gidado"']
# ['"Mr. Femi Gidado"']
# ['"Mr.Femi Gidado"']
# ['"Mr. Johnson Moyo"']
# []
# ['"sam ibrahim5"']
# []
# ['"Oumarou Trikouni"']
# ['"MR. JOHN FISHER"']
# []
# []
# []
# []
# ['"MR EDDY IBE,"']
# ['"Engr Ikenga Eri"']
# ['"Saees Ahmed"']
# []
# ['"Mrs.Atiya Mohameed"']
# ['"Madam Aicha Ahmed"']
# []
# []
# []
# ['"Mr. Simon Robson"']
# []
# ['"MR.  EDWARD  BROWN"']
# []
# []
# []
# ['"stephean lawrence"']
# []
# []
# []
# ['"stephean lawrence"']
# []
# []
# []
# ['"Mr. Micheal Tan"']
# ['"david1111kalabi@terra.es"']
# ['"LAMI KALLON"']
# []
# ['"sheriff johnson"']
# []
# []
# ['"Mis.Amina Idris"']
# ['"javed ahmed"']
# []
# []
# ['"Dr. Abdul Siop"']
# ['"Sir John Wilson."']
# []
# ['"ALICE000000048286661@fbc.local"']
# ['"MRS.AISHA MOHAMMED."']
# ['"Mrs Farah al-Hashemi"']
# []
# ['"Jack Vanrenos Esq."']
# ['"Huang Yanxiong"']
# ['"service@irelandjail.com"']
# ['"Mrs. Shade lbrahim"']
# ['"baro isa"']
# []
# []
# ['"Barr.Mark Grillo"']
# ['"raji raji"']
# []
# []
# ['"john nna"']
# ['"sankara usman"']
# ['"sankara usman"']
# ['"Ying Cheng"']
# ['"Mr. Hon-Hing Wong"']
# ['"BARNETT SCOTT"']
# ['"BARNETT SCOTT"']
# ['"djema farid"']
# ['"mussa ali"']
# ['"ahmed hassana"']
# ['"Mrs. Tonia Van Smith"']
# []
# []
# []
# ['"DR.LESTER WALLACE"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"markwwww@terra.es"']
# ['"=?iso-8859-1?Q?Fred_Gabby?="']
# []
# []
# []
# ['"Andrew Clark"']
# ['"amedi ali"']
# []
# []
# ['"Mr Mohammad Musa"']
# ['"Mary A. CHATHAM"']
# ['"LETTER FROM MR.JOSEPH POON"']
# ['"STELLA DIKKO SAMBA"']
# []
# []
# []
# []
# ['"mark_ibe02@elsalvador.com"']
# []
# []
# ['"RAHA ALI"']
# ['"Ms Silvia Mavasa."']
# ['"Roland Bartic"']
# ['"Dr Azizan coker"']
# ['"mrs shade lbrahim"']
# []
# ['"zainab fuseini"']
# []
# ['"mark akima"']
# ['"MICHAEL  KAMARA"']
# ['"mark akima"']
# ['"MARK AKIMA"']
# []
# ['"karem ahmed"']
# ['"central bank"']
# ['"central bank"']
# ['"central bank"']
# ['"Mr. Richard Wainwright"']
# []
# []
# ['"usman sankara"']
# ['"pascal dunga"']
# ['"Dr. Suleman M"']
# []
# []
# ['"Dr.David Bryan Ellis"']
# ['"Stanley Jones."']
# ['"azem usman"']
# ['"WILLIAMS MORROW"']
# ['"DR.BISI OMOYENI."']
# ['"DR. BISI OMOYENI."']
# ['"karem ahmed"']
# ['"mrs aicha"']
# ['"Barrister Martinez Obe."']
# ['"DR.BISI OMOYENI."']
# ['"DR.BISI OMOYENI."']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# ['"Dr. Kenneth Scott"']
# []
# []
# ['"ishmila sani"']
# ['"derek17800@tiscali.cz"']
# ['"usman karim"']
# []
# []
# []
# ['"Michael Howard"']
# ['"Michael Howard"']
# []
# ['"Chen Jiang"']
# ['"Mrs. Doris Janjani"']
# []
# ['"ibrahim usman"']
# ['"firstabngplc@hotmail.com"']
# ['"alimatou ouedraogo"']
# []
# ['"pissa kabore"']
# []
# []
# []
# []
# ['"idris makafi"']
# ['"idris makafi"']
# ['"harrison ken"']
# ['"MR. JAMES SMITH"']
# []
# []
# []
# ['"moha william"']
# []
# []
# []
# []
# ['"ali abdulahi"']
# ['"ibrahim niabba"']
# []
# ['"Maria Socorro"']
# []
# []
# ['"Wujiang Wanlida Textile Co.Ltd."']
# ['"adamu ismaler"']
# []
# []
# []
# []
# ['"hassan sass"']
# ['"frank jewell"']
# []
# ['"frank jewell"']
# []
# []
# []
# []
# ['"benjamin ame"']
# []
# []
# []
# ['"Mr. Chris Swales"']
# ['"abisha allahim"']
# ['"desmond martin"']
# ['"Musa Dura"']
# ['"adama j.k kambore"']
# ['"Daivd Bryan"']
# []
# ['"Daniel Johnson"']
# ['"kelleyko"']
# ['"usman adamu"']
# ['"Mr.Philip Tarila"']
# ['"MRS. LARISA SOSNITSKAYA"']
# ['"Dr.David Bryan Ellis"']
# ['"Dr.David Bryan Ellis"']
# ['"saku watara"']
# ['"mas ahmed"']
# ['"Dr. Paul A. Sule"']
# []
# []
# []
# ['"Elliott I. Gideon"']
# ['"sayid mustafa"']
# []
# ['"Mr. Robert King"']
# ['"dan wahili"']
# []
# ['"buhari_ buhari_tijani00011"']
# ['"Muspham Benson"']
# []
# []
# []
# ['"mussa sani"']
# []
# ['"Rusty Campbell"']
# []
# ['"Rachael Oniga"']
# []
# ['"HANG SENG BANK"']
# ['"Mr. Richard Williams."']
# ['"linda1m1@terra.es"']
# ['"stella"']
# []
# ['"EVANGELIST REACHEL MIKE."']
# ['"evansonumba16@tiscali.co.uk"']
# []
# ['"Dr.Mohammed Azeez"']
# []
# ['"Mr Patrick K.W Chan."']
# ['"MRS. LARISA SOSNITSKAYA"']
# []
# []
# []
# ['"maureen mike"']
# []
# []
# ['"Patrick Berger"']
# []
# []
# []
# ['"sani mustapha"']
# []
# ['"E.U. PHILIPSON & SOLICITORS"']
# ['"adamu ali"']
# []
# []
# ['"favour"']
# []
# []
# []
# []
# ['"DrDinka Dogon"']
# []
# []
# ['"Ken Saro-wiwa Jr."']
# []
# ['"Mr Charles Greene"']
# ['"Admin. Office"']
# ['"ANTHONY  DILLION"']
# []
# []
# []
# []
# ['"alex daniel"']
# []
# ['"Barrister Gareth Jones"']
# []
# ['"muhammd amin"']
# []
# ['"MR. ADRIAAN CHRIS"']
# ['"Ganeswary Ajith Kumar"']
# []
# ['"HASSAN BILLY"']
# ['"idrisa biko"']
# []
# ['"MR.ROBERT JOHN"']
# []
# []
# ['"MR.  JOHN  FISHER"']
# ['"pae.za@terra.es"']
# ['"MRS. LARISA SOSNITSKAYA"']
# []
# ['"Mr. Nopparat Sujaritpinij"']
# ['"Mr. Moreno Garcia"']
# ['"Mrs.Mary Saleh Galal"']
# []
# []
# ['"Barrister Gareth Jones"']
# []
# ['"Edward Moore & Associates"']
# ['"Mr John Jasper"']
# []
# []
# ['"Edward Moore & Associates"']
# []
# ['"Edward Moore & Associates"']
# []
# ['"Edward Moore & Associates"']
# []
# ['"Edward Moore & Associates"']
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Edward Moore & Associates"']
# ['"Mr. Gamudi Mboma"']
# []
# []
# []
# []
# []
# []
# ['"Mr.Jonathan Mutambara"']
# []
# ['"FREDERICK WILLIAMS."']
# []
# ['"Mahmud Azzam"']
# ['"Mahmud Azzam"']
# []
# []
# ['"MRS. LARISA SOSNITSKAYA"']
# []
# []
# []
# ['"MRS. LARISA SOSNITSKAYA"']
# ['" MR james roberts"']
# []
# ['"Dr. Paul A. Sule"']
# []
# ['"alimoheamed1"']
# ['"Mr. Joseph Chau."']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Mr. Albert Sitholi"']
# []
# []
# []
# []
# ['"PETER NDABA"']
# []
# ['"DR DAVID RAY"']
# []
# []
# ['"Mikhail Khodorkovsky"']
# []
# []
# []
# []
# ['"A.B. Solarin"']
# ['"Martins Mazuri"']
# ['"Mr. Peter Leon"']
# []
# []
# []
# []
# ['"IRS"']
# []
# []
# ['"MR. MARK ADAMS"']
# ['"MR. MARK ADAMS"']
# ['"bala kabore"']
# ['"DR.IDRISSA SEKK"']
# []
# []
# []
# []
# []
# []
# ['"Chief Anthony Enahoro. JP"']
# ['"Richard Akintunde"']
# ['"Martins Akim"']
# ['"Dr. Ahmed Hassan"']
# ['"Dr. Ahmed Hassan"']
# ['"LUISA ESTRADA"']
# []
# ['"Evangelist Lindy Mike (Widow)."']
# []
# []
# []
# ['"Edward Moore & Associates"']
# []
# ['"Edward Moore & Associates"']
# ['"bjsri budak"']
# []
# []
# []
# ['"Mr. Robin Shephard"']
# ['"Martin J. Waghorn"']
# []
# ['"Didan Kimati"']
# []
# []
# ['"BACKGROUND: none transparent scroll repeat 0% 0%; CURSOR: hand; BORDER-BOTTOM: #0066cc 1px dashed; HEIGHT: 1em"']
# []
# []
# ['"Dave Yorke."']
# ['"Mrs  Farah Al-hashemi"']
# ['"Mrs  Farah Al-hashemi"']
# []
# []
# []
# []
# []
# []
# []
# []
# ['"REV.WILSON MORGAN"']
# ['"REV.WILSON MORGAN"']
# []
# []
# []
# ['"Mr Aphisak Tantiworawong"']
# []
# []
# []
# ['"Mr.Morgan Wimpoe"']
# []
# ['"Adekunle michael."']
# []
# []
# []
# []
# ['"DR. CLEMENT ASUZU"']
# []
# ['"Bank of America"']
# []
# ['"Prof.Charles.C.Soludo"']
# []
# ['"jen_marthin"']
# []
# []
# ['"aziz moustafa"']
# []
# ['"Mrs Farah al-Hashemi"']
# []
# []
# []
# ['"bajoga bajoga"']
# ['"Robert Zulugan."']
# ['"Mrs. Farah al-Hashemi"']
# []
# []
# []
# []
# []
# ['"GOBLOUSO SOLANGE "']
# []
# []
# []
# ['"Christopher  Wilson"']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['"Mr A.B Solarino"']
# []
# []
# ['"Sunoco Sun Oil Company Ltd"']
# ['"Sunoco Sun Oil Company Ltd"']
# []
# []
# []
# []
# []
# []
# ['"Steven Lee"']
# []
# []
# []
# ['"MR. KENNETH MASHABA"']
# []
# ['"The SHIGA BANK LTD"']
# ['"Louis (Business).."']
# ['"The SHIGA BANK LTD"']
# ['"MRS. ANNAH KRUGA"']
# []
# ['"julia.chen.shenhua.group@hotmail.com"']
# []
# []
# ['"james bongani"']
# []
# []
# []
# []
# ['"BARR.JONATHAN WRIGHT"']
# []
# []
# []
# []
# ['"Dr. David Smith"']
# []
# []
# ['"HENRY ALLEN"']
# []
# []
# []
# ['"Fernando Gonzalez"']
# ['"From: Dr. Jackson Gaius-Obaseki"']
# []
# []
# []
# []
# []
# []
# []

# %% [markdown]
# Notice that we use a backslash next to the first quotation mark. The backslash is a special character used for escaping other special characters. For instance, when we want to use a quotation mark as a string literal instead of a special character, we escape it with a backslash like this: \". If we do not escape the pattern above with backslashes, it would become "".*"", which the Python interpreter would read as a period and an asterisk between two empty strings. It would produce an error and break the script. Hence, it’s crucial that we escape the quotation marks here with backslashes.
#
# After the first quotation mark is matched, .* acquires all the characters in the line until the next quotation mark, also escaped in the pattern. This gets us just the name, within quotation marks. The name is also printed within square brackets because re.findall returns matches in a list.

# %% [markdown]
# #email address

# %%
match = re.findall("From:.*", fh)

for line in match:
    print(re.findall("\w\S*@.*\w", line))

# %% [markdown]
# Emails always contain an @ symbol, so we start with it. The part of the email before the @ symbol might contain alphanumeric characters, which means w is required. However, because some emails contain a period or a dash, that’s not enough. We add S to look for non-whitespace characters. But, w\S will get only two characters. Add * to look for repetitions. The front part of the pattern thus looks like this: \w\S*@.

# %%
for line in match:
    print(re.findall("@.*", line))

# %% [markdown]
# The domain name usually contains alphanumeric characters, periods, and a dash sometimes, so a . will do. To make it greedy, we extend the search with a *. This allows us to match any character till the end of the line.
#
# If we look at the line closely, we see that each email is encapsulated within angle brackets, < and >. Our pattern, .*, includes the closing bracket, >. Let’s remedy it:

# %%
for line in match:
    print(re.findall("@.*\w", line))

# %% [markdown]
# Email addresses end with an alphanumeric character, so we cap the pattern with w. So, after the @ symbol we have .*\w, which means that the pattern we want is a group of any type of characters ending with an alphanumeric character. This excludes >.
#
# Our full email address pattern thus looks like this: \w\S*@.*\w.

# %%
for line in match:
    print(re.findall("\w\S*@.*\w", line))

# %% [markdown]
# #Common Python Regex Functions
# re.findall() is undeniably useful, but it’s not the only built-in function that’s available to us in re:
#
# re.search()
#
# re.split()
#
# re.sub()

# %% [markdown]
# re.search()
# While re.findall() matches all instances of a pattern in a string and returns them in a list, re.search() matches the first instance of a pattern in a string, and returns it as a re match object.

# %%
match = re.search("From:.*", fh)
print(type(match))
print(type(match.group()))
print(match)
print(match.group())
# Out:
# <class '_sre.SRE_Match'>
# <class 'str'>
# <_sre.SRE_Match object; span=(190, 244), match='From: "MR. JAMES NGOLA." <james_ngola2002@maktoob>
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>

# %% [markdown]
# Like re.findall(), re.search() also takes two arguments. The first is the pattern to match, and the second is the string to find it in. Here, we’ve assigned the results to the match variable for neatness.
#
# Because re.search() returns a re match object, we can’t display the name and email address by printing it directly. Instead, we have to apply the group() function to it first. We’ve printed both their types out in the code above. As we can see, group() converts the match object into a string.
#
# We can also see that printing match displays properties beyond the string itself, whereas printing match.group() displays only the string.

# %% [markdown]
# #re.split()
# Suppose we need a quick way to get the domain name of the email addresses. We could do it with three regex operations, like so:

# %%
address = re.findall("From:.*", fh)
for item in address:
    for line in re.findall("\w\S*@.*\w", item):
        username, domain_name = re.split("@", line)
        print("{}, {}".format(username, domain_name))

# %% [markdown]
# The first line is familiar. We return a list of strings, each containing the contents of the From: field, and assign it to a variable. Next, we iterate through the list to find the email addresses. At the same time, we iterate through the email addresses and use the re module’s split() function to snip each address in half, with the @ symbol as the delimiter. Finally, we print it.

# %% [markdown]
# #re.sub()
# Another handy re function is re.sub(). As the function name suggests, it substitutes parts of a string. An example:

# %%
sender = re.search("From:.*", fh)
address = sender.group()
email = re.sub("From", "Email", address)
print(address)
print(email)
# Out:
# From: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>
# Email: "MR. JAMES NGOLA." <james_ngola2002@maktoob.com>

# %% [markdown]
# We’ve already seen the tasks on the first and second lines before. On the third line, we apply re.sub() on address, which is the full From: field in the email header.
#
# re.sub() takes three arguments. The first is the substring to substitute, the second is a string we want in its place, and the third is the main string itself.

# %% [markdown]
# #Sorting Emails with Python Regex and Pandas
# Our corpus is a single text file containing thousands of emails (though again, for this tutorial we’re using a much smaller file with just two emails, since printing the results of our regex work on the full corpus would make this post far too long).
#
# We’ll use regex and pandas to sort the parts of each email into appropriate categories so that the Corpus can be more easily read or analysed.
#
# We’ll sort each email into the following categories:
#
# sender_name
#
# sender_address
#
# recipient_address
#
# recipient_name
#
# date_sent
#
# subject
#
# email_body
#
#
#
#
# Each of these categories will become a column in our pandas dataframe (i.e., our table). This will make it easier for us work on and analyze each column individually.
#
# We’ll keep working with our small sample, but it’s worth reiterating that regular expressions allow us to write more concise code. Concise code reduces the number of operations our machines have to do, which speeds up our analytical process. Working with our small file of two emails, there’s not much difference, but if you try processing the entire corpus with and without regex, you’ll start to see the advantages!

# %% [markdown]
# #Importing
# To start, let’s import the libraries we’ll need and get our file opened again.
#
# In addition to re and pandas, we’ll import Python’s email package as well, which will help with the body of the email. The body of the email is rather complicated to work with using regex alone. It might even require enough cleaning up to warrant its own tutorial. So, we’ll use the well-developed email package to save some time and let us focus on learning regex.

# %%
import re
import pandas as pd
import email

emails = []

fh = open(r"fradulent_emails.txt", "r",encoding="utf8", errors='ignore').read()

# %% [markdown]
# We’ve also created an empty list, emails, which will store dictionaries. Each dictionary will contain the details of each email.
#
# Now, let’s begin applying regex!

# %%
contents = re.split(r"From r", fh)
#contents
contents.pop(0)
# Out:
# ''

# %% [markdown]
# We use the re module’s split function to split the entire chunk of text in fh into a list of separate emails, which we assign to the variable contents. This is important because we want to work on the emails one by one, by iterating through the list with a for loop. But, how do we know to split by the string "From r"?
#
# We know this because we looked into the file before we wrote the script. We didn’t have to peruse the thousands of emails in there. Just the first few, to see what the structure of the data looks like. Whenever possible, it’s good to get your eyes on the actual data before you start working with code, as you’ll often discover useful features like this.

# %% [markdown]
# Emails start with “From r”
#
# Disorganized data like this may require a lot of cleaning up. For instance, even though we count 3,977 emails in this set using the full script we’re about to construct for this tutorial, there are actually more. Some emails actually are not preceded by "From r", and so are not counted separately. (However, for the purposes of brevity, we’ll proceed as if that issue has already been fixed and all emails are separated by "From r".)
#
# Notice also that we use contents.pop(0) to get rid of the first element in the list. That’s because a "From r" string precedes the first email. When that string is split, it produces an empty string at index 0. The script we’re about to write is designed for emails. If we try to use it on an empty string, it might throw errors. Getting rid of the empty string lets us keep these errors from breaking our script.

# %% [markdown]
# #Getting Every Name and Address With a For Loop

# %%
count =0
for item in contents:
# First two lines again so that Jupyter runs the code.
  emails_dict = {}

# Find sender's email address and name.
  #if count ==0: 
  print(item)
    # Step 1: find the whole line beginning with "From:".
  sender = re.search(r"From:.*", item)
    #print(sender.group())

# %%
type(sender)
# Out:
# NoneType

# %% [markdown]
# With Step 1, we find the entire From: field using the re.search() function. The . means any character except n, and * extends it to the end of the line. We then assign this to the variable sender.
#
# But, data isn’t always straightforward. It can contain surprises. For instance, what if there’s no From: field? The script would throw an error and break. We pre-empt errors from this scenario in Step 2.

# %%
for item in contents:
# First two lines again so that Jupyter runs the code.
    emails_dict = {}

# Find sender's email address and name.

    # Step 1: find the whole line beginning with "From:".
    sender = re.search(r"From:.*", item)


# Step 2: find the email address and name.
    if sender is not None:
        s_email = re.search(r"\w\S*@.*\w", sender.group())
        s_name = re.search(r":.*<", sender.group())
    else:
        s_email = None
        s_name = None

# %%
print("sender type: " + str(type(sender)))
# Out:
# sender type: <class 'NoneType'>

# %% [markdown]
# We’ll use a different tactic for the name. Each name is bounded by the colon, :, of the substring "From:" on the left, and by the opening angle bracket, <, of the email address on the right. Hence, we use :.*< to find the name. We get rid of : and < from each result in a moment.
#
# Now, let’s print out the results of our code to see how they look.

# %% [markdown]
# recall that if there is no From: field, sender would have the value of None, and so too would s_email and s_name. Hence, we have to check for this scenario again so that the script doesn’t break unexpectedly. Let’s see how to construct the code with s_email first.

# %%
for item in contents:
# First two lines again so that Jupyter runs the code.
  emails_dict = {}

# Find sender's email address and name.

    # Step 1: find the whole line beginning with "From:".
  sender = re.search(r"From:.*", item)
  # Step 2: find the email address and name.
  if sender is not None:
    s_email = re.search(r"\w\S*@.*\w", sender.group())
    s_name = re.search(r":.*<", sender.group())
  else:
    s_email = None
    s_name = None

# Step 3A: assign email address as string to a variable.
  if s_email is not None:
      sender_email = s_email.group()
  else:
      sender_email = None
# Add email address to dictionary.
  emails_dict["sender_email"] = sender_email

  if s_name is not None:
      sender_name = re.sub("s*<", "", re.sub(":s*", "", s_name.group()))
  else:
      sender_name = None

# Add sender's name to dictionary.
  emails_dict["sender_name"] = sender_name
  print(emails_dict)
# Out:
# {'sender_email': 'james_ngola2002@maktoob.com', 'sender_name': ' "MR. JAMES NGOLA." '}
# {'sender_email': 'bensul2004nng@spinfinder.com', 'sender_name': ' "Mr. Ben Suleman" '}
# {'sender_email': 'obong_715@epatra.com', 'sender_name': ' "PRINCE OBONG ELEME" '}
# {'sender_email': 'obong_715@epatra.com', 'sender_name': ' "PRINCE OBONG ELEME" '}
# {'sender_email': 'm_abacha03@www.com', 'sender_name': ' "Maryam Abacha" '}
# {'sender_email': 'davidkuta@postmark.net', 'sender_name': ' Kuta David '}
# {'sender_email': 'tunde_dosumu@lycos.com', 'sender_name': ' "Barrister tunde dosumu" '}
# {'sender_email': 'william2244drallo@maktoob.com', 'sender_name': ' "William Drallo" '}
# {'sender_email': 'abdul_817@rediffmail.com', 'sender_name': ' "MR USMAN ABDUL" '}
# {'sender_email': 'barrister_td@lycos.com', 'sender_name': ' "Tunde  Dosumu" '}
# {'sender_email': 'temijohnson2@rediffmail.com', 'sender_name': ' MR TEMI JOHNSON '}
# {'sender_email': 'sjordan@diplomats.com', 'sender_name': ' "Dr.Sam jordan" '}
# {'sender_email': 'p_brown2@lawyer.com', 'sender_name': None}
# {'sender_email': 'mic_k1@post.com', 'sender_name': None}
# {'sender_email': 'mikebunduu1@rediffmail.com', 'sender_name': ' "COL. MICHAEL BUNDU" '}
# {'sender_email': 'elixwilliam@usa.com', 'sender_name': ' "MRS MARIAM ABACHA" '}
# {'sender_email': 'anayoawka@hotmail.com', 'sender_name': ' " DR. ANAYO AWKA " '}
# {'sender_email': 'anayoawka@hotmail.com', 'sender_name': ' " DR. ANAYO AWKA " '}
# {'sender_email': 'victorloma@netscape.net', 'sender_name': ' "Victor Aloma" '}
# {'sender_email': 'victorloma@netscape.net', 'sender_name': ' "Victor Aloma" '}
# {'sender_email': 'james_ngola2002@maktoob.com', 'sender_name': ' "JAMES NGOLA" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'martinchime@usa.com', 'sender_name': ' "MARTIN CHIME" '}
# {'sender_email': 'mboro1555@post.com', 'sender_name': ' "Mr George Mboro" '}
# {'sender_email': 'martinchime@borad.com', 'sender_name': ' "MARTIN  CHIME" '}
# {'sender_email': 'martinchime@borad.com', 'sender_name': ' "MARTIN  CHIME" '}
# {'sender_email': 'edema_mb@phantomemail.com', 'sender_name': ' '}
# {'sender_email': 'edema_mb@phantomemail.com', 'sender_name': ' '}
# {'sender_email': 'adewilliams_ade@lawyer.com', 'sender_name': ' "ADE WILLIAMS" '}
# {'sender_email': 'smithkam2@post.com', 'sender_name': None}
# {'sender_email': 'sesm@omaninfo.com', 'sender_name': ' "MRS. M SESE-SEKO" '}
# {'sender_email': 'obinaokoro@37.com', 'sender_name': ' "obina okoro" '}
# {'sender_email': 'jamesalbert0@eircom.net', 'sender_name': ' "DR. JAMES  ALBERT" '}
# {'sender_email': 'adamuohiroma.adamuohiroma@caramail.com', 'sender_name': ' adamuohiroma adamuohiroma '}
# {'sender_email': 'fredobi3@omaninfo.com', 'sender_name': ' "MR FRED OBI." '}
# {'sender_email': 'mbengu@37.com', 'sender_name': ' "mbeki ngumeni" '}
# {'sender_email': 'mmahoyi@caramail.com', 'sender_name': ' mahoyi mamudu '}
# {'sender_email': 'adgua@mail.com', 'sender_name': ' "Mr. David Agu" '}
# {'sender_email': 'bbell.idr@caramail.com', 'sender_name': ' "bell.idr bell.idr" '}
# {'sender_email': 'iidris.bello@caramail.com', 'sender_name': ' "idris.bello idris.bello" '}
# {'sender_email': 'john2002@bluemail.ch', 'sender_name': None}
# {'sender_email': 'clem-apute@consultant.com', 'sender_name': ' "CLEMENT APUTE" '}
# {'sender_email': 'g.godwin12345@caramail.com', 'sender_name': ' "MR GODWIN IGBUNU" '}
# {'sender_email': 'bbell.idr@caramail.com', 'sender_name': ' "bell.idr bell.idr" '}
# {'sender_email': 'dav84@mail.com', 'sender_name': ' "Mr. David Agu" '}
# {'sender_email': 'kabila72b@37.com', 'sender_name': ' "deborah kabila" '}
# {'sender_email': 'kss07@go.com', 'sender_name': ' Khalifa Sese '}
# {'sender_email': 'kss07@go.com', 'sender_name': ' Khalifa Sese '}
# {'sender_email': 'mohammed_bello_1@yahoo.com', 'sender_name': ' "MOHAMMED BELLO (Ph.D)" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'cooooofoooooooo@rediffmail.com', 'sender_name': ' "PETER WILLIAMS" '}
# {'sender_email': 'olivsav@netscape.net', 'sender_name': ' "Oliveira Savimbi" '}
# {'sender_email': 'tdannosondu@mail.com', 'sender_name': ' "Mr. Daniel Osondu" '}
# {'sender_email': 'williamsdaniel1@phantomemail.com', 'sender_name': ' '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'rulagg@excite.com', 'sender_name': ' "Ruka" '}
# {'sender_email': 'idris2003942@aol.com', 'sender_name': ' "IDRIS ADAMU" '}
# {'sender_email': 'davidmensoh@mail.com', 'sender_name': ' "DR.  SANNI  SABO" '}
# {'sender_email': 'davidmensoh@mail.com', 'sender_name': ' "DR.  SANNI  SABO" '}
# {'sender_email': 'ig_esq@rediffmail.com', 'sender_name': ' "Ibrahim Galadima" '}
# {'sender_email': 'ademola1950@hknetmail.com', 'sender_name': None}
# {'sender_email': 'a_mabachas@yahoo.co.uk', 'sender_name': ' "Mohammed Abacha" '}
# {'sender_email': 'princeadisaraki5@usa.com', 'sender_name': ' "PRINCE TUNDE O ADISARAKI" '}
# {'sender_email': 'judeestrada2@dmailman.com', 'sender_name': ' "judeestrada" '}
# {'sender_email': 'davidmensoh@mail.com', 'sender_name': ' "JONATHAN  MOKOENA" '}
# {'sender_email': 'olu@mailservice.ms', 'sender_name': None}
# {'sender_email': 'resbobi2@al-islam.com', 'sender_name': ' "res bob12" '}
# {'sender_email': 'mariam.abacha58@boredmail.com', 'sender_name': ' "LADY MARYAM ABACHA " '}
# {'sender_email': 'tundebalogun@omaninfo.com', 'sender_name': ' "MR.TUNDE  BALOGUN" '}
# {'sender_email': 'mrbenson_attah@omaninfo.com', 'sender_name': ' "MR.BENSON  ATTAH" '}
# {'sender_email': 'mrbenson_attah@omaninfo.com', 'sender_name': ' "MR.BENSON  ATTAH" '}
# {'sender_email': 'tundebalogun@omaninfo.com', 'sender_name': ' "MR.TUNDE  BALOGUN" '}
# {'sender_email': 'mariam.abacha57@boredmail.com', 'sender_name': ' "LADY MARYAM ABACHA " '}
# {'sender_email': 'davidmensoh@mail.com', 'sender_name': ' "DR.  SANNI  SABO" '}
# {'sender_email': 'luisaestrada2002@luisapestrada.zzn.com', 'sender_name': ' "Dr Luisa Pimental Estrada" '}
# {'sender_email': 'douglas.graham@caramail.com', 'sender_name': ' "Graham Douglas" '}
# {'sender_email': 'oluis2@caramail.com', 'sender_name': ' luis oboh '}
# {'sender_email': 'oluis2@caramail.com', 'sender_name': ' luis oboh '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'sekou_family@mailsurf.com', 'sender_name': ' "Nsekou Mobutu Sesekou" '}
# {'sender_email': 'dr_bellomusa01@omaninfo.com', 'sender_name': ' "DR. BELLO MUSA" '}
# {'sender_email': 'frankwilliams2@starmedia.com', 'sender_name': ' Frank Williams '}
# {'sender_email': 'lawrence.smith@voila.fr', 'sender_name': ' "=?iso-8859-1?Q?lawrence.smith?=" '}
# {'sender_email': 'donaldattah@netzero.com', 'sender_name': ' "DONALD  ATTAH" '}
# {'sender_email': 'daninno555@37.com', 'sender_name': ' "daniel innocent" '}
# {'sender_email': 'kabila72i@37.com', 'sender_name': ' "deborah kabila" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'peter_savimbi20@phantomemail.com', 'sender_name': ' "peter" '}
# {'sender_email': 'josephbenson@weedmail.com', 'sender_name': ' "joseph benson" '}
# {'sender_email': 'mr_bb@hknetmail.com', 'sender_name': None}
# {'sender_email': 'pat11@weedmail.com', 'sender_name': ' "pat odogu" '}
# {'sender_email': 'felix.lamine@caramail.com', 'sender_name': ' felix lamine '}
# {'sender_email': 'patrickmohammed@omaninfo.com', 'sender_name': ' "PATRICK  MOHAMMED" '}
# {'sender_email': 'patrickmohammed@omaninfo.com', 'sender_name': ' "PATRICK  MOHAMMED" '}
# {'sender_email': 'lawrenceabba@operamail.com', 'sender_name': ' "Mr. Lawrence Abba" '}
# {'sender_email': 'bill_james4@bluemail.ch', 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'macontu05@yahoo.com', 'sender_name': ' "MALCOM TUTU" '}
# {'sender_email': 'macontu05@yahoo.com', 'sender_name': ' "MALCOM TUTU" '}
# {'sender_email': 'stevens.bangura@caramail.com', 'sender_name': ' stevens bangura '}
# {'sender_email': 'donaldattah@omaninfo.com', 'sender_name': ' "MR. DONALD ATTAH" '}
# {'sender_email': 'marabac011@hotmail.com', 'sender_name': ' "Dr mariam abacha" '}
# {'sender_email': 'frankikpendu3@mail.co.za', 'sender_name': ' Frank Ikpendu '}
# {'sender_email': 'jeffery_hill10007@hotmail.com', 'sender_name': ' "jeffery hill" '}
# {'sender_email': 'macontu028@yahoo.com', 'sender_name': ' "malcom tutu" '}
# {'sender_email': 'macontu028@yahoo.com', 'sender_name': ' "malcom tutu" '}
# {'sender_email': 'samaluko1@37.com', 'sender_name': ' "sam aluko" '}
# {'sender_email': 'ggeorgekabyl@caramail.com', 'sender_name': ' "GEORGE  KABILA" '}
# {'sender_email': 'madu_invest@yahoo.com', 'sender_name': ' "CYRIL AKWARANDU" '}
# {'sender_email': 'madu_invest@yahoo.com', 'sender_name': ' "CYRIL AKWARANDU" '}
# {'sender_email': 'doomer@themail.com', 'sender_name': ' "MR.YARO BAMIYI" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'barr.femi@caramail.com', 'sender_name': ' "barr.femi" '}
# {'sender_email': 'douglankwo@yahoo.com', 'sender_name': ' "DR DOUGLAS NWANKWO" '}
# {'sender_email': 'leathercity1@irangate.net', 'sender_name': ' "Mrs. Safi  Al Mustapha" '}
# {'sender_email': 'leathercity1@irangate.net', 'sender_name': ' "Mrs. Safi  Al Mustapha" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'mariam.aba@caramail.com', 'sender_name': ' "Dr Mariam abacha" '}
# {'sender_email': 'moses1970@englishexpert.com', 'sender_name': ' "Dr.Moses" '}
# {'sender_email': 'moses1970@englishexpert.com', 'sender_name': ' "Dr.Moses" '}
# {'sender_email': 'olu002@phantomemail.com', 'sender_name': ' "DR. OLUSEGUN SMITH" '}
# {'sender_email': 'benkelele@phantomemail.com', 'sender_name': ' "Dr. Bernard Makelele" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'chiedo_jonathan2@netzero.com', 'sender_name': None}
# {'sender_email': 'kasekek@email.com', 'sender_name': ' "kaseke kenneth" '}
# {'sender_email': 'willbanigo003@juntos.com', 'sender_name': None}
# {'sender_email': 'drabdullrasaq@phantomemail.com', 'sender_name': ' "DR ABDULL RASAQ" '}
# {'sender_email': 'drabdullrasaq@phantomemail.com', 'sender_name': ' "DR ABDULL RASAQ" '}
# {'sender_email': 'kkalume@bluemail.ch', 'sender_name': ' "williame ume" '}
# {'sender_email': 'jisrael2@breathe.com', 'sender_name': None}
# {'sender_email': 'umarb@themail.com', 'sender_name': ' "KENNETH ILOKA" '}
# {'sender_email': 'charlesnwodo@excite.com', 'sender_name': None}
# {'sender_email': 'olivsav@netscape.net', 'sender_name': ' "Oliveira Savimbi" '}
# {'sender_email': 'jdsouza1@hotvoice.com', 'sender_name': ' "James DeSouza." '}
# {'sender_email': 'jdsouza1@hotvoice.com', 'sender_name': ' "James DeSouza." '}
# {'sender_email': 'jdsouza1@hotvoice.com', 'sender_name': ' "James DeSouza." '}
# {'sender_email': 'jdsouza1@hotvoice.com', 'sender_name': ' "James DeSouza." '}
# {'sender_email': 'chinaeke7@juno.com', 'sender_name': None}
# {'sender_email': 'papabello@lawyer.com', 'sender_name': ' "PAPA BELLO" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'don_1000@fastermail.com', 'sender_name': ' "Dr. Don Arturo Ramitez." '}
# {'sender_email': 'foryourconsumption_2@hotmail.com', 'sender_name': ' "E E" '}
# {'sender_email': 'greenkab@email.com', 'sender_name': ' "KABILA" '}
# {'sender_email': 'olivsav@netscape.net', 'sender_name': ' "Oliveira Savimbi" '}
# {'sender_email': 'danielkalukalu@netscape.net', 'sender_name': ' "MR DANIEL KALU" '}
# {'sender_email': 'sameezx6@go.com', 'sender_name': ' SOLOMON azeez '}
# {'sender_email': 'sameezx6@go.com', 'sender_name': ' SOLOMON azeez '}
# {'sender_email': 'sameezx6@go.com', 'sender_name': ' SOLOMON azeez '}
# {'sender_email': 'sameezx6@go.com', 'sender_name': ' SOLOMON azeez '}
# {'sender_email': 'sameezx6@go.com', 'sender_name': ' SOLOMON azeez '}
# {'sender_email': 'ni452003@yahoo.com', 'sender_name': ' "NOSA" '}
# {'sender_email': 'tundatx@zapo.net', 'sender_name': ' "MR TUNDA" '}
# {'sender_email': 'u.stephen1@caramail.com', 'sender_name': ' "DR STEPHEN UMAH" '}
# {'sender_email': 'u.stephen@caramail.com', 'sender_name': ' "Dr stephen umah" '}
# {'sender_email': 'jochom12@hotmail.com', 'sender_name': ' "JOHN CHOMA" '}
# {'sender_email': 'tony3@ecplaza.net', 'sender_name': ' "DR TONY COLE" '}
# {'sender_email': 'tony3@ecplaza.net', 'sender_name': ' "DR TONY COLE" '}
# {'sender_email': 'savim_5@email.com', 'sender_name': ' "DR. GOODWILL MPENZA" '}
# {'sender_email': 'wbanigo@anfmail.com', 'sender_name': None}
# {'sender_email': 'wgoye@ecplaza.net', 'sender_name': ' "Engr. William Goye" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'frank_jnr3@myself.com', 'sender_name': ' "FRANK  GUEI JNR." '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'solochuks5000@breathe.com', 'sender_name': None}
# {'sender_email': 'falbashar@olumo.net', 'sender_name': ' Farouk Al-Bashar '}
# {'sender_email': 'fowika@ecplaza.net', 'sender_name': ' "WILLIAM   OKAFOR" '}
# {'sender_email': 'falbashar@olumo.net', 'sender_name': ' Farouk Al-Bashar '}
# {'sender_email': 'ohunola@latinmail.com', 'sender_name': ' "DR STEPHEN AKIGA" '}
# {'sender_email': 'ohunola@latinmail.com', 'sender_name': ' "DR STEPHEN AKIGA" '}
# {'sender_email': 'olakelv3@ecplaza.net', 'sender_name': ' "Ola Kelvin" '}
# {'sender_email': 'mrscecilliaak@ecplaza.net', 'sender_name': ' MRS CECILIA MARK AKU '}
# {'sender_email': 'donubala@ecplaza.net', 'sender_name': ' "MR.DON UBALA," '}
# {'sender_email': 'itwilson33@netscape.net', 'sender_name': ' "Dr. Wilson" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'dayonaps04@aol.com', 'sender_name': None}
# {'sender_email': 'olisav@netscape.net', 'sender_name': ' "Oliveira Savimbi" '}
# {'sender_email': 'pascal_962@myself.com', 'sender_name': ' "Dr Pascal Ugoti" '}
# {'sender_email': 'pascal_962@myself.com', 'sender_name': ' "Dr Pascal Ugoti" '}
# {'sender_email': 'professorfranko@netscape.com', 'sender_name': ' "Professor Frank Obi" '}
# {'sender_email': 'offjo@hotmail.com', 'sender_name': ' "koffi joseph" '}
# {'sender_email': 'kumalodiliza6@ecplaza.net', 'sender_name': ' "ENGR KUMALO DILIZA" '}
# {'sender_email': 'salisu_bola@yahoo.com', 'sender_name': ' "MR GBENRO ADEGBOLA" '}
# {'sender_email': 'okere1972@netscape.net', 'sender_name': ' "MAKO OKERE" '}
# {'sender_email': 'gbealuko@voila.fr', 'sender_name': ' "GBENGA ALUKO" '}
# {'sender_email': 'kecityy@netscape.net', 'sender_name': ' "MR, DOMAS K, YANK" '}
# {'sender_email': 'olisav@netscape.net', 'sender_name': ' "Oliveira Savimbi" '}
# {'sender_email': 'paulbabs@caramail.com', 'sender_name': ' "DR. PAUL BABS." '}
# {'sender_email': 'gabbagana@albawaba.com', 'sender_name': ' "grace abba-gana" '}
# {'sender_email': 'salatu_ibru300@indiatimes.com', 'sender_name': ' "salatu_ibru300" '}
# {'sender_email': 'ademuyiwa1950@rediffmail.com', 'sender_name': ' "ADEROJU MUYIWA" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'olu_martins007@yahoo.com', 'sender_name': ' "Mr Olu Martins" '}
# {'sender_email': 'maryamy2k@indiatimes.com', 'sender_name': ' "maryam  abacha" '}
# {'sender_email': 'rosesavibmi@rediffmail.com', 'sender_name': ' "MRS ROSE SAVIMBI" '}
# {'sender_email': 'luisaastrada@portugalmail.com', 'sender_name': None}
# {'sender_email': 'mariamabacha202@ecplaza.net', 'sender_name': ' MARIAM ABACHA '}
# {'sender_email': 'bolaharryt@tiscali.co.uk', 'sender_name': ' "Bola  Harry" '}
# {'sender_email': 'bolaharryt@tiscali.co.uk', 'sender_name': ' "Bola  Harry" '}
# {'sender_email': 'tunjiowo@regards.net', 'sender_name': ' "DR.TUNJI OWO" '}
# {'sender_email': 'muowen^%&@mmail.com', 'sender_name': ' Owen Mubane '}
# {'sender_email': 'tunjiowo@regards.net', 'sender_name': ' "DR.TUNJI OWO" '}
# {'sender_email': 'orionventures@go.com', 'sender_name': ' Mohammed Abacha '}
# {'sender_email': 'zulumakaleni1@netscape.net', 'sender_name': ' "ENGR ZULUMAKALENI." '}
# {'sender_email': 'koolizzy@hotmail.com', 'sender_name': ' "DR (MRS) MARIAM ABACHA" '}
# {'sender_email': 'engranthony_zuma@lycos.com', 'sender_name': ' "MR. TAMBO" '}
# {'sender_email': 'dukatka_s22@rediffmail.com', 'sender_name': ' Dukat Kabila '}
# {'sender_email': 'samaguiba1@ecplaza.net', 'sender_name': ' "Dr. Bouguiba Samuel" '}
# {'sender_email': 'jamesoni2000@go.com', 'sender_name': ' James Oni '}
# {'sender_email': 'jamesoni2000@go.com', 'sender_name': ' James Oni '}
# {'sender_email': 'jamesoni2000@go.com', 'sender_name': ' James Oni '}
# {'sender_email': 'carlos_sav@go.com', 'sender_name': ' CARLOS SAVIMBI '}
# {'sender_email': 'isa_kaitha2002@yahoo.com', 'sender_name': ' "MRS, AMINA BOLA IGE" '}
# {'sender_email': 'andy_bello2003@rediffmail.com', 'sender_name': ' "Andy Bello" '}
# {'sender_email': 'andy_bello2003@rediffmail.com', 'sender_name': ' "Andy Bello" '}
# {'sender_email': 'martinsdanjuma@mail15.com', 'sender_name': ' "AHMED MARTINS. D" '}
# {'sender_email': 'gadikali@gatechambers.com', 'sender_name': ' Gabriel Kali '}
# {'sender_email': 'kola.awosika@caramail.com', 'sender_name': ' "Mr.Kola Awosika" '}
# {'sender_email': 'husseinalli33@zwallet.com', 'sender_name': ' "SAAD A.ALLI" '}
# {'sender_email': 'johnsonabbas@zwallet.com', 'sender_name': ' "JOHNSON ABBAS" '}
# {'sender_email': 'macusgee@hotmail.com', 'sender_name': ' "Dr.Tito Sithole." '}
# {'sender_email': 'mrkatban@netscape.net', 'sender_name': ' KATURA BANGA '}
# {'sender_email': 'maryamy2k@indiatimes.com', 'sender_name': ' "MADAM MARYAM" '}
# {'sender_email': 'delemartins@indiatimes.com', 'sender_name': ' "DELE MARTINS" '}
# {'sender_email': 'saidifatou@moldova.com', 'sender_name': ' saidi fatou '}
# {'sender_email': 'Liusa11@totalise.co.uk', 'sender_name': ' "Mrs. Mariam M. Sese-seko" '}
# {'sender_email': 'frankemeni@ecplaza.net', 'sender_name': ' "MICHAEL AFOLABI" '}
# {'sender_email': 'Nzangamobutu@phantomemail.com', 'sender_name': ' NZANGA MOBUTU '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'Nzangamobutu@phantomemail.com', 'sender_name': ' NZANGA MOBUTU '}
# {'sender_email': 'chuksanthony05@netscape.net', 'sender_name': ' "CHUKS ANTHONY" '}
# {'sender_email': 'godfreyeche3@albawaba.com', 'sender_name': ' "godfrey eche3" '}
# {'sender_email': 'godfreyeche3@albawaba.com', 'sender_name': ' "godfrey eche3" '}
# {'sender_email': 'khalil_muhammad@myownemail.com', 'sender_name': ' "Muhammad Khalil Hasan" '}
# {'sender_email': 'khalil_muhammad@myownemail.com', 'sender_name': ' "Muhammad Khalil Hasan" '}
# {'sender_email': 'hamzatsulaiman@unionintbanks.com', 'sender_name': ' "Hamzat Sulaiman" '}
# {'sender_email': 'envoltbattery@163.com', 'sender_name': ' "keven wei" '}
# {'sender_email': 'ami44000@netzero.com', 'sender_name': None}
# {'sender_email': 'chuksanthony05@netscape.net', 'sender_name': ' "Mr Chuks Anthony" '}
# {'sender_email': 'jelendu@nzoomail.com', 'sender_name': ' " JOHNSON ELENDU " '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'mijez2001_nnpc@indiatimes.com', 'sender_name': ' "Mike Jide" '}
# {'sender_email': 'mijez2001_nnpc@indiatimes.com', 'sender_name': ' "Mike Jide" '}
# {'sender_email': 'wale_williams@post.cz', 'sender_name': None}
# {'sender_email': 'mfrred@hknetmail.com', 'sender_name': ' "Fred Mbonu" '}
# {'sender_email': 'mfrred@hknetmail.com', 'sender_name': ' "Fred Mbonu" '}
# {'sender_email': 'johncolemen1970@netscape.net', 'sender_name': ' JOHN COLEMEN '}
# {'sender_email': 'j_remitance@hknetmail.com', 'sender_name': None}
# {'sender_email': 'liusaxxxx@totalise.co.uk', 'sender_name': ' "Mrs. Mariam M. Sese-seko" '}
# {'sender_email': 'sa_03@breathe.com', 'sender_name': ' "MakamSomo" '}
# {'sender_email': 'engr_musa@hknetmail.com', 'sender_name': ' "Engr. Musa  Akim." '}
# {'sender_email': 'engr_musa@hknetmail.com', 'sender_name': ' "Engr. Musa  Akim." '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'mattokoye@didamail.com', 'sender_name': ' "DR.MATTHEW OKOYE" '}
# {'sender_email': 'ab_nkomo@hotmail.com', 'sender_name': ' "abram nkomo" '}
# {'sender_email': 'sseko019@go.com', 'sender_name': ' maira ssesko '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'jmobutu189@latinmail.com', 'sender_name': ' Joseph Mobutu Sese-Seko '}
# {'sender_email': 'myriaj03@femail.com.au', 'sender_name': ' "Mariam Abacha" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'jmobutu189@latinmail.com', 'sender_name': ' Joseph Mobutu Sese-Seko '}
# {'sender_email': 'folufadaka@netzero.com', 'sender_name': ' "PRINCE FOLU FADAKA" '}
# {'sender_email': 'e.sussy@caramail.com', 'sender_name': ' sussy emma '}
# {'sender_email': 'harry1@hknet.com', 'sender_name': ' "Harry O Harry" '}
# {'sender_email': 'jdrmoore@personal.ro', 'sender_name': ' Drmoore James '}
# {'sender_email': 'princewilliamson99@portugalmail.pt', 'sender_name': ' "PRINCE WILLIAMS" '}
# {'sender_email': 'princewilliamson99@portugalmail.pt', 'sender_name': ' "PRINCE M  WILLIAMS" '}
# {'sender_email': 'aku_cmrs2002@surfy.net', 'sender_name': ' "MRS CECILIA  AKU" '}
# {'sender_email': 'mahabile10@netscape.net', 'sender_name': ' MECK MAHABILE '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'fbellojr39@hotmail.com', 'sender_name': ' "FRANK BELLO" '}
# {'sender_email': 'fbellojr39@hotmail.com', 'sender_name': ' "FRANK BELLO" '}
# {'sender_email': 'mike.obodoh@caramail.com', 'sender_name': ' "Mr. Mike Obodoh" '}
# {'sender_email': 'basseyowo300@hknetmail.com', 'sender_name': ' "Barrister. Bassey  Owo" '}
# {'sender_email': 'bechmank@yahoo.com', 'sender_name': ' "MUYIWA IGE" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'tundecole@uboot.com', 'sender_name': ' "Dr.Tunde Cole" '}
# {'sender_email': 'tundecole@uboot.com', 'sender_name': ' "Dr Tunde Cole" '}
# {'sender_email': 'willyume@zapo.net', 'sender_name': ' "williamume" '}
# {'sender_email': 'philjones1@uboot.com', 'sender_name': ' "Mr.Philip Jones" '}
# {'sender_email': 'solosavimbi@netscape.com', 'sender_name': None}
# {'sender_email': 'leowilliams3@ipost.cz', 'sender_name': ' "LEO  WILLIAMS" '}
# {'sender_email': 'makathy@libero.it', 'sender_name': ' =?iso-8859-1?Q?makathy?= '}
# {'sender_email': 'sank_mary6@popmail.com', 'sender_name': ' "MRS MARY SANKOH" '}
# {'sender_email': 'mrbom@fastermail.com', 'sender_name': ' "Mr.Bom Uche" '}
# {'sender_email': 'mrbom@fastermail.com', 'sender_name': ' "Mr.Bom Uche" '}
# {'sender_email': 'ikhayere6000@addlebrain.com', 'sender_name': ' ikhayere obinyan '}
# {'sender_email': 'danielabass@afmail.com', 'sender_name': ' "Mr. Daniel Abass." '}
# {'sender_email': 'basher39@lycos.com', 'sender_name': ' BASHER MOBUTU '}
# {'sender_email': 'evanspeter@hkonline.com', 'sender_name': ' evans peter '}
# {'sender_email': 'bode_george@xuppa.com', 'sender_name': ' "CHIEF(DR.)BODE GEORGE" '}
# {'sender_email': 'bode_george@xuppa.com', 'sender_name': ' "CHIEF(DR.)BODE GEORGE" '}
# {'sender_email': 'gregoryprem@incamail.com', 'sender_name': ' "GREGORY PREMIER" '}
# {'sender_email': 'xxxxnnnnaaaa@netscape.net', 'sender_name': ' "....." '}
# {'sender_email': 'fredobi02@zwallet.com', 'sender_name': ' "Mr.Fred Obi" '}
# {'sender_email': 'idrisumar94@go.com', 'sender_name': ' idris umar '}
# {'sender_email': 'idrisumar94@go.com', 'sender_name': ' idris umar '}
# {'sender_email': 'idrisumar94@go.com', 'sender_name': ' idris umar '}
# {'sender_email': 'danbello07@hotmail.com', 'sender_name': ' "daniel bello" '}
# {'sender_email': 'dansekou@voila.fr', 'sender_name': ' "Mohammed Abacha" '}
# {'sender_email': 'dansekou@voila.fr', 'sender_name': ' "Mohammed Abacha" '}
# {'sender_email': 'mrsmbeki@juno.com', 'sender_name': ' "mrs m mbeki" '}
# {'sender_email': 'kolad05@indiatimes.com', 'sender_name': ' "Kola Daniel" '}
# {'sender_email': 'consumer.support@e-loan.com', 'sender_name': ' E-Loan Consumer Department '}
# {'sender_email': 'consumer.support@e-loan.com', 'sender_name': ' E-Loan Consumer Department '}
# {'sender_email': 'consumer.support@e-loan.com', 'sender_name': ' E-Loan Consumer Department '}
# {'sender_email': 'princeige@mail3000.com', 'sender_name': None}
# {'sender_email': 'dr_francis_mboma0@lycos.com', 'sender_name': ' "Francis Sonto Mbomam" '}
# {'sender_email': 'wfba.accounting@wellsfargo.com', 'sender_name': ' Wells Fargo Accounting '}
# {'sender_email': 'wfba.accounting@wellsfargo.com', 'sender_name': ' Wells Fargo Accounting '}
# {'sender_email': 'wfba.accounting@wellsfargo.com', 'sender_name': ' Wells Fargo Accounting '}
# {'sender_email': 'frankzambani42@netscape.net', 'sender_name': ' frank '}
# {'sender_email': None, 'sender_name': ' "Pandindra" '}
# {'sender_email': 'dr_aminuusman@anytimenow.com', 'sender_name': ' usman aminu '}
# {'sender_email': 'titi_okonkwo@yahoo.com', 'sender_name': ' "Dr .Titi okonkwo" '}
# {'sender_email': 'titiokonkwo234@yahoo.com', 'sender_name': ' "Dr .Titiokonkwo" '}
# {'sender_email': 'ejieego@netscape.net', 'sender_name': ' "Godwin Ekpontu Sangana, Esq" '}
# {'sender_email': 'ejieego@netscape.net', 'sender_name': ' "Godwin Ekpontu Sangana, Esq" '}
# {'sender_email': 'ejieego@netscape.net', 'sender_name': ' "Godwin Ekpontu Sangana, Esq" '}
# {'sender_email': 'ejieego@netscape.net', 'sender_name': ' "Godwin Ekpontu Sangana, Esq" '}
# {'sender_email': 'igho200@netscape.net', 'sender_name': ' ENGR MARK DAVID '}
# {'sender_email': 'randebe@kalpoint.com', 'sender_name': ' "Fadaka Randebe" '}
# {'sender_email': 'randebe@kalpoint.com', 'sender_name': ' "Fadaka Randebe" '}
# {'sender_email': 'ali_mohammed@123.com', 'sender_name': ' Ali Mohammed '}
# {'sender_email': 'fbplcnig@nzoomail.com', 'sender_name': ' "First Bank Nig. Plc.( Dr. Femi Johnson.)" '}
# {'sender_email': 'savimbicar1@dogmail.co.uk', 'sender_name': ' "carlos savimbi" '}
# {'sender_email': 'vumeh704@hknetmail.com', 'sender_name': None}
# {'sender_email': 'bodegeorge@pisem.net', 'sender_name': ' "CHIEF(DR.)BODE GEORGE" '}
# {'sender_email': 'mariamabachs@go.com', 'sender_name': ' mariam abachas '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'aliahmed@ecplaza.net', 'sender_name': ' "ALI AHMED" '}
# {'sender_email': 'akyari1@sudanmail.net.sd', 'sender_name': ' "Abu Kyari." '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'alimabu@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'joseph_1ang@zwallet.com', 'sender_name': ' "Joseph Savimbi" '}
# {'sender_email': 'joseph_1ang@zwallet.com', 'sender_name': ' "Joseph Savimbi" '}
# {'sender_email': 'naa8m@mail.com', 'sender_name': ' "prince george duke" '}
# {'sender_email': 'okijames@latinmail.com', 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'jeffreydaniels2@excite.com', 'sender_name': ' "Mr. Jeffrey Daniels" '}
# {'sender_email': 'jeffreydaniels4@excite.com', 'sender_name': ' "Mr. Jeffrey Daniels" '}
# {'sender_email': 'adausman@popmail.com', 'sender_name': ' "ADA USMAN!" '}
# {'sender_email': 'dankar3@zwallet.com', 'sender_name': ' "Daniel  Kargbu" '}
# {'sender_email': 'johnnlobo@yahoo.com', 'sender_name': ' "Mr. John Nlobo" '}
# {'sender_email': 'ajala8000@rediffmail.com', 'sender_name': ' '}
# {'sender_email': 'kunowolo3@tiscali.co.uk', 'sender_name': ' "Dr.Kunle Owolo" '}
# {'sender_email': 'kunowolo3@tiscali.co.uk', 'sender_name': ' "Dr.Kunle Owolo" '}
# {'sender_email': 'mrsjennikobe@hknetmail.com', 'sender_name': ' "MRSJENNIFER KOBE" '}
# {'sender_email': 'jackamala@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'thomasaudu@mail.com', 'sender_name': ' "DR THOMAS AUDU" '}
# {'sender_email': 'kaluidikak@go.com', 'sender_name': ' kalu idika '}
# {'sender_email': 'makalele01@xzapmail.com', 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'g_ineh@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'marksteven301@netscape.net', 'sender_name': ' "Michael Stevens Junior." '}
# {'sender_email': 'maraba234@anfmail.com', 'sender_name': ' "Hajia Maryam Abacha" '}
# {'sender_email': 'maraba234@latinmail.com', 'sender_name': ' "Hajia Maryam Abacha" '}
# {'sender_email': 'mathewike212@juno.com', 'sender_name': ' "BARRISTER MATHEW IKE" '}
# {'sender_email': 'engedetamanah@post.cz', 'sender_name': None}
# {'sender_email': 'sunnyokogwo@post.cz', 'sender_name': ' "MR.ODIASE GEORGE" '}
# {'sender_email': 'deacon_zik@yaoo.com', 'sender_name': ' "DEACON ZIK R. DON" '}
# {'sender_email': 'mobkuz3@kukamail.com', 'sender_name': ' "Nzanga Mobutu" '}
# {'sender_email': 'adew1@mail3000.com', 'sender_name': None}
# {'sender_email': 'adew1@mail3000.com', 'sender_name': None}
# {'sender_email': 'muhammed303@arabtop.net', 'sender_name': ' "DR.MUHAMMED MUSTAFA" '}
# {'sender_email': 'hopkinsmbeki@hknetmail.com', 'sender_name': ' "BARRISTER, HOPKINS MBEKI" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'ndandla@latinmail.com', 'sender_name': None}
# {'sender_email': 'mcabacha@freesurf.fr', 'sender_name': ' '}
# {'sender_email': 'ugoch_8@z6.com', 'sender_name': ' "Mr Ugochukwu .W" '}
# {'sender_email': 'shaabanbait@primposta.com', 'sender_name': None}
# {'sender_email': 'shaabanbait@primposta.com', 'sender_name': None}
# {'sender_email': 'consultant_ng3@send-mail.co.uk', 'sender_name': None}
# {'sender_email': 'modey06@go.com', 'sender_name': ' mike odey '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'akindada@indiatimes.com', 'sender_name': ' "DR. AKIN DADA." '}
# {'sender_email': '2003vincent@freesurf.fr', 'sender_name': ' "barrister vincent usman" '}
# {'sender_email': 'jamie777@mail.biz.ly', 'sender_name': ' "JAMIE  OPUKU." '}
# {'sender_email': 'jerrypeter2@freesurf.fr', 'sender_name': ' '}
# {'sender_email': 'mnoah3@hotmail.com', 'sender_name': ' "mona noah" '}
# {'sender_email': 'JUDE@YAHOO.COM', 'sender_name': ' "MICHEAL  OSSAI" '}
# {'sender_email': 'test@yahoo.com', 'sender_name': None}
# {'sender_email': 'test@yahoo.com', 'sender_name': None}
# {'sender_email': 'mrbongo@themail.com', 'sender_name': ' "Peter Bongo" '}
# {'sender_email': 'akumembeki@netscape.net', 'sender_name': ' MASTER HAROLD MBEKI '}
# {'sender_email': 'mmaryaabacha8@caramail.com', 'sender_name': ' "maryaabacha8 maryam " '}
# {'sender_email': 'mmaryaabacha8@caramail.com', 'sender_name': ' "maryaabacha8 maryam " '}
# {'sender_email': 'hansob@123.com', 'sender_name': ' "H B" '}
# {'sender_email': 'dtshombe2@123.com', 'sender_name': ' diaka tshombe '}
# {'sender_email': 'ekong.bassey2@caramail.com', 'sender_name': ' EKONG BASSEY '}
# {'sender_email': 'vas_imoti@abv.bg', 'sender_name': ' Vasil Nanchev '}
# {'sender_email': 'frankokonjo5@123.com', 'sender_name': ' frank okonjo '}
# {'sender_email': 'gokalala1@tiscali.co.uk', 'sender_name': ' "DR. GODWIN KALALA" '}
# {'sender_email': 'ekong.bassey2@caramail.com', 'sender_name': ' EKONG BASSEY '}
# {'sender_email': 'hellenshaka@netscape.net', 'sender_name': ' HELLEN SHAKA ZUMA '}
# {'sender_email': 'fredsam@123.com', 'sender_name': ' Akande fredrick '}
# {'sender_email': 'esamakingdom@fsmail.net', 'sender_name': ' esama kingdom '}
# {'sender_email': 'mary_abass2@123.com', 'sender_name': ' MARY ABASS '}
# {'sender_email': 'frankokonjo6@123.com', 'sender_name': ' frank okonjo '}
# {'sender_email': 'vinokoni5@hotmail.com', 'sender_name': ' "vino koni" '}
# {'sender_email': 'sarah.mutete@caramail.com', 'sender_name': None}
# {'sender_email': 'anders01_lb@post.cz', 'sender_name': ' "DAVIDS ANDERSON." '}
# {'sender_email': 'dtshombe3@123.com', 'sender_name': ' diaka tshombe '}
# {'sender_email': 'markedeozo@freesurf.fr', 'sender_name': None}
# {'sender_email': 'abu_saeed4@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'elosub@freesurf.fr', 'sender_name': None}
# {'sender_email': 'yetunde@mail2world.com', 'sender_name': ' "Yetunde Bassey" '}
# {'sender_email': 'yetunde@mail2world.com', 'sender_name': ' "Yetunde Bassey" '}
# {'sender_email': 'lary_kamokai1@hotmail.com', 'sender_name': ' "lary kamokai" '}
# {'sender_email': 'micheal_ado@hotmail.com', 'sender_name': ' "micheal ado santigo" '}
# {'sender_email': 'fredkuma@freesurf.fr', 'sender_name': ' '}
# {'sender_email': 'wolny_olkusz@latinmail.com', 'sender_name': None}
# {'sender_email': 'dr_georgequattara@indiatimes.com', 'sender_name': ' "DR. George Ibrahim Quattara" '}
# {'sender_email': 'johnchukwu1@caramail.com', 'sender_name': ' "Mr..John Chukwu" '}
# {'sender_email': 'dr.bell_bat@portugalmail.com', 'sender_name': ' "DR BELLO BATURE" '}
# {'sender_email': 'mmaryaabacha8@caramail.com', 'sender_name': ' "maryaabacha8 maryam " '}
# {'sender_email': 'ladyj4u@mail2cherry.com', 'sender_name': ' "Mrs. Juliet Bello." '}
# {'sender_email': 'serenajones$$7@netscape.net', 'sender_name': ' "Mrs. Serena  Jones" '}
# {'sender_email': 'chuksanthony05@netscape.net', 'sender_name': ' "chuks Anthony" '}
# {'sender_email': 'jide.williams@seznam.cz', 'sender_name': ' =?us-ascii?Q?jide=20williams?= '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'yinkadavi@mailbox.hu', 'sender_name': None}
# {'sender_email': 'william_d@zwallet.com', 'sender_name': ' "MR.WILLIAM" '}
# {'sender_email': 'william_d@zwalley.com', 'sender_name': ' "MR.WILLIAM" '}
# {'sender_email': 'karimusesay@whipmail.com', 'sender_name': None}
# {'sender_email': 'chesson_joseph@mail2world.com', 'sender_name': None}
# {'sender_email': 'nelson_abia203@hotmail.com', 'sender_name': ' "Nelson Abia" '}
# {'sender_email': 'prince_amed011@hotmail.com', 'sender_name': ' "MR ALI AMED" '}
# {'sender_email': 'abamohammed@ananzi.co.za', 'sender_name': ' "muhammed abacha" '}
# {'sender_email': 'hassandiko@fsmail.net', 'sender_name': ' "HASSAN DIKO" '}
# {'sender_email': 'oluwatobiboye@dcemail.com', 'sender_name': ' "OLUWATOBI E.BOYE" '}
# {'sender_email': 'oluwatobiboye@dcemail.com', 'sender_name': ' "OLUWATOBI E.BOYE" '}
# {'sender_email': 'nelson_abia203@hotmail.com', 'sender_name': ' "Mr Nelson Abia" '}
# {'sender_email': 'redokoli42@yahoo.com', 'sender_name': ' "Fred Okoli" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'musa_diya@fastermail.com', 'sender_name': ' "haji musa diya" '}
# {'sender_email': 'musa_diya@fastermail.com', 'sender_name': ' "haji musa diya" '}
# {'sender_email': 'victoriabucknor23@mail15.com', 'sender_name': ' "From Mrs. Victoria Bucknor" '}
# {'sender_email': 'victoriabucknor23@mail15.com', 'sender_name': ' "From Mrs. Victoria Bucknor" '}
# {'sender_email': 'victoriabucknor23@mail15.com', 'sender_name': ' "From Mrs. Victoria Bucknor" '}
# {'sender_email': 'victoriabucknor23@mail15.com', 'sender_name': ' "From Mrs. Victoria Bucknor" '}
# {'sender_email': 'ssarejo355@netscape.net', 'sender_name': ' Mrs Serena Jones '}
# {'sender_email': 'aa44@rt.nl', 'sender_name': ' "prince duke" '}
# {'sender_email': 'nanaseko3@web-mail.com.ar', 'sender_name': ' "MRS M. SESE SEKO" '}
# {'sender_email': 'jonsonbonida_mac$77@latinmail.com', 'sender_name': ' Mac Jonson Bonida '}
# {'sender_email': 'floxypage44@hknetmail.com', 'sender_name': ' "Mrs.Floxy Page" '}
# {'sender_email': 'opeter6@caramail.com', 'sender_name': ' "PETER OKOYE" '}
# {'sender_email': 'opeter6@caramail.com', 'sender_name': ' "PETER OKOYE" '}
# {'sender_email': 'firstlady234@post.cz', 'sender_name': ' "MRS.MARYAM ABACHA" '}
# {'sender_email': 'nanaseko4@web-mail.com.ar', 'sender_name': ' "MRS M. SESE SEKO" '}
# {'sender_email': 'port1.net@email.it', 'sender_name': ' "MOHAMMED" '}
# {'sender_email': 'port1.net@email.it', 'sender_name': ' "MOHAMMED" '}
# {'sender_email': 'port1.net@email.it', 'sender_name': ' "MOHAMMED" '}
# {'sender_email': 'hajia2000@i2828.com', 'sender_name': ' "HAJIA MARYAM ABACHA" '}
# {'sender_email': 'moguam@seznam.cz', 'sender_name': ' =?us-ascii?Q?mogua=20mogogo?= '}
# {'sender_email': 'selina_gabrielmarinze@voila.fr', 'sender_name': ' selina_gabrielmarinze '}
# {'sender_email': 'project101@123.com', 'sender_name': ' y a '}
# {'sender_email': 'aminamohammed311@netscape.net', 'sender_name': ' "MRS AMINA MOHAMMED" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'mrs_susan2@123.com', 'sender_name': ' MRS SUSAN '}
# {'sender_email': 'faroqz10@hotmail.com', 'sender_name': ' "Dr.Faroq Uztaz[Regional Director]" '}
# {'sender_email': 'jangdo1@hknetmail.com', 'sender_name': ' MR JANG DOO-HWAN '}
# {'sender_email': 'kendikko01@123.com', 'sender_name': ' ken dikko '}
# {'sender_email': 'ugochukwu_8@z6.com', 'sender_name': ' "Mr Ugochukwu" '}
# {'sender_email': 'd11@rt.nl', 'sender_name': ' "from prince duke" '}
# {'sender_email': 'van77@rt.nl', 'sender_name': ' "from prince duke" '}
# {'sender_email': 'thomutete@netscape.net', 'sender_name': ' Thomas Taylor '}
# {'sender_email': 'm_doh4@zwallet.com', 'sender_name': ' "Mr.Michael Dohn" '}
# {'sender_email': 'm_doh4@zwallet.com', 'sender_name': ' "Mr.Michael Dohn" '}
# {'sender_email': 'jonbwaya@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'jonbwaya@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'williamisiaka55@123.com', 'sender_name': ' william Isiaka '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'hmariam234@rediffmail.com', 'sender_name': ' "DR. MRS. MARIAM ABACHA" '}
# {'sender_email': 'mikeewald@eudoramail.com', 'sender_name': ' "MR MICHAEL EWALD" '}
# {'sender_email': 'abayomidavies@yahoo.com', 'sender_name': None}
# {'sender_email': 'errol_marshall2@albawaba.com', 'sender_name': None}
# {'sender_email': 'mrsjaneabdullah@123.com', 'sender_name': ' mrsjane abdullah '}
# {'sender_email': 'yet_bassey@123.com', 'sender_name': ' Yetunde Bassey '}
# {'sender_email': 'mohammedabacha000@tiscali.co.uk', 'sender_name': ' "MOHAMMED ABACHA" '}
# {'sender_email': 'mohammedabacha000@tiscali.co.uk', 'sender_name': ' "MOHAMMED ABACHA" '}
# {'sender_email': 'mohammed_ab000@go.com', 'sender_name': ' "MOHAMMED ABACHA" '}
# {'sender_email': 'mohammedabacha000@tiscali.co.uk', 'sender_name': ' "MOHAMMED ABACHA" '}
# {'sender_email': 'mohammedabacha000@tiscali.co.uk', 'sender_name': ' "MOHAMMED ABACHA" '}
# {'sender_email': 'markakpu@tiscali.co.uk', 'sender_name': ' "MARK AKPU" '}
# {'sender_email': 'sussy_shab@123.com', 'sender_name': ' susan shabangu '}
# {'sender_email': 'nassernasiri2003@uaemail.com', 'sender_name': ' "Mr. Nasser Nasiri." '}
# {'sender_email': 'nassernasiri2003@uaemail.com', 'sender_name': ' "Mr. Nasser Nasiri." '}
# {'sender_email': 'nassernasiri2003@uaemail.com', 'sender_name': ' "Mr. Nasser Nasiri." '}
# {'sender_email': 'sogolo_hmd@juno.com" <sogolo_hmd@juno.com', 'sender_name': ' "sogolo_hmd@juno.com" '}
# {'sender_email': 'laa@rt.nl', 'sender_name': ' "prince duke" '}
# {'sender_email': 'jrchesson@rediffmail.com', 'sender_name': None}
# {'sender_email': 'serenajones1@rediffmail.com', 'sender_name': ' Mrs Serena Jones '}
# {'sender_email': 'mobutbashe3@rediffmail.com', 'sender_name': ' MR BASHE MOBUTU SESE SEKO '}
# {'sender_email': 'peterbuno@rediffmail.com', 'sender_name': ' "PETER BUNO" '}
# {'sender_email': 'peterbuno@rediffmail.com', 'sender_name': ' "PETER BUNO" '}
# {'sender_email': 'jeffmboma@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'abdulkareem_39@findology.com', 'sender_name': ' "ABDULKAREEM USMAN" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'dukenze@123.com', 'sender_name': ' "Mr. Duke Nze" '}
# {'sender_email': 'dukenze@123.com', 'sender_name': ' "Mr. Duke Nze" '}
# {'sender_email': 'philpenza@ecplaza.com', 'sender_name': ' "Phill Ipenza" '}
# {'sender_email': 'jameskyari22@netscape.net', 'sender_name': ' james kyari '}
# {'sender_email': 'dr_don_ike@hknetmail.com', 'sender_name': ' "DR DONALD" '}
# {'sender_email': 'mmssko2@123.com', 'sender_name': ' mariama seseko '}
# {'sender_email': 'netherlotto@corporation.com', 'sender_name': ' "NETHERLOTTO CORPORATION." '}
# {'sender_email': 'dandy_nnaji@yahoo.com', 'sender_name': ' "MR.DANDY NNAJI" '}
# {'sender_email': 'dandy_nnaji@yahoo.com', 'sender_name': ' "MR.DANDY NNAJI" '}
# {'sender_email': 'peson@zwallet.com', 'sender_name': ' "PETERSON BULINGA" '}
# {'sender_email': 'josephmobutu200$@latinmail.com', 'sender_name': ' MR JOSEPH MOBUTU SESE SEKO '}
# {'sender_email': 'dada@fsmail.net', 'sender_name': ' dada abu '}
# {'sender_email': 'yet_bassey@123.com', 'sender_name': ' Yetunde Bassey '}
# {'sender_email': 'susanshubangu@123.com', 'sender_name': ' susan shubangu '}
# {'sender_email': 'kayodephillip@fsmail.net', 'sender_name': ' kayode phillip '}
# {'sender_email': 'juma2003@thepostbox.co.uk', 'sender_name': ' Mrs Jumai YOUSSEF '}
# {'sender_email': 'wasa@was.com', 'sender_name': ' "DR Peter Clapton" '}
# {'sender_email': 'wasa@was.com', 'sender_name': ' "DR Peter Clapton" '}
# {'sender_email': 'wasa@was.com', 'sender_name': ' "DR Peter Clapton" '}
# {'sender_email': 'wasa@was.com', 'sender_name': ' "DR Peter Clapton" '}
# {'sender_email': 'eeaesq@123.com', 'sender_name': ' Alexander Afadia '}
# {'sender_email': 'musma_adb@ny.com', 'sender_name': ' "MUSA AHMED ZULU" '}
# {'sender_email': 'issacwimpoehato@yahoo.com', 'sender_name': None}
# {'sender_email': 'mallam_bello@123.com', 'sender_name': ' Mallam Bello Ali '}
# {'sender_email': 'jamesmorgan@fsmail.net', 'sender_name': ' james morgan '}
# {'sender_email': 'fredokoli300@yahoo.com', 'sender_name': ' "Fred Okoli" '}
# {'sender_email': 'fredokoli300@yahoo.com', 'sender_name': ' "Fred Okoli" '}
# {'sender_email': 'lucman_watson@macmail.com', 'sender_name': ' "MR.lucman Watson" '}
# {'sender_email': 'kazeemahmed@gawab.com', 'sender_name': ' "KAZEEM AHMED" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'julietugaga22@netscape.net', 'sender_name': ' JULIET UGAGA '}
# {'sender_email': 'fbello1@megamail.pt', 'sender_name': ' Frank Bello '}
# {'sender_email': 'fbello1@megamail.pt', 'sender_name': ' Frank Bello '}
# {'sender_email': 'femi-martins876@fsmail.net', 'sender_name': ' "MR FEMI MARTINS" '}
# {'sender_email': 'laurent_nkono@zwallet.com" <laurent_nkono@zwallet.com', 'sender_name': ' "laurent_nkono@zwallet.com" '}
# {'sender_email': 'bonakama232322de45@eudoramail.com', 'sender_name': ' "MRS. MARIAM ABACHA (WIDOW)." '}
# {'sender_email': 'manuelsisilu@latinmail.com', 'sender_name': None}
# {'sender_email': 'mohammedmustafa@arabtop.net', 'sender_name': ' "Mohammed Mustafa" '}
# {'sender_email': 'abachafamily4@tiscali.co.uk', 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'thembi79@zwallet.com', 'sender_name': ' "THEMBI" '}
# {'sender_email': 'kojadams@voila.fr', 'sender_name': ' kojadams '}
# {'sender_email': 'carleblon@zwallet.com', 'sender_name': ' "Carl Eblon" '}
# {'sender_email': 'davistutu@yahoo.co.uk', 'sender_name': ' "DAVIS TUTU" '}
# {'sender_email': 'sarakoroma@hotmail.com', 'sender_name': ' "SAM KOROMA" '}
# {'sender_email': 'mjaja02@libero.it', 'sender_name': ' "" '}
# {'sender_email': 'hildatoms@Eudoramail.com', 'sender_name': None}
# {'sender_email': 'rosesav1@webave.com', 'sender_name': ' "Rose Savimbi" '}
# {'sender_email': 'mrnelsonbidi_3@123.com', 'sender_name': ' "From Mr Nelson Bidi ." '}
# {'sender_email': 'mrnelsonbidi_3@123.com', 'sender_name': ' "From Mr Nelson Bidi ." '}
# {'sender_email': 'mrnelsonbidi_3@123.com', 'sender_name': ' "From Mr Nelson Bidi ." '}
# {'sender_email': 'usman_ali@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'hc_agah555@fsmail.net', 'sender_name': ' henrich agah '}
# {'sender_email': 'rama1@whipmail.com', 'sender_name': ' "FROM MRS RAMA IDRIS" '}
# {'sender_email': 'princewillams773@z6.com', 'sender_name': ' "FROM  PRINCE WILLIAMS  TAYOLR." '}
# {'sender_email': 'princewillams773@z6.com', 'sender_name': ' "FROM  PRINCE WILLIAMS  TAYOLR." '}
# {'sender_email': 'joseph.williamvaye@caramail.com', 'sender_name': None}
# {'sender_email': 'collinsngobe@fsmail.net', 'sender_name': ' "collins" '}
# {'sender_email': 'collinsngobe@fsmail.net', 'sender_name': ' "collins" '}
# {'sender_email': 'kaladah@epatra.com', 'sender_name': None}
# {'sender_email': 'okphilip1@tiscali.co.uk', 'sender_name': ' "DR OKON PHILIP" '}
# {'sender_email': 'dongakabaka@tiscali.co.uk', 'sender_name': ' "Donga Kabaka" '}
# {'sender_email': 'Bruno.Daems@pandora.be', 'sender_name': ' james momodu '}
# {'sender_email': 'ibrahimyadudu@tiscali.co.uk', 'sender_name': ' "MR IBRAHIM YADUDU." '}
# {'sender_email': 'jjoh3000@yahoo.co.uk', 'sender_name': ' "DR. JOHNSON KENNETH" '}
# {'sender_email': 'jjoh3000@yahoo.co.uk', 'sender_name': ' "DR. JOHNSON KENNETH" '}
# {'sender_email': 'gregorykabila333@mail.bg', 'sender_name': None}
# {'sender_email': 'maryalade66@fsmail.net', 'sender_name': ' mary alade '}
# {'sender_email': 'K.M.ZONDI@foxfire.mr.itd.UM (REV', 'sender_name': None}
# {'sender_email': 'danjumawilliams@fsmail.net', 'sender_name': ' "DANJUMA WILLIAMS M" '}
# {'sender_email': 'ka_hammed@fsmail.net', 'sender_name': ' dr kabo hammed '}
# {'sender_email': 'mar_maryam@fsmail.net', 'sender_name': ' maryam abacha '}
# {'sender_email': 'ukpd@web-mail.com.ar', 'sender_name': ' "KEN GOMAN" '}
# {'sender_email': 'mohameed_aba1@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'mohameed_aba@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'george2000@wp.pl', 'sender_name': ' "george akin" '}
# {'sender_email': 'rharare1@spinfinder.com', 'sender_name': ' robert harare '}
# {'sender_email': 'mohameed_aba@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'jocg102@netscape.net', 'sender_name': ' "J.C.G" '}
# {'sender_email': 'oliveryengeni@tiscali.co.uk', 'sender_name': ' "oliver  yengeni" '}
# {'sender_email': 'kufor2000@tatanova.com', 'sender_name': ' kufor2000 '}
# {'sender_email': 'matthewmolefe3@webmail.co.za', 'sender_name': ' "matthew molefe" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'tblmichl@voila.fr', 'sender_name': ' tblmichl '}
# {'sender_email': 'dr_usmanbello@fsmail.net', 'sender_name': ' DR USMAN BELLO '}
# {'sender_email': 'her29@rediffmail.com', 'sender_name': None}
# {'sender_email': '03mariam@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'jeweltaylor_274@fsmail.net', 'sender_name': ' jewel taylor '}
# {'sender_email': 'sankoh.james@caramail.com', 'sender_name': ' "James Mercy Sankoh" '}
# {'sender_email': 'sankoh.james@caramail.com', 'sender_name': ' "James Mercy Sankoh" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'zakirmahmood@primposta.com', 'sender_name': ' "Mr Zakir Mahmood" '}
# {'sender_email': 'zakirmahmood@primposta.com', 'sender_name': ' "Mr Zakir Mahmood" '}
# {'sender_email': 'jamesnicholas@zwallet.com', 'sender_name': ' "MR. JAMES NICHOLAS" '}
# {'sender_email': 'wahidmallam@fsmail.net', 'sender_name': ' "Dr.Wahid Mallam" '}
# {'sender_email': 'bmusa11@fsmail.net', 'sender_name': ' Bello Musa '}
# {'sender_email': 'bakko_bakko@yahoo.com', 'sender_name': ' "MR. BASIL EZE" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'felix_william123@hotmail.com', 'sender_name': ' "Dr. Felix William" '}
# {'sender_email': 'steveuwa@telstra.com', 'sender_name': ' steveuwa '}
# {'sender_email': 'steveuwa2@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'steveuwa2@tiscali.co.uk', 'sender_name': None}
# {'sender_email': 'kamara1000w@hotmail.com', 'sender_name': ' "KAMARA WILLIAM" '}
# {'sender_email': 'roseoba1@webmail.co.za', 'sender_name': ' "MRS.ROSE OBASEKI" '}
# {'sender_email': 'jj_walter9@netzero.com" <jj_walter9@netzero.com', 'sender_name': ' "jj_walter9@netzero.com" '}
# {'sender_email': 'b.goronyo1@caramail.com', 'sender_name': ' "Dardossi" '}
# {'sender_email': 'zuka2004@netscape.net', 'sender_name': ' MRS MUDIWA ZUKA '}
# {'sender_email': 'fatima_abdul@sify.com', 'sender_name': ' "Mrs. Jumai Abdul Azad." '}
# {'sender_email': 'zuka2005@netscape.net', 'sender_name': ' Zuka '}
# {'sender_email': 'marab_ha@weedmail.com', 'sender_name': ' "Mariam Mustapha" '}
# {'sender_email': 'jubeegv@fsmail.net', 'sender_name': ' jubeeg venture '}
# {'sender_email': 'dr_kanuchijuka@fsmail.net', 'sender_name': ' Kanu Chijuka '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'dr.robinson.dike@webmail.co.za', 'sender_name': ' "Robinson Dike" '}
# {'sender_email': 'dr.robinson.dike@webmail.co.za', 'sender_name': ' "Robinson Dike" '}
# {'sender_email': 'dr.robinson.dike@webmail.co.za', 'sender_name': ' "Robinson Dike" '}
# {'sender_email': 'nkomo2004_026@fsmail.net', 'sender_name': ' =?iso-8859-1?Q?michael_=A0nkomo?= '}
# {'sender_email': 'nkomo2004_026@fsmail.net', 'sender_name': ' =?iso-8859-1?Q?michael_=A0nkomo?= '}
# {'sender_email': 'kolapoomidire2@webmail.co.za', 'sender_name': ' "kolapo omidire" '}
# {'sender_email': 'abdullah_andani@z6.com', 'sender_name': None}
# {'sender_email': 'abdullah_andani@z6.com', 'sender_name': None}
# {'sender_email': 'patrickatike2@fsmail.net', 'sender_name': ' patrick atike '}
# {'sender_email': 'nze_moore@voila.fr', 'sender_name': ' nze_moore '}
# {'sender_email': 'mngomeni4@fsmail.net', 'sender_name': ' mngomeni james '}
# ...
# {'sender_email': 'frankkone0011@hotmail.com', 'sender_name': ' frank kone '}
# {'sender_email': 'darekking2007@yahoo.co.uk', 'sender_name': ' "MR.  JOHN  FISHER" '}
# {'sender_email': 'pae.za@terra.es" <pae.za@terra.es', 'sender_name': ' "pae.za@terra.es" '}
# {'sender_email': 'larisasosnkayapofey@mail2russia.com', 'sender_name': ' "MRS. LARISA SOSNITSKAYA" '}
# {'sender_email': 'jonathancharles3@hotmail.com', 'sender_name': ' Jonathan Charles '}
# {'sender_email': 'nopparat@indiatimes.com', 'sender_name': ' "Mr. Nopparat Sujaritpinij" '}
# {'sender_email': 'morenogarcia@web2mail.com', 'sender_name': ' "Mr. Moreno Garcia" '}
# {'sender_email': 'mrssalehgalal@myway.com', 'sender_name': ' "Mrs.Mary Saleh Galal" '}
# {'sender_email': 'nelsonsmith033@terra.es', 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'edwardmoore99@yahoo.co.uk', 'sender_name': ' "Edward Moore & Associates" '}
# {'sender_email': 'johnp11@iwon.com', 'sender_name': ' "Mr John Jasper" '}
# {'sender_email': 'attahmarieange23@hotmail.fr', 'sender_name': ' marie ange attah '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'robertwills@pre.sltnet.lk', 'sender_name': ' Robert Williams '}
# {'sender_email': 'adnanhram@aim.com', 'sender_name': None}
# {'sender_email': 'michjones@mickyjones.co.uk', 'sender_name': ' Michael Jones '}
# {'sender_email': 'koutab0078@hotmail.com', 'sender_name': ' Koutaba jean '}
# {'sender_email': 'bullfrog812@charter.net', 'sender_name': ' Phillip Croce '}
# {'sender_email': 'asinthe_nignan33@hotmail.fr', 'sender_name': ' asinthe nignan '}
# {'sender_email': 'robertwills@pre.sltnet.lk', 'sender_name': ' Robert Williams '}
# {'sender_email': 'emekaben@aol.co.uk', 'sender_name': None}
# {'sender_email': 'edwardmoore99@yahoo.co.uk', 'sender_name': ' "Edward Moore & Associates" '}
# {'sender_email': 'gmboma2@hotmail.com', 'sender_name': ' "Mr. Gamudi Mboma" '}
# {'sender_email': 'mrcolinshand20@poczta.pf.pl', 'sender_name': ' mrcolinshand20 '}
# {'sender_email': 'richard_bongo112za@hotmail.com', 'sender_name': ' richard bongo '}
# {'sender_email': 'richard_bongo112za@hotmail.com', 'sender_name': ' richard bongo '}
# {'sender_email': 'koutab0025@hotmail.com', 'sender_name': ' Koutaba jean '}
# {'sender_email': 'drahmed_sh14@hotmail.com', 'sender_name': ' DR AHMED SHALAA '}
# {'sender_email': 'collins_lyons73@yahoo.co.uk', 'sender_name': ' COLLINS LYONS '}
# {'sender_email': 'rahim.attah1@virgilio.it', 'sender_name': ' "Mr.Jonathan Mutambara" '}
# {'sender_email': 'fred_williams05@o2.pl', 'sender_name': ' "FREDERICK WILLIAMS." '}
# {'sender_email': 'amija_1035@hotmail.com', 'sender_name': ' amir jasmin '}
# {'sender_email': 'mamud_islandoil@yahoo.com.hk', 'sender_name': ' "Mahmud Azzam" '}
# {'sender_email': 'mamud_islandoil@yahoo.com.hk', 'sender_name': ' "Mahmud Azzam" '}
# {'sender_email': 'chris_anderson@universia.com.br', 'sender_name': ' CHRIS ANDERSON '}
# {'sender_email': 'bencoroma12@hotmail.com', 'sender_name': ' ben coroma '}
# {'sender_email': 'larisasosnkayapawou@mail2russia.com', 'sender_name': ' "MRS. LARISA SOSNITSKAYA" '}
# {'sender_email': 'Mashaba=0D=0AEmail:kmashaba@myway.com=0D=0ATel', 'sender_name': None}
# {'sender_email': 'williamkabila05@gmail.com', 'sender_name': ' MR WILLIAM KABILA '}
# {'sender_email': 'joemelosi@charter.net', 'sender_name': ' LIKA CHEUNG HOLDINGS LIMITED '}
# {'sender_email': 'larisasosnkayanxly@mail2russia.com', 'sender_name': ' "MRS. LARISA SOSNITSKAYA" '}
# {'sender_email': 'james_roberts007@navegante.com.sv', 'sender_name': ' " MR james roberts" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'drpaulsule1950@o2.pl', 'sender_name': ' "Dr. Paul A. Sule" '}
# {'sender_email': 'johnali20@hotmail.com', 'sender_name': ' john alison '}
# {'sender_email': 'alimoheamed1@mynet.com', 'sender_name': ' "alimoheamed1" '}
# {'sender_email': 'info_unionbankofchain007@adelphia.net', 'sender_name': ' "Mr. Joseph Chau." '}
# {'sender_email': 'patrickokonta10@virgilio.it', 'sender_name': ' Mr Paul Baloyi '}
# {'sender_email': 'patrickokonta10@virgilio.it', 'sender_name': ' Mr Paul Baloyi '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'nabjib_n27@hotmail.fr', 'sender_name': ' nabjib ibrahim '}
# {'sender_email': 'nabjib_n27@hotmail.fr', 'sender_name': ' nabjib ibrahim '}
# {'sender_email': 'sitholi@webmail.co.za', 'sender_name': ' "Mr. Albert Sitholi" '}
# {'sender_email': 'fredrick.thambo.107@hotmail.com', 'sender_name': ' fredrick thambo '}
# {'sender_email': 'musa_saladin030@hotmail.com', 'sender_name': ' musa saladin '}
# {'sender_email': 'peterndaba@fsmail.net', 'sender_name': ' "PETER NDABA" '}
# {'sender_email': 'kouajo@hotmail.fr', 'sender_name': None}
# {'sender_email': 'david_ray202@yahoo.co.uk', 'sender_name': ' "DR DAVID RAY" '}
# {'sender_email': 'meetic@meetic.com', 'sender_name': ' JOHN ABOH '}
# {'sender_email': 'mikhail@yukosoil.com', 'sender_name': ' "Mikhail Khodorkovsky" '}
# {'sender_email': 'koajoo_aka@yahoo.com', 'sender_name': None}
# {'sender_email': 'mrst5heresa@hotmail.fr', 'sender_name': ' theresa coleman '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'alexandro_solarin1973@yahoo.co.uk', 'sender_name': ' "A.B. Solarin" '}
# {'sender_email': 'mart_mazuri03@yahoo.ca', 'sender_name': ' "Martins Mazuri" '}
# {'sender_email': 'mr66leon@hotmail.com', 'sender_name': ' "Mr. Peter Leon" '}
# {'sender_email': 'kouakou_chantou15@hotmail.fr', 'sender_name': ' chantal kouakou '}
# {'sender_email': 'kouakou_chantou15@hotmail.fr', 'sender_name': ' chantal kouakou '}
# {'sender_email': 'sahidi_ngoma14@hotmail.fr', 'sender_name': ' sahidi ngoma '}
# {'sender_email': 'officialmail@realmail.co.uk', 'sender_name': ' Capt James C Willians '}
# {'sender_email': 'IRS"<refund@irs.gov', 'sender_name': ' "IRS"'}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'm_adams1102@walla.com', 'sender_name': ' "MR. MARK ADAMS" '}
# {'sender_email': 'm_adams1102@walla.com', 'sender_name': ' "MR. MARK ADAMS" '}
# {'sender_email': 'bala_kabore48@hotmail.fr', 'sender_name': ' "bala kabore" '}
# {'sender_email': 'd_dudu@virgilio.it', 'sender_name': ' "DR.IDRISSA SEKK" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'geraldzongo_38@hotmail.fr', 'sender_name': ' gerald zongo '}
# {'sender_email': 'chant004@hotmail.fr', 'sender_name': ' chantal kouakou '}
# {'sender_email': 'princess_gesinta016@hotmail.fr', 'sender_name': ' princess gesinta '}
# {'sender_email': 'williambrown@virgilio.it', 'sender_name': ' MR JAMES ROBERTS '}
# {'sender_email': 'pre91@pre.sltnet.lk', 'sender_name': ' Tim McCarron '}
# {'sender_email': 'coalition_protect@yahoo.fr', 'sender_name': ' "Chief Anthony Enahoro. JP" '}
# {'sender_email': 'Akintunde"<r.akintunde@yahoo.it', 'sender_name': ' "Richard Akintunde"'}
# {'sender_email': 'martinsakim@handbag.com', 'sender_name': ' "Martins Akim" '}
# {'sender_email': 'ahassan1696@gmail.com', 'sender_name': ' "Dr. Ahmed Hassan" '}
# {'sender_email': 'ahassan1696@gmail.com', 'sender_name': ' "Dr. Ahmed Hassan" '}
# {'sender_email': 'luisa@blue-conn.de', 'sender_name': ' "LUISA ESTRADA" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'bjsri072@hotmail.com', 'sender_name': ' "bjsri budak" '}
# {'sender_email': 'benmowilliamss@lawyer.com', 'sender_name': ' Barrister Al Mohammed El Said '}
# {'sender_email': 'stella.sigcau4@virgilio.it', 'sender_name': ' Gary William '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'fredmaxwell@virgilio.it', 'sender_name': ' "Mr. Robin Shephard" '}
# {'sender_email': 'leonardmuller@virgilio.it', 'sender_name': ' "Martin J. Waghorn" '}
# {'sender_email': 'kimati_didan@excite.com', 'sender_name': ' "Didan Kimati" '}
# {'sender_email': 'mrlaad_cologo13@hotmail.fr', 'sender_name': ' MR LAAD cologo '}
# {'sender_email': 'harryugo@zipmail.com.br', 'sender_name': None}
# {'sender_email': 'mikkon5@hotmail.fr', 'sender_name': ' mike kone '}
# {'sender_email': 'dyorke@freenet.de', 'sender_name': ' "Dave Yorke." '}
# {'sender_email': 'msalhak@yahoo.com', 'sender_name': ' "Mrs  Farah Al-hashemi" '}
# {'sender_email': 'msalhak@yahoo.com', 'sender_name': ' "Mrs  Farah Al-hashemi" '}
# {'sender_email': 'ericjohnson6@myway.com', 'sender_name': ' Eric Johnson '}
# {'sender_email': 'sahidi_ngoma13@hotmail.fr', 'sender_name': ' sahidi ngoma '}
# {'sender_email': 'mikeko018@hotmail.fr', 'sender_name': ' mike kone '}
# {'sender_email': 'tonywach4@hotmail.com', 'sender_name': ' tony anthony '}
# {'sender_email': 'mrsbakare@rediffmail.com', 'sender_name': ' PROF CHARLES SOLUDO '}
# {'sender_email': 'urgentmatter@sunumail.sn', 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'inheritance_fund00@o2.pl', 'sender_name': ' "REV.WILSON MORGAN" '}
# {'sender_email': 'inheritance_fund00@o2.pl', 'sender_name': ' "REV.WILSON MORGAN" '}
# {'sender_email': 'janetbradford@sunumail.sn', 'sender_name': None}
# {'sender_email': 'stella.sigcau4@virgilio.it', 'sender_name': ' Gary William '}
# {'sender_email': 'aphisak.project@yahoo.co.th', 'sender_name': ' "Mr Aphisak Tantiworawong" '}
# {'sender_email': 'jkemp1968@yahoo.co.uk', 'sender_name': ' J_KEMPWELCH01 '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'morgan.wimpoe01@yahoo.com', 'sender_name': ' "Mr.Morgan Wimpoe" '}
# {'sender_email': 'alima_kkk10@centrum.cz', 'sender_name': ' '}
# {'sender_email': 'dmike0013@o2.pl', 'sender_name': ' "Adekunle michael." '}
# {'sender_email': 'buddycrk@fuse.net', 'sender_name': ' QIN LI WANG '}
# {'sender_email': 'idris_makafi167@hotmail.fr', 'sender_name': ' idris makafi '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'clementasuzu@yahoo.it', 'sender_name': ' "DR. CLEMENT ASUZU" '}
# {'sender_email': 'ball16@hotmail.fr', 'sender_name': ' emma tano '}
# {'sender_email': 'Banking@Bankofamerica.com', 'sender_name': ' "Bank of America" '}
# {'sender_email': 'spiritsanct@onetel.com', 'sender_name': ' Mou Xinsheng '}
# {'sender_email': 'cbnpayment.org@host45.porar.com', 'sender_name': ' "Prof.Charles.C.Soludo" '}
# {'sender_email': 'matinread@turbonett.com', 'sender_name': None}
# {'sender_email': 'jen_marthin@centrum.sk', 'sender_name': ' "jen_marthin" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'aziz_moustafa100@hotmail.com', 'sender_name': ' "aziz moustafa" '}
# {'sender_email': 'mbd095@hotmail.com', 'sender_name': ' MM BB '}
# {'sender_email': 'mrsfarah30@yahoo.co.uk', 'sender_name': ' "Mrs Farah al-Hashemi" '}
# {'sender_email': 'kanazoe_alidaa0007@hotmail.fr', 'sender_name': ' kanazoe alidaa '}
# {'sender_email': 'wil_li_net0064@hotmail.fr', 'sender_name': ' williams susan '}
# {'sender_email': 'bajoga@latinmail.com', 'sender_name': ' "bajoga bajoga" '}
# {'sender_email': 'rubzuul@freenet.de', 'sender_name': ' "Robert Zulugan." '}
# {'sender_email': 'mrsfarah30@yahoo.co.uk', 'sender_name': ' "Mrs. Farah al-Hashemi" '}
# {'sender_email': 'jaron_abbass@yahoo.de', 'sender_name': ' Jaron Abbas '}
# {'sender_email': 'jaron_abbass@yahoo.de', 'sender_name': ' Jaron Abbas '}
# {'sender_email': 'adams5swill@hotmail.com', 'sender_name': ' adams swill '}
# {'sender_email': 'susan_john203@yahoo.co.uk', 'sender_name': ' susan  john '}
# {'sender_email': 'gosolanges@latinmail.com', 'sender_name': ' "GOBLOUSO SOLANGE " '}
# {'sender_email': 'djedjess007@hotmail.com', 'sender_name': ' Prince David Djedjess '}
# {'sender_email': 'adams_kabora11@hotmail.com', 'sender_name': ' adams kabora '}
# {'sender_email': 'adams_kabora31@hotmail.com', 'sender_name': ' adams kabora '}
# {'sender_email': 'christopherwilson@sunumail.sn', 'sender_name': ' "Christopher  Wilson" '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'chantalveroniq2@yahoo.fr', 'sender_name': ' '}
# {'sender_email': 'johnhill87@aol.fr', 'sender_name': ' JOHN HILL '}
# {'sender_email': 'esoil_gasltd231@yahoo.com.hk', 'sender_name': ' CAROL HARVEY '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'mr_isedore_lawan0053@hotmail.fr', 'sender_name': ' isedore lawan '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'benjaminosolarin4u@yahoo.co.uk', 'sender_name': ' "Mr A.B Solarino" '}
# {'sender_email': 'felissajen115@hotmail.fr', 'sender_name': ' HARRISON FELISSA '}
# {'sender_email': 'mrscarolyn@virgilio.it', 'sender_name': ' MR NELSON BROWN '}
# {'sender_email': 'onlineli@phreego.com', 'sender_name': ' "Sunoco Sun Oil Company Ltd" '}
# {'sender_email': 'onlineli@phreego.com', 'sender_name': ' "Sunoco Sun Oil Company Ltd" '}
# {'sender_email': 'joelthomson804@hotmail.com', 'sender_name': ' joel thomson '}
# {'sender_email': 'peter@hangsengbank.com.hk', 'sender_name': ' HANG SENG BANK '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'Lee"<stevnlee010@sify.com', 'sender_name': ' "Steven Lee"'}
# {'sender_email': 'ch_20007@centrum.cz', 'sender_name': ' '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'liuyan_office@yahoo.com.hk', 'sender_name': ' LIUYANMAILPOST '}
# {'sender_email': 'kmashaba1@myway.com', 'sender_name': ' "MR. KENNETH MASHABA" '}
# {'sender_email': 'ooxxee.ooxxeee03@laposte.net', 'sender_name': ' "The SHIGA BANK LTD" '}
# {'sender_email': 'femirhodes@virgilio.it', 'sender_name': ' "Louis (Business).." '}
# {'sender_email': 'ooxxee.ooxxeee03@laposte.net', 'sender_name': ' "The SHIGA BANK LTD" '}
# {'sender_email': 'a_annah50@hotmail.com', 'sender_name': ' "MRS. ANNAH KRUGA" '}
# {'sender_email': 'nafmohd101@yahoo.fr', 'sender_name': None}
# {'sender_email': 'julia.chen.shenhua.group@hotmail.com" <ooxxee.ooxxeee03@laposte.net', 'sender_name': ' "julia.chen.shenhua.group@hotmail.com" '}
# {'sender_email': 'mansuguri63@hotmail.com', 'sender_name': ' nelson mansuguri '}
# {'sender_email': 'kali_oddo017@hotmail.fr', 'sender_name': ' kali oddo '}
# {'sender_email': 'jamesbongani10015@latinmail.com', 'sender_name': ' "james bongani" '}
# {'sender_email': 'us_zongo35@hotmail.fr', 'sender_name': ' us zongo '}
# {'sender_email': 'gladvince01@yahoo.co.uk', 'sender_name': ' Vincent Cheung '}
# {'sender_email': None, 'sender_name': None}
# {'sender_email': 'wrightchember@gmail.com', 'sender_name': ' "BARR.JONATHAN WRIGHT" '}
# {'sender_email': 'petertayloruk2@yahoo.de', 'sender_name': ' petertaylor '}
# {'sender_email': 'jaron_abbass@yahoo.de', 'sender_name': ' Jaron Abbas '}
# {'sender_email': 'mrjombo23@hotmail.fr', 'sender_name': ' patrick jombo '}
# {'sender_email': 'ablmusa_03@hotmail.fr', 'sender_name': ' abl musa '}
# {'sender_email': 'dickson_robert1@virgilio.it', 'sender_name': ' "Dr. David Smith" '}
# {'sender_email': 'idris40adamu@hotmail.fr', 'sender_name': ' IDRIS ADAMU '}
# {'sender_email': 'kennethobia5@hotmail.com', 'sender_name': ' KENNETH OBI '}
# {'sender_email': 'henryallenci@seznam.cz', 'sender_name': ' "HENRY ALLEN" '}
# {'sender_email': 'mobeef@birch.net', 'sender_name': ' Mr John Davids '}
# {'sender_email': 'mobeef@birch.net', 'sender_name': ' Khaled Bin al- Walid '}
# {'sender_email': 'motherdorisk93@hotmail.com', 'sender_name': ' Mother Doris Killam '}
# {'sender_email': 'best.list@laposte.net', 'sender_name': ' "Fernando Gonzalez" '}
# {'sender_email': 'tony_eselu2@virgilio.it', 'sender_name': ' "From Dr. Jackson Gaius-Obaseki" '}
# {'sender_email': 'michealagu0255@zipmail.com.br', 'sender_name': None}
# {'sender_email': 'ali_sherif252@hotmail.fr', 'sender_name': ' ali sherif '}
# {'sender_email': 'drusmanibrahimtg08@hotmail.fr', 'sender_name': ' Dr Usman Ibrahim Danko '}
# {'sender_email': 'motherdorisk61@hotmail.com', 'sender_name': ' Mother Doris Killam '}
# {'sender_email': None, 'sender_name': None}

# %%
emails_dict
# Out:
# {'sender_email': None, 'sender_name': None}

# %% [markdown]
# Again, we have match objects. Every time we apply re.search() to strings, it produces match objects. We have to turn them into string objects.
#
# Before we do this, recall that if there is no From: field, sender would have the value of None, and so too would s_email and s_name. Hence, we have to check for this scenario again so that the script doesn’t break unexpectedly. Let’s see how to construct the code with s_email first.
#
#
# Then, we use the re module’s re.sub() function twice before assigning the string to a variable. First, we remove the colon and any whitespace characters between it and the name. We do this by substituting :s* with an empty string "". Then, we remove whitespace characters and the angle bracket on the other side of the name, again substituting it with an empty string. Finally, after assigning the string to sender_name, we add it to the dictionary.

# %%
#Now that we’ve found the sender’s email address and name, we do exactly the same set of steps 
#to acquire the recipient’s email address and name for the dictionary.

# %%
for item in contents:
# First two lines again so that Jupyter runs the code.
  emails_dict = {}

# Find sender's email address and name.

    # Step 1: find the whole line beginning with "From:".
  sender = re.search(r"From:.*", item)
  # Step 2: find the email address and name.
  if sender is not None:
    s_email = re.search(r"\w\S*@.*\w", sender.group())
    s_name = re.search(r":.*<", sender.group())
  else:
    s_email = None
    s_name = None

# Step 3A: assign email address as string to a variable.
  if s_email is not None:
      sender_email = s_email.group()
  else:
      sender_email = None
# Add email address to dictionary.
  emails_dict["sender_email"] = sender_email

  if s_name is not None:
      sender_name = re.sub("s*<", "", re.sub(":s*", "", s_name.group()))
  else:
      sender_name = None

# Add sender's name to dictionary.
  emails_dict["sender_name"] = sender_name
  
  

  recipient = re.search(r"To:.*", item)
  if recipient is not None:
    r_email = re.search(r"\w\S*@.*\w", recipient.group())
    #print (r_email.group())
    r_name = re.search(r":.*<", recipient.group())
    #print(r_name.group())
  else:
    r_email = None
    r_name = None

  if r_email is not None:
    #print(r_email.group())
    recipient_email = r_email.group()
  else:
    recipient_email = None

  emails_dict["recipient_email"] = recipient_email

  if r_name is not None:
    
    recipient_name = re.sub("\s*<", "", re.sub(":\s*", "", r_name.group()))
    print(recipient_name)
  else:
    recipient_name = None

  emails_dict["recipient_name"] = recipient_name
# Out:
# " resbob@al-islam.com"
#
# "=?iso-8859-1?Q?lawrence.smith?="
#
# "elisabth  lamine"
# "webmaster@aclweb.org"
#
# "R@M"
# "grace abba-gana"
#
# "astrada@kukamail.com"
#
# "godfrey eche3"
# "godfrey eche3"
# "s.kaa@katamail.com"
# =?iso-8859-1?Q?makathy?=
# Rrrrr
# Rrrrr
# Rrrrr
#
# Rrrrr
# Rrrrr
# Rrrrr
#
# "SI2003@kukamail.com"
# llavanwa@UM>,rossah@UM>,
#
#
#
#
#
#
#
#
# "zainabuba@katamail.com"
# "patelnikes4you"
# "patelnikes4you"
# "patelnikes4you"
#
#
#
#
# "mjaja02"
#
# "jeffersila04"
# "dr_frances"
# "dr_frances"
# "markduke2004"
#
# "williams\.onwa"
#
# "larry_ed1"
#
# "Shadak Shari"
# "Shadak Shari"
# "Shadak Shari"
# rrrrr
# "info@crack-ag.com"
# "Joey"
# "rrrrr"
#
#
# Masesela Dikgale
#
#
# "rrrrr"
# rrrrr
# "rrrrr"
# "rrrrr"
# rrrrr
# "kenneth masuku."
# "danbrown"
# "SESAY MASSAQUOE."
# "SESAY MASSAQUOE."
#
#
#
#
#
#
# rrrrr
#
#
#
#
# rrrrr
# "lucas"
# rrrrr
# rrrrr
# rrrrr
# rrrrr
# rrrrr
# "mohammad urban"
# "mohammad urban"
# rrrrr
#
#
# "benard_mcarthy@wanadoo.es"
# "benard_mcarthy@wanadoo.es"
# rrrrr
#
#
# "KOJO WILLIAM"
#
#
# rrrrr
# "webmaster"
# "webmaster"
#
# "peterkhan@latinmail.com"
# "webmaster"
# "webmaster"
# "webmaster"
# "webmaster"
# "webmaster"
# "webmaster"
#
#
#
#
#
#
#
#
# "moh_yaya005@latinmail.com"
# rrrrr
#
# rrrrr
# rrrrr
# webmaster
# webmaster
# webmaster
# webmaster
# rrrrr
# rrrrr
# "Mr.Kabir Bello."
#
# Rrrrr
# Webmaster
#
#
# "R@M\r"
#
#
#
#
# "Investment"
# "Mr. Ben Otutu."
# rrrrr
# "will.wilcox1@virgin.net"
# "charakroultwells@adinet.com.uy"
# "charakroultwells@adinet.com.uy"
# "FROM DESSU METHAN"
# "vski.ziv@virgin.net"
# "ELIZABETH GARANGE"
#
#
# "david"
#
# "Rrrrr"
# "sem_bouabre"
# Karonga Zungu
# Karonga Zungu
# Karonga Zungu
# Karonga Zungu
# Karonga Zungu
# Karonga Zungu
# Karonga Zungu
# Karonga Zungu
# "Nepyyvoda Petro"
# "JAMES MORGAN"
# rrrrr
# "Rrrrr"
# sigmod-pods06-webmaster
# "Rrrrr"
# "Rrrrr"
#
#
# "Harry Hilal"
#
# rrrrr
#
#
# rrrrr
# "jim owens"
# ELIZABETH LAMINE
#
# "mary_20bamba@latinmail.com"
#
#
# rrrrr
# rrrrr
# "david505@adinet.com.uy"
# "mrcliveosborn@netscape.net"
#
# "dr_idris_ali@latinmail.com"
# "emeson_joe02@latinmail.com"
# "emeson_joe02@latinmail.com"
# "emeson_joe02@latinmail.com"
# "emeson_joe02@latinmail.com"
# "Mr. Moore"
#
# "mustafa_joseph01@latinmail.com"
#
# rrrrr
# "mjerry@adinet.com.uy"
# "joe_kekabu4@latinmail.com"
# "joe_kekabu4@latinmail.com"
# "joe_kekabu4@latinmail.com"
# "joe_kekabu4@latinmail.com"
# "joe_kekabu4@latinmail.com"
# "joe_kekabu4@latinmail.com"
# "joe_kekabu4@latinmail.com"
# "joe_kekabu4@latinmail.com"
# rrrrr
#
#
#
# "Barr.Charles Brown"
# "williamspadmore"
#
# "musa_sani00@latinmail.com"
# "azize_ouattara@latinmail.com"
# "steven taha"
#
#
# rrrrr
# "bala_tomson3@latinmail.com"
# "ben_coroma75@latinmail.com"
# "Rrrrr"
# "Webmaster"
# "john_jacob@latinmail.com"
# "jamessakato2@latinmail.com"
# "jamessakato2@latinmail.com"
# "mose_maliki@latinmail.com"
# "Doris Luanda"
#
# "jenniferwils@terra.es"
# "jenniferwils@terra.es"
# "jenniferwils@terra.es"
# "faith5ad@latinmail.com"
#
# "Lon Morton"
# "rose_c2006@latinmail.com"
# "pio_mohammed1@latinmail.com"
# "WEST BANK"
# "Larisa Sosnitskaya"
#
# "linda_kokori@latinmail.com"
# "alicelacson8@latinmail.com"
# "musagaruba2005@latinmail.com"
# "faith5ad@latinmail.com"
# "florenceeteh@latinmail.com"
# "smart_60@latinmail.com"
# "drphilipk@adinet.com.uy"
#
#
#
#
# "garuba_umaru2005@latinmail.com"
# "ppw9500@excite.com "
#
# "rrrrr"
#
# "joe4jkk@latinmail.com"
# "joe4jkk@latinmail.com"
# rrrrr
# rrrrr
# rrrrr
# "abdulaye_baraze@latinmail.com"
# rrrrr
# "justus_lee002@latinmail.com"
# rrrrr
# daemon
# "seyes_campury@latinmail.com"
# "musa_garuba55@latinmail.com"
# rrrrr
# "sulemanz@latinmail.com"
# "joe_alex1bf@latinmail.com"
# rrrrr
# rrrrr
# "Comhghall Partin"
# rrrrr
# "jonesalun@terra.es"
# rrrrr
# rrrrr
# sigmod-pods06-webmaster
#
# rrrrr
# "mohammed_hassan@latinmail.com"
# rrrrr
# rrrrr
#
# rrrrr
# rrrrr
# giorgi krissy
# rrrrr
#
# rrrrr
# "sa_dlo1@terra.es"
#
# rrrrr
# "Administrator"
# Razaq Samiu
# rrrrr
# Razaq Samiu
#
#
# rrrrr
#
# "lacson alice"
#
# "rrrrr"
# "rrrrr"
# rrrrr
# ""
# rrrrr
# "david1111kalabi@terra.es"
# "Mrs. Tonia Van Smith"
# "markwwww@terra.es"
# rrrrr
# "LETTER FROM MR.JOSEPH POON"
#
# "rrrrr"
# "sulemanzz@latinmail.com"
#
#
#
# "rrrrr"
#
# "saku_watara2007@latinmail.com"
#
#
#
# "Rachael Oniga"
# "linda1m1@terra.es"
# "evansonumba16@tiscali.co.uk"
#
#
#
# shoulson@cs.CU>,
#
#
#
# "mr_hassanbilly01@latinmail.com"
#
#
# "pae.za@terra.es"
# "MRS. LARISA SOSNITSKAYA"
#
#
#
#
#
#
#
#
# "MRS. LARISA SOSNITSKAYA"
#
# ""
#
#
#
#
#
# "rrrrr"
# N/A>, N/A
# N/A
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# "bajoga@latinmail.com"
#
# "gosolanges@latinmail.com"
#
#
#
#
#
# ""
# ""
#
#
#
#
#
#
#
# "jamesbongani10015@latinmail.com"

# %%
#Getting the Date of the Email

for item in contents:
# First two lines again so that Jupyter runs the code.
  emails_dict = {}

  date_field = re.search(r"Date:.*", item)
  if date_field is not None:
    date = re.search(r"\d+\s\w+\s\d+", date_field.group())
  else:
    date = None

  if date is not None:
    date_sent = date.group()
    date_star = date_star_test.group()
  else:
    date_sent = None

emails_dict["date_sent"] = date_sent

print(date_field.group())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-bb46833c4a76> in <module>()
#      12   if date is not None:
#      13     date_sent = date.group()
# ---> 14     date_star = date_star_test.group()
#      15   else:
#      16     date_sent = None
#
# NameError: name 'date_star_test' is not defined

# %%
import re
import pandas as pd
import email

emails = []


contents = re.split(r"From r",fh)
contents.pop(0)

for item in contents:
    emails_dict = {}

    sender = re.search(r"From:.*", item)

    if sender is not None:
        s_email = re.search(r"\w\S*@.*\w", sender.group())
        s_name = re.search(r":.*<", sender.group())
    else:
        s_email = None
        s_name = None

    if s_email is not None:
        sender_email = s_email.group()
    else:
        sender_email = None

    emails_dict["sender_email"] = sender_email

    if s_name is not None:
        sender_name = re.sub("\s*<", "", re.sub(":\s*", "", s_name.group()))
    else:
        sender_name = None

    emails_dict["sender_name"] = sender_name

    recipient = re.search(r"To:.*", item)

    if recipient is not None:
        r_email = re.search(r"\w\S*@.*\w", recipient.group())
        r_name = re.search(r":.*<", recipient.group())
    else:
        r_email = None
        r_name = None

    if r_email is not None:
        recipient_email = r_email.group()
    else:
        recipient_email = None
    emails_dict["recipient_email"] = recipient_email

    if r_name is not None:
        recipient_name = re.sub("s*<", "", re.sub(":s*", "", r_name.group()))
    else:
        recipient_name = None

    emails_dict["recipient_name"] = recipient_name

    date_field = re.search(r"Date:.*", item)

    if date_field is not None:
        date = re.search(r"\d+\s\w+\s\d+", date_field.group())
    else:
        date = None

    if date is not None:
        date_sent = date.group()
    else:
        date_sent = None

    emails_dict["date_sent"] = date_sent

    subject_field = re.search(r"Subject: .*", item)

    if subject_field is not None:
        subject = re.sub(r"Subject: ", "", subject_field.group())
    else:
        subject = None

    emails_dict["subject"] = subject

    # "item" substituted with "email content here" so full email not
# displayed.

    full_email = email.message_from_string(item)
    body = full_email.get_payload()
    emails_dict["email_body"] = "email body here"

    emails.append(emails_dict)
# Print number of dictionaries, and hence, emails, in the list.
print("Number of emails: " + str(len(emails)))

print("\n")

# Print first item in the emails list to see how it looks.
for key, value in emails[0].items():
    print(str(key) + ": " + str(emails[0][key]))
# Out:
# Number of emails: 3977
#
#
# sender_email: james_ngola2002@maktoob.com
# sender_name: "MR. JAMES NGOLA."
# recipient_email: james_ngola2002@maktoob.com
# recipient_name: None
# date_sent: 31 Oct 2002
# subject: URGENT BUSINESS ASSISTANCE AND PARTNERSHIP
# email_body: email body here

# %% [markdown]
# ##Manipulating Data With Pandas

# %%
import pandas as pd
# Module imported above, imported again as reminder.
emails_df = pd.DataFrame(emails)

# %%
emails_df.head()
# Out:
#                    sender_email  ...       email_body
# 0   james_ngola2002@maktoob.com  ...  email body here
# 1  bensul2004nng@spinfinder.com  ...  email body here
# 2          obong_715@epatra.com  ...  email body here
# 3          obong_715@epatra.com  ...  email body here
# 4            m_abacha03@www.com  ...  email body here
#
# [5 rows x 7 columns]

# %% [markdown]
# We can also find precisely what we want. For instance, we can find all the emails sent from a particular domain name. However, let’s learn a new regex pattern to improve our precision in finding the items we want.
#
# The pipe symbol, |, looks for characters on either side of itself. For instance, a|b looks for either a or b.
#
# | might seem to do the same as [ ], but they really are different. Suppose we want to match either "crab", "lobster", or "isopod". Using crab|lobster|isopod would make more sense than [crablobsterisopod], wouldn’t it? The former would look for each whole word, whereas the latter would look for every single letter.

# %%
emails_df[emails_df["sender_email"].str.contains("epatra|spinfinder",na=False)]
# Out:
#                      sender_email  ...       email_body
# 1    bensul2004nng@spinfinder.com  ...  email body here
# 2            obong_715@epatra.com  ...  email body here
# 3            obong_715@epatra.com  ...  email body here
# 567            kaladah@epatra.com  ...  email body here
# 584       rharare1@spinfinder.com  ...  email body here
#
# [5 rows x 7 columns]

# %%
# Step 1: find the index where the "sender_email" column contains "@spinfinder.com".
index = emails_df[emails_df["sender_email"].str.contains(r"\w\S*@spinfinder.com",na=False)].index.values

# %%
# Step 2: use the index to find the value of the cell i the "sender_email" column.
# The result is returned as pandas Series object
address_Series = emails_df.loc[index]["sender_email"]
print(address_Series)
print(type(address_Series))
# Out:
# 1      bensul2004nng@spinfinder.com
# 584         rharare1@spinfinder.com
# Name: sender_email, dtype: object
# <class 'pandas.core.series.Series'>

# %%
# Step 3: extract the email address, which is at index 0 in the Series object.
address_string = address_Series[1]
print(address_string)
print(type(address_string))
# Out:
# bensul2004nng@spinfinder.com
# <class 'str'>

# %%
# Step 4: find the value of the "email_body" column where the "sender email" column is address_string.
print(emails_df[emails_df["sender_email"] == address_string]["email_body"].values)
# Out:
# ['email body here']

# %%
##Regex Groups

# %% [markdown]
# Group Extraction
# The "group" feature of a regular expression allows you to pick out parts of the matching text. Suppose for the emails problem that we want to extract the username and host separately. To do this, add parenthesis ( ) around the username and host in the pattern, like this: r'([\w.-]+)@([\w.-]+)'. In this case, the parenthesis do not change what the pattern will match, instead they establish logical "groups" inside of the match text. On a successful search, match.group(1) is the match text corresponding to the 1st left parenthesis, and match.group(2) is the text corresponding to the 2nd left parenthesis. The plain match.group() is still the whole match text as usual.

# %%
str = 'purple alice-b@google.com monkey dishwasher'
match = re.search(r'([\w.-]+)@([\w.-]+)', str)
if match:
  print (match.group())   ## 'alice-b@google.com' (the whole match)
  print (match.group(1))  ## 'alice-b' (the username, group 1)
  print (match.group(2))  ## 'google.com' (the host, group 2)
# Out:
# alice-b@google.com
# alice-b
# google.com

# %% [markdown]
# #In Class
#
# Problem 1: Return the each Character of a given string without inclucing spaces
#
#
# 'Intellee is an academy for getting your IT skills upgraded'

# %% [markdown]
# 'Intellee is an academy for getting your IT skills upgraded'

# %%
import re
result=re.findall(r'\w','Intellee is an academy for getting your IT skills upgraded')
print (result)
# Out:
# ['I', 'n', 't', 'e', 'l', 'l', 'e', 'e', 'i', 's', 'a', 'n', 'a', 'c', 'a', 'd', 'e', 'm', 'y', 'f', 'o', 'r', 'g', 'e', 't', 't', 'i', 'n', 'g', 'y', 'o', 'u', 'r', 'I', 'T', 's', 'k', 'i', 'l', 'l', 's', 'u', 'p', 'g', 'r', 'a', 'd', 'e', 'd']

# %% [markdown]
# #Problem 2: Return the last and first words of a given string without inclucing spaces

# %%
input_string = 'Intellee is an academy for getting your IT skills upgraded'
result=re.findall(r'^\w+',input_string)
print (result)
result=re.findall(r'\w+$',input_string)
print (result)
# Out:
# ['Intellee']
# ['upgraded']

# %% [markdown]
# #Problem 2: Return the first two character of each word

# %%
result=re.findall(r'\b\w\w',input_string)
print (result)
# Out:
# ['In', 'is', 'an', 'ac', 'fo', 'ge', 'yo', 'IT', 'sk', 'up']

# %% [markdown]
# #Problem 3: Return the domain of a email id

# %%
result=re.findall(r'([\S]*)@(\w+).(\w+)','abc.test@gmail.com, xyz@test.in, test.first@rbc.com, first.test@rest.biz')
print (result)
# Out:
# [('', 'gmail', 'com'), ('', 'test', 'in'), ('', 'rbc', 'com'), ('', 'rest', 'biz')]

# %% [markdown]
# #Problem 4: Return date from given string

# %%
result=re.findall(r'\d{2}-\d{2}-\d{4}','Amit 34-3456 12-05 07, XYZ 56-4532 11*11-11, ABC 67-8945 12 01 2009')
print (result)
# Out:
# ['12-05-2007', '11-11-2011', '12-01-2009']

# %% [markdown]
# #Problem 5: Return all words of a string those starts with vowel

# %%
result=re.findall(r'\b[aeiouAEIOU]\w+',input_string)
print (result)
# Out:
# ['Intellee', 'is', 'an', 'academy', 'IT', 'upgraded']

# %% [markdown]
# #Problem 6: Validate a phone number (phone number must be of 10 digits and starts with 7 or 4)

# %%
import re
li=['7057967656','413-705-7966','4137057966']
for val in li:
 if re.match(r'[4,7]{1}[0-2-]{9,13}',val) and (len(val) >= 10 and len(val) < 13):
     print ('yes')
 else:
     print ('no')
# Out:
# no
# no
# no
